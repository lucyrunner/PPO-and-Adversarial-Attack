# %%
from __future__ import annotations
import numpy as np
import gymnasium as gym
from gymnasium import spaces

class ACCEnv(gym.Env):
    """
    1D ACC environment with simple kinematics and a headway-based safety filter.

    Observation s = [Δx, Δv, v]  (raw units: m, m/s, m/s)
    Action a = acceleration in m/s^2 (continuous).

    Normalization:
      - If normalize_obs=True, env outputs normalized obs in [-1, 1] using fixed ranges.
      - Attack budgets (epsilon) should be defined in normalized space.
    """
    metadata = {"render.modes": []}

    def __init__(
        self,
        dt: float = 0.1,
        v_ref: float = 15.0,
        a_min: float = -3.5,
        a_max: float = 2.0,
        Th: float = 1.5,
        d0: float = 5.0,
        w_v: float = 0.5,
        w_s: float = 2.0,
        w_a: float = 0.01,
        lead_v0: float = 15.0,
        brake_profile: bool = False,
        brake_start_s: float = 5.0,
        brake_dur_s: float = 3.0,
        lead_decel: float = -2.0,
        episode_seconds: float = 20.0,
        seed: int | None = None,
        normalize_obs: bool = True,
        obs_clip: float = 1.0,
    ) -> None:
        super().__init__()
        self.dt = dt
        self.v_ref = v_ref
        self.a_min = a_min
        self.a_max = a_max
        self.Th = Th
        self.d0 = d0
        self.w_v = w_v
        self.w_s = w_s
        self.w_a = w_a
        self.lead_v0 = lead_v0
        self.brake_profile = brake_profile
        self.brake_start_s = brake_start_s
        self.brake_dur_s = brake_dur_s
        self.lead_decel = lead_decel
        self.episode_steps = int(episode_seconds / dt)
        self.normalize_obs = normalize_obs
        self.obs_clip = obs_clip

        self.np_random, _ = gym.utils.seeding.np_random(seed)

        # Observation space (normalized if normalize_obs=True)
        high = np.array([1.0, 1.0, 1.0], dtype=np.float32) if normalize_obs else np.array([np.inf, np.inf, np.inf], dtype=np.float32)
        self.observation_space = spaces.Box(low=-high, high=high, dtype=np.float32)

        # Action space in raw units (m/s^2)
        self.action_space = spaces.Box(
            low=np.array([self.a_min], dtype=np.float32),
            high=np.array([self.a_max], dtype=np.float32),
            dtype=np.float32,
        )

        # Normalization ranges for obs (hand-tuned for ACC task)
        # Δx in [0, 200] m -> map to [-1, 1]
        # Δv in [-20, 20] m/s -> map to [-1, 1]
        # v in [0, 30] m/s -> map to [-1, 1]
        self._x_range = (0.0, 200.0)
        self._dv_range = (-20.0, 20.0)
        self._v_range = (0.0, 30.0)

        self.reset()

    # ---------- Normalization helpers ----------
    def _norm(self, s_raw: np.ndarray) -> np.ndarray:
        Δx, Δv, v = s_raw
        def _scale(val, lo, hi):
            # map [lo,hi] -> [-1,1]
            val = (val - lo) / (hi - lo + 1e-8)
            return np.clip(2.0*val - 1.0, -self.obs_clip, self.obs_clip)
        return np.array([
            _scale(Δx, *self._x_range),
            _scale(Δv, *self._dv_range),
            _scale(v, *self._v_range),
        ], dtype=np.float32)

    def _denorm(self, s_norm: np.ndarray) -> np.ndarray:
        # Map [-1,1] back to raw
        def _inv(vn, lo, hi):
            x = (vn + 1.0) * 0.5 * (hi - lo) + lo
            return x
        Δx = _inv(s_norm[0], *self._x_range)
        Δv = _inv(s_norm[1], *self._dv_range)
        v  = _inv(s_norm[2], *self._v_range)
        return np.array([Δx, Δv, v], dtype=np.float32)

    # ---------- Safety filter ----------
    def _amax_safe(self, Δx: float, Δv: float, v: float) -> float:
        # Eq.(5): a_max_safe = (Δx - Th*v + Δv*dt) / (Th*dt)
        return (Δx - self.Th * v + Δv * self.dt) / (self.Th * self.dt + 1e-8)

    def _apply_safety(self, a_rl: float, Δx: float, Δv: float, v: float) -> float:
        a_safe_max = self._amax_safe(Δx, Δv, v)
        a_clamped = min(a_rl, a_safe_max)
        return float(np.clip(a_clamped, self.a_min, self.a_max))

    # ---------- Gym API ----------
    def reset(self, *, seed: int | None = None, options=None):
        if seed is not None:
            self.np_random, _ = gym.utils.seeding.np_random(seed)
        # Ego starts behind lead with ~30-50 m headway and near target speed with small noise
        self.x_e = 0.0
        self.v_e = float(np.clip(self.v_ref + self.np_random.normal(0, 0.5), 0.0, self._v_range[1]))
        self.a_prev = 0.0

        self.x_l = float(self.np_random.uniform(30.0, 50.0))
        self.v_l = self.lead_v0
        self._t = 0
        self._collision = False

        obs = self._get_obs()
        info = {}
        return obs, info

    def _lead_step(self):
        t = self._t * self.dt
        if self.brake_profile and (t >= self.brake_start_s) and (t < self.brake_start_s + self.brake_dur_s):
            self.v_l = max(self.v_l + self.lead_decel * self.dt, 0.0)
        # else constant

        self.x_l = self.x_l + self.v_l * self.dt

    def _get_obs(self) -> np.ndarray:
        Δx = self.x_l - self.x_e
        Δv = self.v_l - self.v_e
        s_raw = np.array([Δx, Δv, self.v_e], dtype=np.float32)
        if self.normalize_obs:
            return self._norm(s_raw)
        return s_raw

    def _reward(self) -> float:
        Δx = self.x_l - self.x_e
        Δv = self.v_l - self.v_e
        v  = self.v_e
        d_safe = self.d0 + self.Th * v
        r_speed = - self.w_v * (v - self.v_ref)**2
        r_safe  = - self.w_s * max(0.0, d_safe - Δx)**2
        r_act   = - self.w_a * (self.a_prev**2)
        return float(r_speed + r_safe + r_act)

    def step(self, action):
        a_rl = float(np.clip(action, self.a_min, self.a_max)[0])
        # Convert (possibly normalized obs) to raw for safety filter
        s = self._get_obs()
        if self.normalize_obs:
            s_raw = self._denorm(s)
        else:
            s_raw = s
        Δx, Δv, v = float(s_raw[0]), float(s_raw[1]), float(s_raw[2])

        a = self._apply_safety(a_rl, Δx, Δv, v)

        # Ego dynamics
        self.x_e = self.x_e + self.v_e * self.dt
        self.v_e = max(self.v_e + a * self.dt, 0.0)
        self.a_prev = a

        # Lead dynamics
        self._lead_step()

        # Check collision
        if (self.x_l - self.x_e) <= 0.0:
            self._collision = True

        obs = self._get_obs()
        reward = self._reward()
        self._t += 1
        terminated = self._collision
        truncated = self._t >= self.episode_steps
        info = {"collision": self._collision, "a": a, "v": self.v_e, "Δx": self.x_l - self.x_e}
        return obs, reward, terminated, truncated, info

# %%
import numpy as np
env = ACCEnv()                      # default: normalized observations
obs, info = env.reset()
print("reset obs:", obs, "info:", info)

for t in range(1000):
    action = np.array([0.5], dtype=np.float32)   # try accelerating
    obs, reward, terminated, truncated, info = env.step(action)
    print(f"t={t}: reward={reward:.3f}, term={terminated}, trunc={truncated}, info={info}")
# Out:
# reset obs: [-0.5977786  -0.04224424  0.05632566] info: {}
# t=0: reward=-0.403, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.894884798850839, 'Δx': 40.13765067854944}
# t=1: reward=-0.449, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.94488479885084, 'Δx': 40.04816219866436}
# t=2: reward=-0.497, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.99488479885084, 'Δx': 39.95367371877927}
# t=3: reward=-0.548, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.04488479885084, 'Δx': 39.85418523889419}
# t=4: reward=-0.602, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.094884798850842, 'Δx': 39.749696759009105}
# t=5: reward=-0.658, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.144884798850843, 'Δx': 39.64020827912402}
# t=6: reward=-0.716, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.194884798850843, 'Δx': 39.525719799238935}
# t=7: reward=-0.777, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.244884798850844, 'Δx': 39.40623131935385}
# t=8: reward=-0.841, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.294884798850845, 'Δx': 39.28174283946876}
# t=9: reward=-0.907, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.344884798850845, 'Δx': 39.15225435958368}
# t=10: reward=-0.975, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.394884798850846, 'Δx': 39.017765879698594}
# t=11: reward=-1.046, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.444884798850847, 'Δx': 38.87827739981351}
# t=12: reward=-1.120, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.494884798850848, 'Δx': 38.73378891992843}
# t=13: reward=-1.196, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.54488479885085, 'Δx': 38.584300440043336}
# t=14: reward=-1.274, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.59488479885085, 'Δx': 38.429811960158254}
# t=15: reward=-1.355, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.64488479885085, 'Δx': 38.27032348027316}
# t=16: reward=-1.439, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.69488479885085, 'Δx': 38.105835000388076}
# t=17: reward=-1.525, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.74488479885085, 'Δx': 37.936346520502994}
# t=18: reward=-1.613, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.794884798850852, 'Δx': 37.76185804061791}
# t=19: reward=-1.704, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.844884798850853, 'Δx': 37.58236956073282}
# t=20: reward=-1.798, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.894884798850853, 'Δx': 37.39788108084774}
# t=21: reward=-1.894, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.944884798850854, 'Δx': 37.208392600962654}
# t=22: reward=-1.992, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.994884798850855, 'Δx': 37.013904121077566}
# t=23: reward=-2.093, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.044884798850855, 'Δx': 36.81441564119248}
# t=24: reward=-2.197, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.094884798850856, 'Δx': 36.6099271613074}
# t=25: reward=-2.303, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.144884798850857, 'Δx': 36.40043868142231}
# t=26: reward=-2.411, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.194884798850858, 'Δx': 36.185950201537224}
# t=27: reward=-2.522, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.24488479885086, 'Δx': 35.96646172165214}
# t=28: reward=-2.636, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.29488479885086, 'Δx': 35.74197324176705}
# t=29: reward=-2.752, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.34488479885086, 'Δx': 35.512484761881964}
# t=30: reward=-2.870, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.39488479885086, 'Δx': 35.27799628199688}
# t=31: reward=-2.991, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.44488479885086, 'Δx': 35.038507802111795}
# t=32: reward=-3.115, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.494884798850862, 'Δx': 34.79401932222671}
# t=33: reward=-3.241, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.544884798850862, 'Δx': 34.54453084234162}
# t=34: reward=-3.369, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.594884798850863, 'Δx': 34.29004236245654}
# t=35: reward=-3.500, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.644884798850864, 'Δx': 34.03055388257145}
# t=36: reward=-3.634, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.694884798850865, 'Δx': 33.766065402686365}
# t=37: reward=-3.770, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.744884798850865, 'Δx': 33.49657692280128}
# t=38: reward=-3.908, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.794884798850866, 'Δx': 33.22208844291619}
# t=39: reward=-4.049, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.844884798850867, 'Δx': 32.9425999630311}
# t=40: reward=-4.193, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.894884798850867, 'Δx': 32.658111483146016}
# t=41: reward=-4.339, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.944884798850868, 'Δx': 32.36862300326092}
# t=42: reward=-4.487, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.99488479885087, 'Δx': 32.07413452337583}
# t=43: reward=-4.809, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 18.04488479885087, 'Δx': 31.774646043490748}
# t=44: reward=-5.695, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 18.09488479885087, 'Δx': 31.470157563605667}
# t=45: reward=-7.181, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 18.14488479885087, 'Δx': 31.160669083720578}
# t=46: reward=-9.289, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 18.19488479885087, 'Δx': 30.846180603835492}
# t=47: reward=-12.043, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 18.244884798850872, 'Δx': 30.52669212395041}
# t=48: reward=-15.467, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 18.294884798850873, 'Δx': 30.20220364406532}
# t=49: reward=-19.585, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 18.344884798850874, 'Δx': 29.872715164180235}
# t=50: reward=-24.420, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 18.394884798850875, 'Δx': 29.538226684295154}
# t=51: reward=-29.998, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 18.444884798850875, 'Δx': 29.198738204410063}
# t=52: reward=-36.344, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 18.494884798850876, 'Δx': 28.854249724524976}
# t=53: reward=-43.482, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 18.544884798850877, 'Δx': 28.504761244639894}
# t=54: reward=-51.438, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 18.594884798850877, 'Δx': 28.150272764754803}
# t=55: reward=-56.225, term=False, trunc=False, info={'collision': False, 'a': -0.6769561316274036, 'v': 18.527189185688137, 'Δx': 27.790784284869716}
# t=56: reward=-55.474, term=False, trunc=False, info={'collision': False, 'a': -2.3514529885815194, 'v': 18.292043886829983, 'Δx': 27.438065366300904}
# t=57: reward=-54.768, term=False, trunc=False, info={'collision': False, 'a': -2.194714717780738, 'v': 18.07257241505191, 'Δx': 27.10886097761791}
# t=58: reward=-54.154, term=False, trunc=False, info={'collision': False, 'a': -2.0483749931413744, 'v': 17.86773491573777, 'Δx': 26.801603736112725}
# t=59: reward=-53.619, term=False, trunc=False, info={'collision': False, 'a': -1.9118167874218492, 'v': 17.676553236995584, 'Δx': 26.514830244538942}
# t=60: reward=-53.152, term=False, trunc=False, info={'collision': False, 'a': -1.7843877874332295, 'v': 17.49811445825226, 'Δx': 26.247174920839385}
# t=61: reward=-52.746, term=False, trunc=False, info={'collision': False, 'a': -1.6653903804595702, 'v': 17.331575420206303, 'Δx': 25.997363475014154}
# t=62: reward=-52.392, term=False, trunc=False, info={'collision': False, 'a': -1.5543771343305868, 'v': 17.176137706773243, 'Δx': 25.76420593299352}
# t=63: reward=-52.084, term=False, trunc=False, info={'collision': False, 'a': -1.4507901496083746, 'v': 17.031058691812405, 'Δx': 25.546592162316202}
# t=64: reward=-51.815, term=False, trunc=False, info={'collision': False, 'a': -1.3540136706170247, 'v': 16.8956573247507, 'Δx': 25.34348629313496}
# t=65: reward=-51.581, term=False, trunc=False, info={'collision': False, 'a': -1.2637333027445212, 'v': 16.76928399447625, 'Δx': 25.153920560659884}
# t=66: reward=-51.377, term=False, trunc=False, info={'collision': False, 'a': -1.1795353103108457, 'v': 16.651330463445166, 'Δx': 24.976992161212266}
# t=67: reward=-51.200, term=False, trunc=False, info={'collision': False, 'a': -1.1009059807851416, 'v': 16.541239865366652, 'Δx': 24.811859114867744}
# t=68: reward=-51.045, term=False, trunc=False, info={'collision': False, 'a': -1.027518680735815, 'v': 16.43848799729307, 'Δx': 24.657735128331083}
# t=69: reward=-50.911, term=False, trunc=False, info={'collision': False, 'a': -0.9589537934916219, 'v': 16.342592617943907, 'Δx': 24.51388632860177}
# t=70: reward=-50.793, term=False, trunc=False, info={'collision': False, 'a': -0.8950552343665161, 'v': 16.253087094507254, 'Δx': 24.379627066807387}
# t=71: reward=-50.691, term=False, trunc=False, info={'collision': False, 'a': -0.8354103803004408, 'v': 16.16954605647721, 'Δx': 24.254318357356667}
# t=72: reward=-50.602, term=False, trunc=False, info={'collision': False, 'a': -0.7797163602452684, 'v': 16.091574420452684, 'Δx': 24.137363751708946}
# t=73: reward=-50.524, term=False, trunc=False, info={'collision': False, 'a': -0.7276844493209552, 'v': 16.01880597552059, 'Δx': 24.028206309663673}
# t=74: reward=-50.457, term=False, trunc=False, info={'collision': False, 'a': -0.679229373154728, 'v': 15.950883038205117, 'Δx': 23.926325712111606}
# t=75: reward=-50.398, term=False, trunc=False, info={'collision': False, 'a': -0.633931515075342, 'v': 15.887489886697582, 'Δx': 23.831237408291088}
# t=76: reward=-50.347, term=False, trunc=False, info={'collision': False, 'a': -0.5916567249045662, 'v': 15.828324214207125, 'Δx': 23.74248841962134}
# t=77: reward=-50.302, term=False, trunc=False, info={'collision': False, 'a': -0.5521874854399017, 'v': 15.773105465663136, 'Δx': 23.659655998200634}
# t=78: reward=-50.263, term=False, trunc=False, info={'collision': False, 'a': -0.5154036337254918, 'v': 15.721565102290587, 'Δx': 23.582345451634325}
# t=79: reward=-50.229, term=False, trunc=False, info={'collision': False, 'a': -0.48105610183563974, 'v': 15.673459492107023, 'Δx': 23.51018894140526}
# t=80: reward=-50.200, term=False, trunc=False, info={'collision': False, 'a': -0.44898248699237436, 'v': 15.628561243407786, 'Δx': 23.442842992194556}
# t=81: reward=-50.174, term=False, trunc=False, info={'collision': False, 'a': -0.41904716876965814, 'v': 15.58665652653082, 'Δx': 23.379986867853773}
# t=82: reward=-50.151, term=False, trunc=False, info={'collision': False, 'a': -0.3910852409946061, 'v': 15.547548002431359, 'Δx': 23.321321215200697}
# t=83: reward=-50.132, term=False, trunc=False, info={'collision': False, 'a': -0.3650510465123643, 'v': 15.511042897780122, 'Δx': 23.266566414957566}
# t=84: reward=-50.115, term=False, trunc=False, info={'collision': False, 'a': -0.34068570249971697, 'v': 15.47697432753015, 'Δx': 23.215462125179556}
# t=85: reward=-50.100, term=False, trunc=False, info={'collision': False, 'a': -0.31798289086473924, 'v': 15.445176038443677, 'Δx': 23.167764692426545}
# t=86: reward=-50.087, term=False, trunc=False, info={'collision': False, 'a': -0.29678082474408146, 'v': 15.415497955969268, 'Δx': 23.12324708858219}
# t=87: reward=-50.076, term=False, trunc=False, info={'collision': False, 'a': -0.2769954615942133, 'v': 15.387798409809847, 'Δx': 23.081697292985268}
# t=88: reward=-50.066, term=False, trunc=False, info={'collision': False, 'a': -0.2585449642433138, 'v': 15.361943913385515, 'Δx': 23.042917452004275}
# t=89: reward=-50.058, term=False, trunc=False, info={'collision': False, 'a': -0.24128955980870298, 'v': 15.337814957404644, 'Δx': 23.006723060665735}
# t=90: reward=-50.050, term=False, trunc=False, info={'collision': False, 'a': -0.22519406168409423, 'v': 15.315295551236234, 'Δx': 22.972941564925264}
# t=91: reward=-50.044, term=False, trunc=False, info={'collision': False, 'a': -0.21020021626721053, 'v': 15.294275529609513, 'Δx': 22.94141200980164}
# t=92: reward=-50.038, term=False, trunc=False, info={'collision': False, 'a': -0.19620274189418244, 'v': 15.274655255420095, 'Δx': 22.911984456840685}
# t=93: reward=-50.033, term=False, trunc=False, info={'collision': False, 'a': -0.183100310675647, 'v': 15.25634522435253, 'Δx': 22.884518931298686}
# t=94: reward=-50.029, term=False, trunc=False, info={'collision': False, 'a': -0.17089361799908023, 'v': 15.239255862552623, 'Δx': 22.858884408863446}
# t=95: reward=-50.025, term=False, trunc=False, info={'collision': False, 'a': -0.15951025416001482, 'v': 15.223304837136622, 'Δx': 22.834958822608172}
# t=96: reward=-50.022, term=False, trunc=False, info={'collision': False, 'a': -0.1488698820367568, 'v': 15.208417848932946, 'Δx': 22.812628338894513}
# t=97: reward=-50.019, term=False, trunc=False, info={'collision': False, 'a': -0.13892614908697598, 'v': 15.194525234024248, 'Δx': 22.79178655400122}
# t=98: reward=-50.017, term=False, trunc=False, info={'collision': False, 'a': -0.12970255940736192, 'v': 15.181554978083511, 'Δx': 22.772334030598785}
# t=99: reward=-50.015, term=False, trunc=False, info={'collision': False, 'a': -0.12101757713024604, 'v': 15.169453220370487, 'Δx': 22.754178532790434}
# t=100: reward=-50.013, term=False, trunc=False, info={'collision': False, 'a': -0.11296563587487192, 'v': 15.158156656783, 'Δx': 22.737233210753374}
# t=101: reward=-50.011, term=False, trunc=False, info={'collision': False, 'a': -0.10544094733792325, 'v': 15.147612562049208, 'Δx': 22.72141754507507}
# t=102: reward=-50.010, term=False, trunc=False, info={'collision': False, 'a': -0.09842425922042108, 'v': 15.137770136127166, 'Δx': 22.706656288870136}
# t=103: reward=-50.008, term=False, trunc=False, info={'collision': False, 'a': -0.09182768447950324, 'v': 15.128587367679216, 'Δx': 22.69287927525741}
# t=104: reward=-50.007, term=False, trunc=False, info={'collision': False, 'a': -0.08575669352706841, 'v': 15.12001169832651, 'Δx': 22.680020538489487}
# t=105: reward=-50.006, term=False, trunc=False, info={'collision': False, 'a': -0.07999190154853895, 'v': 15.112012508171656, 'Δx': 22.668019368656843}
# t=106: reward=-50.006, term=False, trunc=False, info={'collision': False, 'a': -0.07465593019120427, 'v': 15.104546915152536, 'Δx': 22.65681811783969}
# t=107: reward=-50.005, term=False, trunc=False, info={'collision': False, 'a': -0.06972019406274653, 'v': 15.097574895746261, 'Δx': 22.646363426324427}
# t=108: reward=-50.004, term=False, trunc=False, info={'collision': False, 'a': -0.06505310598448907, 'v': 15.091069585147812, 'Δx': 22.63660593674979}
# t=109: reward=-50.004, term=False, trunc=False, info={'collision': False, 'a': -0.06070987972202792, 'v': 15.084998597175609, 'Δx': 22.627498978234996}
# t=110: reward=-50.003, term=False, trunc=False, info={'collision': False, 'a': -0.05666891356012581, 'v': 15.079331705819596, 'Δx': 22.618999118517422}
# t=111: reward=-50.003, term=False, trunc=False, info={'collision': False, 'a': -0.05288461988267624, 'v': 15.074043243831328, 'Δx': 22.611065947935458}
# t=112: reward=-50.002, term=False, trunc=False, info={'collision': False, 'a': -0.0493367331118066, 'v': 15.069109570520148, 'Δx': 22.603661623552313}
# t=113: reward=-50.002, term=False, trunc=False, info={'collision': False, 'a': -0.04610166142997133, 'v': 15.06449940437715, 'Δx': 22.5967506665003}
# t=114: reward=-50.002, term=False, trunc=False, info={'collision': False, 'a': -0.04298370790025809, 'v': 15.060201033587123, 'Δx': 22.590300726062594}
# t=115: reward=-50.002, term=False, trunc=False, info={'collision': False, 'a': -0.040118130353806264, 'v': 15.056189220551742, 'Δx': 22.584280622703886}
# t=116: reward=-50.001, term=False, trunc=False, info={'collision': False, 'a': -0.0375008061362937, 'v': 15.052439139938112, 'Δx': 22.578661700648723}
# t=117: reward=-50.001, term=False, trunc=False, info={'collision': False, 'a': -0.034927636539981745, 'v': 15.048946376284114, 'Δx': 22.573417786654915}
# t=118: reward=-50.001, term=False, trunc=False, info={'collision': False, 'a': -0.03264363389146607, 'v': 15.045682012894968, 'Δx': 22.568523149026504}
# t=119: reward=-50.001, term=False, trunc=False, info={'collision': False, 'a': -0.03045149937911279, 'v': 15.042636862957057, 'Δx': 22.563954947737017}
# t=120: reward=-50.001, term=False, trunc=False, info={'collision': False, 'a': -0.028411863340250774, 'v': 15.039795676623031, 'Δx': 22.559691261441316}
# t=121: reward=-50.001, term=False, trunc=False, info={'collision': False, 'a': -0.026552705186683054, 'v': 15.037140406104363, 'Δx': 22.555711693779017}
# t=122: reward=-50.001, term=False, trunc=False, info={'collision': False, 'a': -0.024769808687494472, 'v': 15.034663425235614, 'Δx': 22.55199765316857}
# t=123: reward=-50.001, term=False, trunc=False, info={'collision': False, 'a': -0.02309941346429249, 'v': 15.032353483889185, 'Δx': 22.548531310645018}
# t=124: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.021553095235026142, 'v': 15.030198174365683, 'Δx': 22.54529596225609}
# t=125: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.02014165485731405, 'v': 15.028184008879952, 'Δx': 22.54227614481951}
# t=126: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.018798879025805574, 'v': 15.026304120977372, 'Δx': 22.539457743931507}
# t=127: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.01754244051649843, 'v': 15.024549876925722, 'Δx': 22.536827331833763}
# t=128: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.01634751399649869, 'v': 15.022915125526072, 'Δx': 22.53437234414119}
# t=129: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.015289467050573463, 'v': 15.021386178821015, 'Δx': 22.532080831588587}
# t=130: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.014241560344164631, 'v': 15.019962022786599, 'Δx': 22.529942213706477}
# t=131: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.013320731973708479, 'v': 15.018629949589227, 'Δx': 22.527946011427815}
# t=132: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.012423148171401659, 'v': 15.017387634772087, 'Δx': 22.526083016468903}
# t=133: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.011566327734586481, 'v': 15.016231001998628, 'Δx': 22.524344252991682}
# t=134: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.010823850108806009, 'v': 15.015148616987748, 'Δx': 22.52272115279183}
# t=135: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.010124511962687476, 'v': 15.014136165791479, 'Δx': 22.52120629109305}
# t=136: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.009427292264844104, 'v': 15.013193436564995, 'Δx': 22.519792674513894}
# t=137: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.008789269288541995, 'v': 15.012314509636141, 'Δx': 22.518473330857404}
# t=138: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.008193781053150358, 'v': 15.011495131530825, 'Δx': 22.51724187989379}
# t=139: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.007682497411406364, 'v': 15.010726881789685, 'Δx': 22.516092366740708}
# t=140: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00715125801174561, 'v': 15.01001175598851, 'Δx': 22.515019678561742}
# t=141: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.006642717425241847, 'v': 15.009347484245986, 'Δx': 22.514018502962898}
# t=142: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.006238017436239854, 'v': 15.008723682502362, 'Δx': 22.513083754538286}
# t=143: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.005806254456787168, 'v': 15.008143057056683, 'Δx': 22.512211386288044}
# t=144: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0054700333703679585, 'v': 15.007596053719647, 'Δx': 22.511397080582384}
# t=145: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.005035428305047876, 'v': 15.007092510889143, 'Δx': 22.510637475210416}
# t=146: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.004750595732224899, 'v': 15.00661745131592, 'Δx': 22.509928224121495}
# t=147: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.004414816092676627, 'v': 15.006175969706652, 'Δx': 22.5092664789899}
# t=148: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0041046006352155546, 'v': 15.00576550964313, 'Δx': 22.50864888201923}
# t=149: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.003824602867995944, 'v': 15.00538304935633, 'Δx': 22.508072331054905}
# t=150: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0036109550000954786, 'v': 15.005021953856321, 'Δx': 22.50753402611926}
# t=151: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.003328899010123182, 'v': 15.00468906395531, 'Δx': 22.507031830733638}
# t=152: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.003148298190257236, 'v': 15.004374234136284, 'Δx': 22.506562924338112}
# t=153: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.002893906825078726, 'v': 15.004084843453777, 'Δx': 22.506125500924497}
# t=154: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0027391269218725997, 'v': 15.00381093076159, 'Δx': 22.505717016579126}
# t=155: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0025279080983052244, 'v': 15.00355813995176, 'Δx': 22.50533592350297}
# t=156: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0023752753591517297, 'v': 15.003320612415845, 'Δx': 22.504980109507784}
# t=157: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0022201027482861542, 'v': 15.003098602141016, 'Δx': 22.504648048266205}
# t=158: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.002075274647008057, 'v': 15.002891074676315, 'Δx': 22.50433818805209}
# t=159: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0019401018766581682, 'v': 15.002697064488649, 'Δx': 22.50404908058448}
# t=160: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0017726148538707005, 'v': 15.002519803003262, 'Δx': 22.503779374135604}
# t=161: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0016735139118556005, 'v': 15.002352451612076, 'Δx': 22.50352739383527}
# t=162: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0015969144978452544, 'v': 15.002192760162291, 'Δx': 22.503292148674063}
# t=163: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0014395908424165783, 'v': 15.00204880107805, 'Δx': 22.50307287265781}
# t=164: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.001365870767174129, 'v': 15.001912214001333, 'Δx': 22.502867992550023}
# t=165: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.001271633656980703, 'v': 15.001785050635634, 'Δx': 22.50267677114988}
# t=166: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0011900369991987634, 'v': 15.001666046935714, 'Δx': 22.50249826608632}
# t=167: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0011011645395081228, 'v': 15.001555930481763, 'Δx': 22.50233166139276}
# t=168: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0010500059073520664, 'v': 15.001450929891027, 'Δx': 22.502176068344568}
# t=169: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0009513953066398121, 'v': 15.001355790360362, 'Δx': 22.502030975355467}
# t=170: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0009356526965493068, 'v': 15.001262225090708, 'Δx': 22.501895396319412}
# t=171: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0008160553638989245, 'v': 15.001180619554317, 'Δx': 22.501769173810317}
# t=172: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0007807251787249447, 'v': 15.001102547036444, 'Δx': 22.50165111185487}
# t=173: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0007350346514807736, 'v': 15.001029043571297, 'Δx': 22.501540857151213}
# t=174: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0007019269122625215, 'v': 15.000958850880071, 'Δx': 22.501437952794106}
# t=175: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0006360583126568289, 'v': 15.000895245048806, 'Δx': 22.501342067706105}
# t=176: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0006000122509115532, 'v': 15.000835243823715, 'Δx': 22.501252543201247}
# t=177: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0005441168736516781, 'v': 15.00078083213635, 'Δx': 22.50116901881887}
# t=178: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0005237369759406711, 'v': 15.000728458438756, 'Δx': 22.501090935605248}
# t=179: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00048564231510867266, 'v': 15.000679894207245, 'Δx': 22.501018089761374}
# t=180: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0004882341856610362, 'v': 15.000631070788678, 'Δx': 22.500950100340674}
# t=181: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00040164369895671567, 'v': 15.000590906418783, 'Δx': 22.500886993261815}
# t=182: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00040665658118549863, 'v': 15.000550240760663, 'Δx': 22.50082790261996}
# t=183: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00037636721791567754, 'v': 15.000512604038873, 'Δx': 22.5007728785439}
# t=184: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0003353814991741663, 'v': 15.000479065888955, 'Δx': 22.500721618140005}
# t=185: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00028759144114336876, 'v': 15.00045030674484, 'Δx': 22.500673711551087}
# t=186: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00030020781498739575, 'v': 15.000420285963342, 'Δx': 22.500628680876616}
# t=187: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0003024463650615692, 'v': 15.000390041326837, 'Δx': 22.500586652280276}
# t=188: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00024413630135733895, 'v': 15.0003656276967, 'Δx': 22.500547648147574}
# t=189: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0002596496896944486, 'v': 15.00033966272773, 'Δx': 22.500511085377923}
# t=190: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0002264451317399983, 'v': 15.000317018214556, 'Δx': 22.500477119105142}
# t=191: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00018591748785678404, 'v': 15.00029842646577, 'Δx': 22.500445417283686}
# t=192: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00023392235154458556, 'v': 15.000275034230615, 'Δx': 22.50041557463709}
# t=193: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0001706438180538885, 'v': 15.000257969848809, 'Δx': 22.500388071214047}
# t=194: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0001624464919215942, 'v': 15.000241725199617, 'Δx': 22.50036227422919}
# t=195: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0001706901901539914, 'v': 15.0002246561806, 'Δx': 22.500338101709247}
# t=196: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0001624897693145982, 'v': 15.000208407203669, 'Δx': 22.50031563609116}
# t=197: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00014212037808568564, 'v': 15.00019419516586, 'Δx': 22.50029479537079}
# t=198: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00011675111403933701, 'v': 15.000182520054457, 'Δx': 22.500275375854187}
# t=199: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -9.94309600279244e-05, 'v': 15.000172576958454, 'Δx': 22.50025712384877}
# t=200: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -0.00011187570859518974, 'v': 15.000161389387594, 'Δx': 22.500239866152924}
# t=201: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -0.00011713299507457789, 'v': 15.000149676088087, 'Δx': 22.500223727214177}
# t=202: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -0.0001093241274427692, 'v': 15.000138743675343, 'Δx': 22.500208759605357}
# t=203: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -0.00010203585939418713, 'v': 15.000128540089404, 'Δx': 22.500194885237818}
# t=204: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -8.887564170922503e-05, 'v': 15.000119652525234, 'Δx': 22.50018203122886}
# t=205: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -6.387710708115736e-05, 'v': 15.000113264814525, 'Δx': 22.500170065976363}
# t=206: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.869211994918556e-05, 'v': 15.00010539560253, 'Δx': 22.500158739494907}
# t=207: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -8.616163694049212e-05, 'v': 15.000096779438836, 'Δx': 22.500148199934642}
# t=208: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -2.319707070119276e-05, 'v': 15.000094459731766, 'Δx': 22.500138521990777}
# t=209: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.887105513754297e-05, 'v': 15.000086572626252, 'Δx': 22.50012907601763}
# t=210: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.361298770542296e-05, 'v': 15.000079211327481, 'Δx': 22.50012041875499}
# t=211: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.055848152147484e-05, 'v': 15.000076155479329, 'Δx': 22.50011249762224}
# t=212: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.620496012118627e-05, 'v': 15.000068534983317, 'Δx': 22.50010488207431}
# t=213: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.569331636107062e-05, 'v': 15.00006396565168, 'Δx': 22.500098028575962}
# t=214: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.311035371218053e-05, 'v': 15.000060654616309, 'Δx': 22.50009163201082}
# t=215: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.043974304513736e-05, 'v': 15.000056610642005, 'Δx': 22.500085566549217}
# t=216: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -2.820701829393361e-05, 'v': 15.000053789940177, 'Δx': 22.500079905484995}
# t=217: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.586328970219231e-05, 'v': 15.000050203611206, 'Δx': 22.500074526491005}
# t=218: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.300915029252423e-05, 'v': 15.000045902696177, 'Δx': 22.500069506129876}
# t=219: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.060512768262962e-05, 'v': 15.00004284218341, 'Δx': 22.500064915860264}
# t=220: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -5.081718846522019e-05, 'v': 15.000037760464563, 'Δx': 22.50006063164193}
# t=221: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.5434078272454607e-07, 'v': 15.000037785898641, 'Δx': 22.50005685559546}
# t=222: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.790958716114304e-05, 'v': 15.000033994939924, 'Δx': 22.50005307700559}
# t=223: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.7646890860943535e-06, 'v': 15.000034271408833, 'Δx': 22.500049677511583}
# t=224: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.5566595573019157e-05, 'v': 15.000030714749276, 'Δx': 22.5000462503707}
# t=225: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.319548968654836e-05, 'v': 15.000027395200307, 'Δx': 22.500043178895794}
# t=226: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -2.3722288091877293e-06, 'v': 15.000027157977426, 'Δx': 22.500040439375766}
# t=227: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.08243074025277e-05, 'v': 15.000024075546685, 'Δx': 22.500037723578032}
# t=228: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -1.5912639507336867e-07, 'v': 15.000024059634045, 'Δx': 22.500035316023343}
# t=229: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -1.4851683691959187e-07, 'v': 15.00002404478236, 'Δx': 22.50003291005993}
# t=230: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.8285586797704554e-05, 'v': 15.000020216223682, 'Δx': 22.50003050558172}
# t=231: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.413755121842657e-06, 'v': 15.000020457599193, 'Δx': 22.50002848395934}
# t=232: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.589413005914361e-05, 'v': 15.000016868186188, 'Δx': 22.500026438199427}
# t=233: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.890961440489326e-06, 'v': 15.000016379090043, 'Δx': 22.500024751380806}
# t=234: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.9718446179151835e-06, 'v': 15.000016876274506, 'Δx': 22.500023113471798}
# t=235: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.3043324250500176e-05, 'v': 15.000012571942081, 'Δx': 22.500021425844352}
# t=236: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 7.509942815445692e-06, 'v': 15.000013322936363, 'Δx': 22.500020168650167}
# t=237: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -2.5274613545374963e-06, 'v': 15.000013070190228, 'Δx': 22.500018836356503}
# t=238: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -2.3589647393413453e-06, 'v': 15.000012834293754, 'Δx': 22.50001752933747}
# t=239: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.08119273614725e-05, 'v': 15.000009753101018, 'Δx': 22.500016245908114}
# t=240: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -1.4757156882256483e-07, 'v': 15.000009738343861, 'Δx': 22.500015270598}
# t=241: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -1.3773386845423434e-07, 'v': 15.000009724570475, 'Δx': 22.500014296763595}
# t=242: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -1.2855100422752463e-07, 'v': 15.000009711715375, 'Δx': 22.500013324306565}
# t=243: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -1.1998113938894381e-07, 'v': 15.00000969971726, 'Δx': 22.500012353135048}
# t=244: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -1.119830435147585e-07, 'v': 15.000009688518956, 'Δx': 22.500011383163326}
# t=245: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -1.0451669884076081e-07, 'v': 15.000009678067286, 'Δx': 22.50001041431142}
# t=246: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -5.096017618105141e-05, 'v': 15.000004582049668, 'Δx': 22.50000944650469}
# t=247: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 1.2088123591879134e-07, 'v': 15.000004594137792, 'Δx': 22.500008988299726}
# t=248: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 1.128225070685304e-07, 'v': 15.000004605420044, 'Δx': 22.500008528885928}
# t=249: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 1.0530098638630298e-07, 'v': 15.000004615950143, 'Δx': 22.500008068343902}
# t=250: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 9.828090041622414e-08, 'v': 15.000004625778233, 'Δx': 22.50000760674891}
# t=251: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 9.172890102145207e-08, 'v': 15.000004634951123, 'Δx': 22.500007144171093}
# t=252: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 8.561376221930748e-08, 'v': 15.000004643512499, 'Δx': 22.500006680675995}
# t=253: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 7.990607701639332e-08, 'v': 15.000004651503106, 'Δx': 22.50000621632472}
# t=254: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 7.457886373835637e-08, 'v': 15.000004658960993, 'Δx': 22.5000057511744}
# t=255: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 6.960695970012464e-08, 'v': 15.000004665921688, 'Δx': 22.50000528527829}
# t=256: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 6.496671804102867e-08, 'v': 15.00000467241836, 'Δx': 22.500004818686136}
# t=257: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 6.063540139503964e-08, 'v': 15.0000046784819, 'Δx': 22.500004351444318}
# t=258: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.809037680907372e-05, 'v': 15.00000086944422, 'Δx': 22.50000388359615}
# t=259: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.5959514169226914e-06, 'v': 15.000001129039362, 'Δx': 22.500003796651754}
# t=260: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.422887963864105e-06, 'v': 15.000001371328159, 'Δx': 22.50000368374782}
# t=261: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.26136217034497e-06, 'v': 15.000001597464376, 'Δx': 22.500003546615005}
# t=262: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.426137810693952e-06, 'v': 15.000000854850596, 'Δx': 22.50000338686857}
# t=263: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.6056804705770153e-06, 'v': 15.000001115418643, 'Δx': 22.500003301383515}
# t=264: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.4319685099436864e-06, 'v': 15.000001358615494, 'Δx': 22.500003189841664}
# t=265: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.2698372203672123e-06, 'v': 15.000001585599216, 'Δx': 22.500003053980095}
# t=266: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.418227784217518e-06, 'v': 15.000000843776437, 'Δx': 22.500002895420153}
# t=267: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.613063293326469e-06, 'v': 15.000001105082767, 'Δx': 22.50000281104252}
# t=268: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.438859068718623e-06, 'v': 15.000001348968674, 'Δx': 22.500002700534253}
# t=269: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.2762684085571536e-06, 'v': 15.000001576595514, 'Δx': 22.500002565637374}
# t=270: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.412225271168433e-06, 'v': 15.000000835372987, 'Δx': 22.50000240797783}
# t=271: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.618665552942231e-06, 'v': 15.000001097239542, 'Δx': 22.500002324440516}
# t=272: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.444087904992977e-06, 'v': 15.000001341648332, 'Δx': 22.500002214716574}
# t=273: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.2811486052190703e-06, 'v': 15.000001569763192, 'Δx': 22.500002080551724}
# t=274: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.407670446214385e-06, 'v': 15.000000828996148, 'Δx': 22.500001923575383}
# t=275: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.622916796164189e-06, 'v': 15.000001091287828, 'Δx': 22.500001840675793}
# t=276: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.4480557269473903e-06, 'v': 15.000001336093401, 'Δx': 22.500001731547002}
# t=277: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.284851991606572e-06, 'v': 15.0000015645786, 'Δx': 22.500001597937683}
# t=278: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.4042140634131726e-06, 'v': 15.000000824157194, 'Δx': 22.50000144147981}
# t=279: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.6261427357607028e-06, 'v': 15.000001086771467, 'Δx': 22.500001359064072}
# t=280: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.4510665331656637e-06, 'v': 15.00000133187812, 'Δx': 22.5000012503869}
# t=281: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.287662102674034e-06, 'v': 15.00000156064433, 'Δx': 22.500001117199076}
# t=282: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.401591232450566e-06, 'v': 15.000000820485207, 'Δx': 22.500000961134617}
# t=283: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.6285907542741607e-06, 'v': 15.000001083344282, 'Δx': 22.500000879086087}
# t=284: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.4533513352866477e-06, 'v': 15.000001328679415, 'Δx': 22.500000770751683}
# t=285: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.2897945644426267e-06, 'v': 15.000001557658871, 'Δx': 22.500000637883716}
# t=286: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.39960080342843e-06, 'v': 15.00000081769879, 'Δx': 22.500000482117855}
# t=287: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.6304483591830794e-06, 'v': 15.000001080743626, 'Δx': 22.50000040034797}
# t=288: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.455085211028761e-06, 'v': 15.000001326252148, 'Δx': 22.500000292273626}
# t=289: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.2914127827828755e-06, 'v': 15.000001555393427, 'Δx': 22.500000159648437}
# t=290: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.398090511785597e-06, 'v': 15.000000815584375, 'Δx': 22.500000004109097}
# t=291: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.631858000085626e-06, 'v': 15.000001078770175, 'Δx': 22.49999992255067}
# t=292: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.4564007192359496e-06, 'v': 15.000001324410247, 'Δx': 22.49999981467363}
# t=293: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.292640752130854e-06, 'v': 15.000001553674322, 'Δx': 22.499999682232612}
# t=294: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.3969445485377606e-06, 'v': 15.000000813979867, 'Δx': 22.499999526865167}
# t=295: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.632927641574827e-06, 'v': 15.00000107727263, 'Δx': 22.499999445467154}
# t=296: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.457399116978261e-06, 'v': 15.000001323012542, 'Δx': 22.499999337739894}
# t=297: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.2935726051819223e-06, 'v': 15.000001552369802, 'Δx': 22.499999205438655}
# t=298: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.396074844287171e-06, 'v': 15.000000812762318, 'Δx': 22.499999050201666}
# t=299: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.6337392897508244e-06, 'v': 15.000001076136247, 'Δx': 22.49999896892541}
# t=300: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.568881346289555e-05, 'v': 14.9999975072549, 'Δx': 22.49999886131178}
# t=301: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.837410850766326e-06, 'v': 14.999997990995984, 'Δx': 22.499999110586316}
# t=302: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 3.312514421719962e-05, 'v': 15.000001303510405, 'Δx': 22.499999311486704}
# t=303: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.306573906868238e-06, 'v': 15.000001534167795, 'Δx': 22.49999918113565}
# t=304: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.383940215202642e-06, 'v': 15.000000795773774, 'Δx': 22.499999027718843}
# t=305: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.550190507607976e-05, 'v': 14.999997245583266, 'Δx': 22.499998948141467}
# t=306: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 5.011858440981897e-06, 'v': 14.999997746769111, 'Δx': 22.49999922358313}
# t=307: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 3.328796225102138e-05, 'v': 15.000001075565336, 'Δx': 22.499999448906237}
# t=308: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.4585372737304277e-06, 'v': 15.000001321419063, 'Δx': 22.499999341349678}
# t=309: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.294634894922774e-06, 'v': 15.000001550882553, 'Δx': 22.499999209207772}
# t=310: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.395083343545889e-06, 'v': 15.00000081137422, 'Δx': 22.49999905411954}
# t=311: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.6346647005481843e-06, 'v': 15.00000107484069, 'Δx': 22.499998972982098}
# t=312: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.568794967036012e-05, 'v': 14.999997506045723, 'Δx': 22.499998865498014}
# t=313: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.838216814600816e-06, 'v': 14.999997989867405, 'Δx': 22.499999114893455}
# t=314: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 3.312589682401517e-05, 'v': 15.000001302457086, 'Δx': 22.499999315906734}
# t=315: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3072761125224182e-06, 'v': 15.000001533184697, 'Δx': 22.49999918566101}
# t=316: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.38328469694004e-06, 'v': 15.000000794856227, 'Δx': 22.499999032342544}
# t=317: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.550129340303799e-05, 'v': 14.999997244726886, 'Δx': 22.499998952856913}
# t=318: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 5.012429452034092e-06, 'v': 14.999997745969832, 'Δx': 22.49999922838424}
# t=319: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 3.328849521488109e-05, 'v': 15.000001074819354, 'Δx': 22.499999453787268}
# t=320: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.459034691507911e-06, 'v': 15.000001320722824, 'Δx': 22.499999346305344}
# t=321: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.2950990403546355e-06, 'v': 15.000001550232728, 'Δx': 22.49999921423307}
# ...
# t=895: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3314681394382e-06, 'v': 15.000001499315974, 'Δx': 22.499998948019538}
# t=896: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.550767577188897e-05, 'v': 14.999996948548397, 'Δx': 22.499998798087972}
# t=897: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 5.2098817997026575e-06, 'v': 14.999997469536577, 'Δx': 22.499999103233222}
# t=898: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.300952652014078e-05, 'v': 15.000001770489229, 'Δx': 22.49999935627966}
# t=899: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.541487803370211e-06, 'v': 15.000001016340448, 'Δx': 22.499999179230826}
# t=900: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.4980205582564755e-06, 'v': 15.000001266142505, 'Δx': 22.49999907759684}
# t=901: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3314858745837025e-06, 'v': 15.000001499291091, 'Δx': 22.499998950982672}
# t=902: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.5507659173611775e-05, 'v': 14.999996948525174, 'Δx': 22.499998801053607}
# t=903: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 5.209897261111556e-06, 'v': 14.9999974695149, 'Δx': 22.49999910620113}
# t=904: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.30095409204726e-05, 'v': 15.000001770468993, 'Δx': 22.499999359249614}
# t=905: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.5414742367418135e-06, 'v': 15.00000101632157, 'Δx': 22.499999182202828}
# t=906: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.4980332153902314e-06, 'v': 15.00000126612489, 'Δx': 22.49999908057066}
# t=907: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3314976980140374e-06, 'v': 15.00000149927466, 'Δx': 22.499998953958084}
# t=908: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.550764818388486e-05, 'v': 14.99999694850984, 'Δx': 22.49999880403061}
# t=909: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 5.20990756871749e-06, 'v': 14.999997469500597, 'Δx': 22.499999109179726}
# t=910: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.3009550470166324e-05, 'v': 15.000001770455643, 'Δx': 22.499999362229573}
# t=911: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.541465444960282e-06, 'v': 15.000001016309099, 'Δx': 22.499999185183924}
# t=912: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.498041552424442e-06, 'v': 15.000001266113255, 'Δx': 22.49999908355312}
# t=913: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.331505428718487e-06, 'v': 15.000001499263798, 'Δx': 22.49999895694191}
# t=914: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.550764098371895e-05, 'v': 14.9999969484997, 'Δx': 22.499998807015572}
# t=915: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 5.209914238344858e-06, 'v': 14.999997469491124, 'Δx': 22.499999112165597}
# t=916: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.3009556836628816e-05, 'v': 15.000001770446808, 'Δx': 22.49999936521658}
# t=917: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.541459457453895e-06, 'v': 15.000001016300862, 'Δx': 22.49999918817184}
# t=918: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.498046933601069e-06, 'v': 15.000001266105555, 'Δx': 22.49999908654172}
# t=919: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3315105825214535e-06, 'v': 15.000001499256612, 'Δx': 22.49999895993119}
# t=920: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.5507636133080866e-05, 'v': 14.999996948493, 'Δx': 22.499998810005536}
# t=921: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 5.209918785818063e-06, 'v': 14.999997469484878, 'Δx': 22.499999115156243}
# t=922: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.300956077777226e-05, 'v': 15.000001770440957, 'Δx': 22.499999368207682}
# t=923: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.54145559210167e-06, 'v': 15.000001016295398, 'Δx': 22.499999191163624}
# t=924: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.4980506473708535e-06, 'v': 15.000001266100464, 'Δx': 22.499999089534185}
# t=925: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.331513917335138e-06, 'v': 15.000001499251855, 'Δx': 22.49999896292411}
# t=926: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.550763302564084e-05, 'v': 14.999996948488553, 'Δx': 22.49999881299891}
# t=927: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 5.209921665884428e-06, 'v': 14.99999746948072, 'Δx': 22.499999118150072}
# t=928: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.3009563657838626e-05, 'v': 15.000001770437086, 'Δx': 22.499999371201966}
# t=929: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.541453015200186e-06, 'v': 15.000001016291785, 'Δx': 22.499999194158363}
# t=930: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.4980529968986766e-06, 'v': 15.000001266097085, 'Δx': 22.49999909252915}
# t=931: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.33151611528052e-06, 'v': 15.000001499248697, 'Δx': 22.49999896591953}
# t=932: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.5507630827695456e-05, 'v': 14.999996948485615, 'Δx': 22.49999881599456}
# t=933: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 5.209923484873709e-06, 'v': 14.999997469477963, 'Δx': 22.499999121145947}
# t=934: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.300956562841034e-05, 'v': 15.000001770434526, 'Δx': 22.49999937419807}
# t=935: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.541451347793345e-06, 'v': 15.000001016289392, 'Δx': 22.499999197154693}
# t=936: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.498054664305518e-06, 'v': 15.00000126609486, 'Δx': 22.49999909552571}
# t=937: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.331517631104922e-06, 'v': 15.000001499246622, 'Δx': 22.499998968916316}
# t=938: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.550762953924471e-05, 'v': 14.999996948483668, 'Δx': 22.49999881899157}
# t=939: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 5.209925000698111e-06, 'v': 14.999997469476169, 'Δx': 22.499999124143187}
# t=940: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.300956668948743e-05, 'v': 15.000001770432837, 'Δx': 22.499999377195536}
# t=941: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.5414501351338225e-06, 'v': 15.000001016287824, 'Δx': 22.49999920015216}
# t=942: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.4980557253825993e-06, 'v': 15.000001266093395, 'Δx': 22.499999098523404}
# t=943: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3315186921820037e-06, 'v': 15.000001499245265, 'Δx': 22.49999897191401}
# t=944: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.550762855395886e-05, 'v': 14.99999694848241, 'Δx': 22.499998821989493}
# t=945: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 5.209925758610312e-06, 'v': 14.999997469474986, 'Δx': 22.499999127141336}
# t=946: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.300956744739963e-05, 'v': 15.00000177043173, 'Δx': 22.499999380193913}
# t=947: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.541449377221621e-06, 'v': 15.000001016286792, 'Δx': 22.499999203150765}
# t=948: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.4980563317123606e-06, 'v': 15.000001266092426, 'Δx': 22.499999101522008}
# t=949: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3315192227205443e-06, 'v': 15.000001499244348, 'Δx': 22.49999897491284}
# t=950: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.550762802342031e-05, 'v': 14.999996948481545, 'Δx': 22.499998824988324}
# t=951: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 5.209926364940073e-06, 'v': 14.999997469474181, 'Δx': 22.499999130140168}
# t=952: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.300956805372939e-05, 'v': 15.000001770430986, 'Δx': 22.499999383192744}
# t=953: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.541448922474301e-06, 'v': 15.000001016286094, 'Δx': 22.499999206149596}
# t=954: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.498056786459681e-06, 'v': 15.000001266091772, 'Δx': 22.499999104521066}
# t=955: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.331519753259085e-06, 'v': 15.000001499243748, 'Δx': 22.4999989779119}
# t=956: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.550762756867299e-05, 'v': 14.999996948480991, 'Δx': 22.49999882798761}
# t=957: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 5.209926668104954e-06, 'v': 14.999997469473659, 'Δx': 22.499999133139454}
# t=958: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.300956835689427e-05, 'v': 15.000001770430494, 'Δx': 22.49999938619203}
# t=959: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.5414485435182e-06, 'v': 15.000001016285639, 'Δx': 22.499999209148882}
# t=960: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.4980570896245614e-06, 'v': 15.000001266091347, 'Δx': 22.499999107520352}
# t=961: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3315199806327456e-06, 'v': 15.000001499243345, 'Δx': 22.499998980911187}
# t=962: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.5507627341299334e-05, 'v': 14.99999694848061, 'Δx': 22.499998830986897}
# t=963: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 5.209926971269835e-06, 'v': 14.999997469473309, 'Δx': 22.49999913613874}
# t=964: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.300956866005915e-05, 'v': 15.000001770430174, 'Δx': 22.499999389191316}
# t=965: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.541448391935761e-06, 'v': 15.000001016285335, 'Δx': 22.499999212148396}
# t=966: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.4980573169982216e-06, 'v': 15.000001266091067, 'Δx': 22.499999110519866}
# t=967: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3315202080064058e-06, 'v': 15.000001499243087, 'Δx': 22.4999989839107}
# t=968: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.550762711392567e-05, 'v': 14.999996948480376, 'Δx': 22.49999883398641}
# t=969: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 5.209927122852274e-06, 'v': 14.999997469473088, 'Δx': 22.49999913913848}
# t=970: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.300956881164159e-05, 'v': 15.00000177042997, 'Δx': 22.499999392191285}
# t=971: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.541448316144541e-06, 'v': 15.000001016285138, 'Δx': 22.499999215148364}
# t=972: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.498057468580662e-06, 'v': 15.000001266090885, 'Δx': 22.499999113519834}
# t=973: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3315202837976255e-06, 'v': 15.000001499242915, 'Δx': 22.49999898691067}
# t=974: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.550762696234323e-05, 'v': 14.999996948480218, 'Δx': 22.49999883698638}
# t=975: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 5.209927274434714e-06, 'v': 14.999997469472946, 'Δx': 22.49999914213845}
# t=976: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.3009568963224036e-05, 'v': 15.000001770429842, 'Δx': 22.499999395191253}
# t=977: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.5414481645621005e-06, 'v': 15.000001016285026, 'Δx': 22.499999218148332}
# t=978: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.498057468580662e-06, 'v': 15.000001266090774, 'Δx': 22.499999116519803}
# t=979: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3315204353800655e-06, 'v': 15.000001499242817, 'Δx': 22.499998989910637}
# t=980: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.550762696234323e-05, 'v': 14.99999694848012, 'Δx': 22.499998839986347}
# t=981: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 5.209927274434714e-06, 'v': 14.999997469472849, 'Δx': 22.499999145138418}
# t=982: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.3009568963224036e-05, 'v': 15.000001770429744, 'Δx': 22.49999939819122}
# t=983: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.541448088770881e-06, 'v': 15.000001016284935, 'Δx': 22.4999992211483}
# t=984: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.498057544371882e-06, 'v': 15.00000126609069, 'Δx': 22.49999911951977}
# t=985: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3315205111712857e-06, 'v': 15.00000149924274, 'Δx': 22.499998992910605}
# t=986: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.550762696234323e-05, 'v': 14.999996948480044, 'Δx': 22.499998842986315}
# t=987: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 5.209927274434714e-06, 'v': 14.999997469472772, 'Δx': 22.499999148138386}
# t=988: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.3009568963224036e-05, 'v': 15.000001770429668, 'Δx': 22.49999940119119}
# t=989: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.541448088770881e-06, 'v': 15.000001016284859, 'Δx': 22.49999922414827}
# t=990: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.498057695954322e-06, 'v': 15.000001266090628, 'Δx': 22.49999912251974}
# t=991: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3315205111712857e-06, 'v': 15.000001499242678, 'Δx': 22.499998995910573}
# t=992: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.550762688655201e-05, 'v': 14.999996948479989, 'Δx': 22.499998845986283}
# t=993: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 5.209927274434714e-06, 'v': 14.999997469472717, 'Δx': 22.499999151138354}
# t=994: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.3009568963224036e-05, 'v': 15.000001770429613, 'Δx': 22.499999404191158}
# t=995: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.541448088770881e-06, 'v': 15.000001016284804, 'Δx': 22.499999227148237}
# t=996: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.498057695954322e-06, 'v': 15.000001266090573, 'Δx': 22.499999125519707}
# t=997: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.331520586962506e-06, 'v': 15.000001499242632, 'Δx': 22.49999899891054}
# t=998: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.550762688655201e-05, 'v': 14.999996948479943, 'Δx': 22.49999884898625}
# t=999: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 5.209927274434714e-06, 'v': 14.999997469472671, 'Δx': 22.499999154138322}
