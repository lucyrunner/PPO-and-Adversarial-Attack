# %%
# One-cell train + save + smoke-check for ACCEnv + PPO (robust reset/step handling)

from __future__ import annotations
import os, sys, subprocess, shlex
from IPython import get_ipython

# 1) Ensure ACCEnv is importable
NOTEBOOK = "acc_env.ipynb"
try:
    from acc_env import ACCEnv  # prefer acc_env.py if present
    print("Imported ACCEnv from acc_env.py")
except Exception:
    if os.path.exists(NOTEBOOK):
        print("Converting acc_env.ipynb -> acc_env.py ...")
        subprocess.run(shlex.split(f"jupyter nbconvert --to python {NOTEBOOK}"), check=True)
        if os.getcwd() not in sys.path:
            sys.path.append(os.getcwd())
        from acc_env import ACCEnv
        print("Imported ACCEnv from converted acc_env.py")
    else:
        print("No acc_env.py found; running acc_env.ipynb ...")
        get_ipython().run_line_magic("run", f"./{NOTEBOOK}")
        if "ACCEnv" in globals():
            print("ACCEnv defined by running acc_env.ipynb")
        else:
            raise FileNotFoundError("ACCEnv not found. Put acc_env.py or acc_env.ipynb in this folder.")

# 2) Imports for training
import numpy as np
import matplotlib.pyplot as plt
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.logger import configure

# 3) Hyperparameters & paths
LOGDIR = "runs/ppo_baseline"
os.makedirs(LOGDIR, exist_ok=True)
TOTAL_TIMESTEPS = 200_000
SEED = 42
N_ENVS = 1

PPO_PARAMS = dict(
    policy="MlpPolicy",
    verbose=1,
    seed=SEED,
    n_steps=1024,
    batch_size=128,
    learning_rate=3e-4,
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    ent_coef=0.0,
)

# 4) Env factory
def make_env(seed=0, brake_profile=True, normalize_obs=True):
    def _thunk():
        return ACCEnv(brake_profile=brake_profile, normalize_obs=normalize_obs, seed=seed)
    return _thunk

# 5) Create vectorized normalized training env
base_env = DummyVecEnv([make_env(seed=SEED, brake_profile=False, normalize_obs=True) for _ in range(N_ENVS)])
train_env = VecNormalize(base_env, norm_obs=True, norm_reward=True, clip_obs=1.0)
print("Train env created. obs_space:", train_env.observation_space, "act_space:", train_env.action_space)

# 6) Create model, set logger, train
model = PPO(**PPO_PARAMS, env=train_env)
model.set_logger(configure(LOGDIR, ["stdout", "csv", "tensorboard"]))
print(f"Starting training for {TOTAL_TIMESTEPS} timesteps ...")
model.learn(total_timesteps=TOTAL_TIMESTEPS)
print("Training finished.")

# 7) Save model + VecNormalize
model_path = os.path.join(LOGDIR, "ppo_acc")
vec_path = os.path.join(LOGDIR, "vecnormalize.pkl")
model.save(model_path)        # writes ppo_acc.zip
train_env.save(vec_path)      # writes vecnormalize.pkl
print("Saved model ->", model_path + ".zip")
print("Saved VecNormalize ->", vec_path)

# --------------------- Smoke-check (fixed) ---------------------

# Robust wrappers for reset/step across gym/sb3 versions
def reset_unwrap(env, **kwargs):
    out = env.reset(**kwargs)
    if isinstance(out, tuple) and len(out) == 2:
        obs, _info = out
        return obs
    return out  # obs only

def step_unwrap(env, action):
    out = env.step(action)
    if len(out) == 5:
        obs, reward, terminated, truncated, info = out
        return obs, reward, bool(terminated), bool(truncated), info
    elif len(out) == 4:
        obs, reward, done, info = out
        return obs, reward, bool(done), False, info
    else:
        raise RuntimeError(f"Unexpected env.step() return length: {len(out)}")

# Build an evaluation env that uses the saved normalization stats
eval_base = DummyVecEnv([make_env(seed=123, brake_profile=True, normalize_obs=True)])
eval_env = VecNormalize.load(vec_path, eval_base)
eval_env.training = False
eval_env.norm_reward = False

# load saved model, bound to eval_env
model_loaded = PPO.load(model_path + ".zip", env=eval_env)
print("Loaded model and VecNormalize for evaluation.")

def run_eval_episode(mdl, env, max_steps=1000):
    obs = reset_unwrap(env)
    total_r = 0.0
    collided = False
    steps = 0
    while True:
        action, _ = mdl.predict(obs, deterministic=True)
        obs, r, term, trunc, info = step_unwrap(env, action)
        total_r += float(r[0]) if hasattr(r, "__len__") else float(r)
        steps += 1
        idict = info if isinstance(info, dict) else (info[0] if hasattr(info, "__len__") and len(info) else {})
        if idict.get("collision", False):
            collided = True
        if term or trunc or (steps >= max_steps):
            break
    return total_r, collided, steps

print("Running 3 smoke-check episodes ...")
for i in range(3):
    ret, coll, steps = run_eval_episode(model_loaded, eval_env)
    print(f"Episode {i}: return={ret:.3f}, collision={coll}, steps={steps}")

# Optional: quick plot of training CSV if available
csv_path = os.path.join(LOGDIR, "progress.csv")
if os.path.exists(csv_path):
    try:
        import pandas as pd
        df = pd.read_csv(csv_path)
        if 'rollout/ep_rew_mean' in df.columns:
            plt.figure(figsize=(8,3))
            plt.plot(df['rollout/ep_rew_mean'])
            plt.title("rollout/ep_rew_mean during training")
            plt.xlabel("logging step")
            plt.ylabel("mean episode reward")
            plt.show()
    except Exception:
        pass

print("\nDone. You now have:")
print(" -", model_path + ".zip")
print(" -", vec_path)
print("These artifacts will be loaded by your attacks notebook.")
# Out:
# Imported ACCEnv from acc_env.py
# Train env created. obs_space: Box(-1.0, 1.0, (3,), float32) act_space: Box(-3.5, 2.0, (1,), float32)
# Using cpu device
# Logging to runs/ppo_baseline
# Starting training for 200000 timesteps ...
# -----------------------------
# | time/              |      |
# |    fps             | 1757 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 1024 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1460         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0038024038 |
# |    clip_fraction        | 0.0116       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.165        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.62         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00378     |
# |    std                  | 0.994        |
# |    value_loss           | 3.74         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1380        |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.006297222 |
# |    clip_fraction        | 0.044       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.747       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0986      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.989       |
# |    value_loss           | 0.217       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1352        |
# |    iterations           | 4           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013207414 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.724       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00684     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0209     |
# |    std                  | 0.992       |
# |    value_loss           | 0.0575      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1342         |
# |    iterations           | 5            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0028878804 |
# |    clip_fraction        | 0.00947      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.113       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0139       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00321     |
# |    std                  | 0.985        |
# |    value_loss           | 0.0329       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1334        |
# |    iterations           | 6           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.003670949 |
# |    clip_fraction        | 0.0444      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | -1.02       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00814     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00509    |
# |    std                  | 0.97        |
# |    value_loss           | 0.0366      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1330        |
# |    iterations           | 7           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.005633874 |
# |    clip_fraction        | 0.0683      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | -0.359      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0133      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00546    |
# |    std                  | 0.97        |
# |    value_loss           | 0.0501      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1318        |
# |    iterations           | 8           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011284882 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.554       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0206     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.97        |
# |    value_loss           | 0.0204      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1315        |
# |    iterations           | 9           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.016536864 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.613       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0315     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0306     |
# |    std                  | 0.958       |
# |    value_loss           | 0.00717     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1313        |
# |    iterations           | 10          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.019697204 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.692       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0369     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0283     |
# |    std                  | 0.944       |
# |    value_loss           | 0.00393     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1311        |
# |    iterations           | 11          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.021158217 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.598       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0499     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0351     |
# |    std                  | 0.936       |
# |    value_loss           | 0.00215     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1310       |
# |    iterations           | 12         |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00670032 |
# |    clip_fraction        | 0.0775     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.34      |
# |    explained_variance   | 0.412      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0279    |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0124    |
# |    std                  | 0.916      |
# |    value_loss           | 0.00137    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1308        |
# |    iterations           | 13          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.003347593 |
# |    clip_fraction        | 0.0204      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.00182    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.599       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.000591   |
# |    std                  | 0.915       |
# |    value_loss           | 1.3         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1307        |
# |    iterations           | 14          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.005352986 |
# |    clip_fraction        | 0.0571      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00252     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00472    |
# |    std                  | 0.905       |
# |    value_loss           | 0.0177      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1303         |
# |    iterations           | 15           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 0.0057410216 |
# |    clip_fraction        | 0.066        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.199        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.445        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00578     |
# |    std                  | 0.902        |
# |    value_loss           | 1.09         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1300         |
# |    iterations           | 16           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0056008315 |
# |    clip_fraction        | 0.0417       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.843        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0184       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00275     |
# |    std                  | 0.907        |
# |    value_loss           | 0.11         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1297         |
# |    iterations           | 17           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 0.0041206023 |
# |    clip_fraction        | 0.00986      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.731        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.208        |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000653    |
# |    std                  | 0.914        |
# |    value_loss           | 0.415        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1297        |
# |    iterations           | 18          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.004742112 |
# |    clip_fraction        | 0.0541      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.616       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.164       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00416    |
# |    std                  | 0.914       |
# |    value_loss           | 0.362       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1294         |
# |    iterations           | 19           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 19456        |
# | train/                  |              |
# |    approx_kl            | 0.0064588403 |
# |    clip_fraction        | 0.0584       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.94         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000713     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00495     |
# |    std                  | 0.912        |
# |    value_loss           | 0.0164       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1292         |
# |    iterations           | 20           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0034153522 |
# |    clip_fraction        | 0.0182       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.918        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.11         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000943    |
# |    std                  | 0.909        |
# |    value_loss           | 0.172        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1292        |
# |    iterations           | 21          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.007701843 |
# |    clip_fraction        | 0.0974      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00778     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.902       |
# |    value_loss           | 0.0123      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1292        |
# |    iterations           | 22          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.014747396 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0103     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0207     |
# |    std                  | 0.894       |
# |    value_loss           | 0.00807     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1292       |
# |    iterations           | 23         |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 23552      |
# | train/                  |            |
# |    approx_kl            | 0.00921124 |
# |    clip_fraction        | 0.102      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | 0.956      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0161    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0121    |
# |    std                  | 0.89       |
# |    value_loss           | 0.0071     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1292        |
# |    iterations           | 24          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009049543 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0233     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.893       |
# |    value_loss           | 0.00498     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1292        |
# |    iterations           | 25          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.005650976 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0108     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00578    |
# |    std                  | 0.882       |
# |    value_loss           | 0.00469     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1292        |
# |    iterations           | 26          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009011213 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0181     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.88        |
# |    value_loss           | 0.00321     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1292        |
# |    iterations           | 27          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.004235113 |
# |    clip_fraction        | 0.0433      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00324     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00749    |
# |    std                  | 0.873       |
# |    value_loss           | 0.00327     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1292        |
# |    iterations           | 28          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.005059126 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00813    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00353    |
# |    std                  | 0.874       |
# |    value_loss           | 0.00177     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1291        |
# |    iterations           | 29          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.007359031 |
# |    clip_fraction        | 0.0874      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00647    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00833    |
# |    std                  | 0.87        |
# |    value_loss           | 0.000636    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1291         |
# |    iterations           | 30           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0020285323 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.916        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00659      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00234     |
# |    std                  | 0.864        |
# |    value_loss           | 0.00165      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1291         |
# |    iterations           | 31           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 0.0040384037 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.952        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.014       |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00427     |
# |    std                  | 0.849        |
# |    value_loss           | 0.000705     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1291         |
# |    iterations           | 32           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0057191816 |
# |    clip_fraction        | 0.0566       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.925        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00247     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00396     |
# |    std                  | 0.854        |
# |    value_loss           | 0.00096      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1291        |
# |    iterations           | 33          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.003842877 |
# |    clip_fraction        | 0.0206      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00152     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00306    |
# |    std                  | 0.839       |
# |    value_loss           | 0.000663    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1290         |
# |    iterations           | 34           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0012365172 |
# |    clip_fraction        | 0.0084       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.782        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00302      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000559    |
# |    std                  | 0.833        |
# |    value_loss           | 0.000869     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1290         |
# |    iterations           | 35           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 35840        |
# | train/                  |              |
# |    approx_kl            | 0.0048022396 |
# |    clip_fraction        | 0.0544       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.932        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0135      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0053      |
# |    std                  | 0.827        |
# |    value_loss           | 0.000618     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1290        |
# |    iterations           | 36          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.004924318 |
# |    clip_fraction        | 0.0593      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0123     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00676    |
# |    std                  | 0.821       |
# |    value_loss           | 0.000378    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1290        |
# |    iterations           | 37          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.006316049 |
# |    clip_fraction        | 0.0521      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00398    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00679    |
# |    std                  | 0.814       |
# |    value_loss           | 0.00024     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1290        |
# |    iterations           | 38          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.006535002 |
# |    clip_fraction        | 0.0524      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0122     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00588    |
# |    std                  | 0.806       |
# |    value_loss           | 0.000194    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1290         |
# |    iterations           | 39           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 39936        |
# | train/                  |              |
# |    approx_kl            | 0.0056134495 |
# |    clip_fraction        | 0.0575       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.971        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0142      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00801     |
# |    std                  | 0.8          |
# |    value_loss           | 0.000102     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1290         |
# |    iterations           | 40           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0047483807 |
# |    clip_fraction        | 0.0316       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0173      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00385     |
# |    std                  | 0.79         |
# |    value_loss           | 8.66e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1290        |
# |    iterations           | 41          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.012772006 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0268     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0176     |
# |    std                  | 0.778       |
# |    value_loss           | 4.07e-05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1289         |
# |    iterations           | 42           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0028263284 |
# |    clip_fraction        | 0.0225       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00337     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00461     |
# |    std                  | 0.774        |
# |    value_loss           | 2.16e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1289        |
# |    iterations           | 43          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.004551503 |
# |    clip_fraction        | 0.0457      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.012      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00639    |
# |    std                  | 0.768       |
# |    value_loss           | 2.73e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1290        |
# |    iterations           | 44          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.005781793 |
# |    clip_fraction        | 0.0472      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0138     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00542    |
# |    std                  | 0.76        |
# |    value_loss           | 3.5e-05     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1290         |
# |    iterations           | 45           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 46080        |
# | train/                  |              |
# |    approx_kl            | 0.0058760378 |
# |    clip_fraction        | 0.0548       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.911        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0176      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00742     |
# |    std                  | 0.75         |
# |    value_loss           | 2.2e-05      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1290        |
# |    iterations           | 46          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.006641977 |
# |    clip_fraction        | 0.0787      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.017      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00813    |
# |    std                  | 0.742       |
# |    value_loss           | 1.41e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1289        |
# |    iterations           | 47          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 48128       |
# | train/                  |             |
# |    approx_kl            | 0.009632883 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.024      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0173     |
# |    std                  | 0.735       |
# |    value_loss           | 3.58e-06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1289        |
# |    iterations           | 48          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009699665 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0118     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.734       |
# |    value_loss           | 2.32e-06    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1289       |
# |    iterations           | 49         |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 50176      |
# | train/                  |            |
# |    approx_kl            | 0.00720764 |
# |    clip_fraction        | 0.0986     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.1       |
# |    explained_variance   | 0.847      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0193    |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0108    |
# |    std                  | 0.725      |
# |    value_loss           | 2.36e-06   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1288        |
# |    iterations           | 50          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.005042024 |
# |    clip_fraction        | 0.0892      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0131     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00716    |
# |    std                  | 0.723       |
# |    value_loss           | 1.97e-06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1288        |
# |    iterations           | 51          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 52224       |
# | train/                  |             |
# |    approx_kl            | 0.010204412 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.867       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0201     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0206     |
# |    std                  | 0.715       |
# |    value_loss           | 1.09e-06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1288        |
# |    iterations           | 52          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.003969932 |
# |    clip_fraction        | 0.0362      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.742       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0125     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00497    |
# |    std                  | 0.705       |
# |    value_loss           | 3.01e-06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1289        |
# |    iterations           | 53          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 54272       |
# | train/                  |             |
# |    approx_kl            | 0.007291303 |
# |    clip_fraction        | 0.0889      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00399    |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.695       |
# |    value_loss           | 1.07e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1288         |
# |    iterations           | 54           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0043202043 |
# |    clip_fraction        | 0.0465       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.639        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00546      |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00602     |
# |    std                  | 0.691        |
# |    value_loss           | 2.25e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1288         |
# |    iterations           | 55           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 56320        |
# | train/                  |              |
# |    approx_kl            | 0.0036902193 |
# |    clip_fraction        | 0.0303       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.875        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00331     |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00204     |
# |    std                  | 0.68         |
# |    value_loss           | 4.56e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1287        |
# |    iterations           | 56          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009203236 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.78        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0107     |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.676       |
# |    value_loss           | 7.51e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1287         |
# |    iterations           | 57           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 58368        |
# | train/                  |              |
# |    approx_kl            | 0.0038620515 |
# |    clip_fraction        | 0.0237       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.269        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0022      |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00223     |
# |    std                  | 0.669        |
# |    value_loss           | 1.55e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1287        |
# |    iterations           | 58          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.005074148 |
# |    clip_fraction        | 0.0397      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.14       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00468    |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00301    |
# |    std                  | 0.657       |
# |    value_loss           | 1.31e-06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1287        |
# |    iterations           | 59          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 60416       |
# | train/                  |             |
# |    approx_kl            | 0.006552827 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.994      |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0128      |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00621    |
# |    std                  | 0.651       |
# |    value_loss           | 1.13e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1287         |
# |    iterations           | 60           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0026708778 |
# |    clip_fraction        | 0.0235       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.987       |
# |    explained_variance   | 0.81         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0129      |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.00251     |
# |    std                  | 0.647        |
# |    value_loss           | 1.12e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1287         |
# ...
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1217         |
# |    iterations           | 178          |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0018396759 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.061        |
# |    explained_variance   | 0.42         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00304     |
# |    n_updates            | 1770         |
# |    policy_gradient_loss | -0.00131     |
# |    std                  | 0.227        |
# |    value_loss           | 4.78e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1216         |
# |    iterations           | 179          |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 183296       |
# | train/                  |              |
# |    approx_kl            | 0.0018665837 |
# |    clip_fraction        | 0.00674      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.0752       |
# |    explained_variance   | 0.409        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000638    |
# |    n_updates            | 1780         |
# |    policy_gradient_loss | -0.00245     |
# |    std                  | 0.222        |
# |    value_loss           | 1.22e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1216        |
# |    iterations           | 180         |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.006816943 |
# |    clip_fraction        | 0.0831      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0893      |
# |    explained_variance   | 0.877       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0114     |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | -0.00892    |
# |    std                  | 0.22        |
# |    value_loss           | 1.25e-07    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1216        |
# |    iterations           | 181         |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 185344      |
# | train/                  |             |
# |    approx_kl            | 0.013237057 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0976      |
# |    explained_variance   | 0.0601      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0193     |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | -0.00697    |
# |    std                  | 0.219       |
# |    value_loss           | 2.66e-07    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1213        |
# |    iterations           | 182         |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.006021213 |
# |    clip_fraction        | 0.0689      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.102       |
# |    explained_variance   | 0.556       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00281    |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | -0.00265    |
# |    std                  | 0.218       |
# |    value_loss           | 1.38e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1206         |
# |    iterations           | 183          |
# |    time_elapsed         | 155          |
# |    total_timesteps      | 187392       |
# | train/                  |              |
# |    approx_kl            | 0.0028913757 |
# |    clip_fraction        | 0.0485       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.113        |
# |    explained_variance   | 0.954        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00607     |
# |    n_updates            | 1820         |
# |    policy_gradient_loss | -0.00578     |
# |    std                  | 0.214        |
# |    value_loss           | 8.52e-09     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1196        |
# |    iterations           | 184         |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.002880307 |
# |    clip_fraction        | 0.0101      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.131       |
# |    explained_variance   | -0.448      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00117     |
# |    n_updates            | 1830        |
# |    policy_gradient_loss | -0.00143    |
# |    std                  | 0.21        |
# |    value_loss           | 2.21e-07    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1189        |
# |    iterations           | 185         |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 189440      |
# | train/                  |             |
# |    approx_kl            | 0.012286438 |
# |    clip_fraction        | 0.0933      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.143       |
# |    explained_variance   | -5.68       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0181     |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | -0.0047     |
# |    std                  | 0.209       |
# |    value_loss           | 4.31e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1189         |
# |    iterations           | 186          |
# |    time_elapsed         | 160          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0050591026 |
# |    clip_fraction        | 0.0676       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.15         |
# |    explained_variance   | 0.725        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00491     |
# |    n_updates            | 1850         |
# |    policy_gradient_loss | -0.00597     |
# |    std                  | 0.207        |
# |    value_loss           | 1.17e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1188         |
# |    iterations           | 187          |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 191488       |
# | train/                  |              |
# |    approx_kl            | 0.0051812963 |
# |    clip_fraction        | 0.0659       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.158        |
# |    explained_variance   | -0.377       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0154      |
# |    n_updates            | 1860         |
# |    policy_gradient_loss | -0.00333     |
# |    std                  | 0.206        |
# |    value_loss           | 5.37e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1188         |
# |    iterations           | 188          |
# |    time_elapsed         | 162          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0058890237 |
# |    clip_fraction        | 0.0378       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.163        |
# |    explained_variance   | 0.579        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0062       |
# |    n_updates            | 1870         |
# |    policy_gradient_loss | -0.0047      |
# |    std                  | 0.205        |
# |    value_loss           | 7.02e-08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1188         |
# |    iterations           | 189          |
# |    time_elapsed         | 162          |
# |    total_timesteps      | 193536       |
# | train/                  |              |
# |    approx_kl            | 0.0022333004 |
# |    clip_fraction        | 0.031        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.168        |
# |    explained_variance   | 0.645        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0127      |
# |    n_updates            | 1880         |
# |    policy_gradient_loss | 4.46e-05     |
# |    std                  | 0.204        |
# |    value_loss           | 1.82e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1188         |
# |    iterations           | 190          |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0072477367 |
# |    clip_fraction        | 0.115        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.179        |
# |    explained_variance   | 0.409        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.017       |
# |    n_updates            | 1890         |
# |    policy_gradient_loss | -0.0106      |
# |    std                  | 0.2          |
# |    value_loss           | 9.19e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1188        |
# |    iterations           | 191         |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 195584      |
# | train/                  |             |
# |    approx_kl            | 0.008295497 |
# |    clip_fraction        | 0.0997      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.191       |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0175     |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | -0.00824    |
# |    std                  | 0.2         |
# |    value_loss           | 2.71e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1188         |
# |    iterations           | 192          |
# |    time_elapsed         | 165          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0036617122 |
# |    clip_fraction        | 0.031        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.192        |
# |    explained_variance   | 0.94         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00568     |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | -0.00284     |
# |    std                  | 0.199        |
# |    value_loss           | 6.01e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1189         |
# |    iterations           | 193          |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 197632       |
# | train/                  |              |
# |    approx_kl            | 0.0025268286 |
# |    clip_fraction        | 0.0354       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.193        |
# |    explained_variance   | 0.941        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00246      |
# |    n_updates            | 1920         |
# |    policy_gradient_loss | -0.00428     |
# |    std                  | 0.2          |
# |    value_loss           | 2.53e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1189        |
# |    iterations           | 194         |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.003755466 |
# |    clip_fraction        | 0.025       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.192       |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00933     |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | -0.00316    |
# |    std                  | 0.2         |
# |    value_loss           | 1.65e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1189         |
# |    iterations           | 195          |
# |    time_elapsed         | 167          |
# |    total_timesteps      | 199680       |
# | train/                  |              |
# |    approx_kl            | 0.0030137452 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.2          |
# |    explained_variance   | 0.923        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000386    |
# |    n_updates            | 1940         |
# |    policy_gradient_loss | -0.00224     |
# |    std                  | 0.197        |
# |    value_loss           | 7.99e-08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1190          |
# |    iterations           | 196           |
# |    time_elapsed         | 168           |
# |    total_timesteps      | 200704        |
# | train/                  |               |
# |    approx_kl            | 0.00070341415 |
# |    clip_fraction        | 0.0161        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | 0.214         |
# |    explained_variance   | 0.947         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00286      |
# |    n_updates            | 1950          |
# |    policy_gradient_loss | -0.000937     |
# |    std                  | 0.194         |
# |    value_loss           | 3.25e-08      |
# -------------------------------------------
# Training finished.
# Saved model -> runs/ppo_baseline/ppo_acc.zip
# Saved VecNormalize -> runs/ppo_baseline/vecnormalize.pkl
# Loaded model and VecNormalize for evaluation.
# Running 3 smoke-check episodes ...
# Episode 0: return=-6965.574, collision=False, steps=200
# Episode 1: return=-5685.896, collision=False, steps=200
# Episode 2: return=-6934.188, collision=False, steps=200
#
# Done. You now have:
#  - runs/ppo_baseline/ppo_acc.zip
#  - runs/ppo_baseline/vecnormalize.pkl
# These artifacts will be loaded by your attacks notebook.

# %%
# === Make model/env ready for the demo ===
import os, sys, subprocess, shlex
from IPython import get_ipython

# 1) Ensure ACCEnv is defined (import .py; else convert .ipynb -> .py; else %run notebook)
try:
    from acc_env import ACCEnv  # if you already have acc_env.py alongside this notebook
    print("Imported ACCEnv from acc_env.py")
except ModuleNotFoundError:
    if os.path.exists("acc_env.ipynb"):
        print("Converting acc_env.ipynb -> acc_env.py ...")
        subprocess.run(shlex.split("jupyter nbconvert --to python acc_env.ipynb"), check=True)
        if os.getcwd() not in sys.path:
            sys.path.append(os.getcwd())
        from acc_env import ACCEnv
        print("Imported ACCEnv from converted acc_env.py")
    else:
        print("Running acc_env.ipynb directly...")
        get_ipython().run_line_magic("run", "./acc_env.ipynb")
        # ACCEnv should now be in globals

# %%
# 2) Try to load saved PPO + VecNormalize; otherwise quick-train a small model
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

LOGDIR = "runs/ppo_baseline"  # change if you saved elsewhere
vec_path = os.path.join(LOGDIR, "vecnormalize.pkl")
mdl_path = os.path.join(LOGDIR, "ppo_acc.zip")

def make_env(seed=123, brake_profile=True, normalize_obs=True):
    def _thunk():
        return ACCEnv(brake_profile=brake_profile, normalize_obs=normalize_obs, seed=seed)
    return _thunk

model = None
env = None

if os.path.exists(vec_path) and os.path.exists(mdl_path):
    print(f"Loading saved model/env from {LOGDIR} ...")
    base_env = DummyVecEnv([make_env(seed=123, brake_profile=True, normalize_obs=True)])
    env = VecNormalize.load(vec_path, base_env)
    env.training = False
    env.norm_reward = False
    model = PPO.load(mdl_path, env=env)
    print("Loaded saved PPO and VecNormalize.")
else:
    print("Saved files not found; doing a quick in-memory train so the demo can run...")
    # quick train on a stationary-lead scenario (no braking) so it learns *something*
    train_env = DummyVecEnv([make_env(seed=42, brake_profile=False, normalize_obs=True)])
    train_env = VecNormalize(train_env, norm_obs=True, norm_reward=True, clip_obs=1.0)
    model = PPO(
        "MlpPolicy", train_env, seed=42, verbose=0,
        n_steps=512, batch_size=128, learning_rate=3e-4,
        gamma=0.99, gae_lambda=0.95, clip_range=0.2, ent_coef=0.0
    )
    model.learn(total_timesteps=8_000)  # small, fast
    # build an eval env (with braking enabled) sharing the same VecNormalize statistics
    eval_base = DummyVecEnv([make_env(seed=123, brake_profile=True, normalize_obs=True)])
    env = VecNormalize(eval_base, norm_obs=True, norm_reward=False, clip_obs=1.0)
    # copy normalization stats from training env so obs scales match what policy expects
    env.obs_rms = train_env.obs_rms
    env.ret_rms = train_env.ret_rms
    env.training = False
    print("Quick train done; model/env are ready.")

print("\n✅ model and env are ready in this kernel.")

# %%
from __future__ import annotations
import gymnasium as gym
import torch
import numpy as np
from typing import Any

# %%
def _to_tensor(x: np.ndarray) -> torch.Tensor:
    return torch.as_tensor(x, dtype=torch.float32)

# %%
class AttackWrapper:
    """Base wrapper that perturbs observations before the agent acts."""
    def __init__(self, model: Any, epsilon: float = 0.01, device: str = "cpu") -> None:
        self.model = model
        self.eps = float(epsilon)
        self.device = device

    def perturb(self, obs: np.ndarray) -> np.ndarray:
        return obs

    def act(self, obs: np.ndarray):
        # Compute adversarial observation (gradients enabled in perturb),
        # then call model.predict without gradients.
        obs_adv = self.perturb(obs)
        with torch.no_grad():
            action, _ = self.model.predict(obs_adv, deterministic=True)
        return action, obs_adv

# %%
class FGSMAttack(AttackWrapper):
    """FGSM with respect to policy mean action (pre-squash)."""
    def perturb(self, obs: np.ndarray) -> np.ndarray:
        # prepare policy for gradients
        self.model.policy.set_training_mode(True)
        self.model.policy.zero_grad(set_to_none=True)

        obs_t = _to_tensor(obs)
        single = False
        if obs_t.ndim == 1:
            obs_t = obs_t.unsqueeze(0)
            single = True
        obs_t = obs_t.to(self.device)
        obs_t.requires_grad_(True)

        # forward through policy internals to get mean action
        features = self.model.policy.extract_features(obs_t)
        latent_pi, _ = self.model.policy.mlp_extractor(features)
        mean_actions = self.model.policy.action_net(latent_pi)  # [B, act_dim]

        # simple scalar objective: increase squared mean action
        obj = (mean_actions ** 2).sum()
        obj.backward()

        grad_sign = torch.sign(obs_t.grad)
        adv = torch.clamp(obs_t + self.eps * grad_sign, -1.0, 1.0)
        adv_np = adv.detach().cpu().numpy()
        return adv_np[0] if single else adv_np

# %%
class OIAttack(AttackWrapper):
    """Optimism Induction Attack: increase the critic value V(s)."""
    def perturb(self, obs: np.ndarray) -> np.ndarray:
        self.model.policy.set_training_mode(True)
        self.model.policy.zero_grad(set_to_none=True)

        obs_t = _to_tensor(obs)
        single = False
        if obs_t.ndim == 1:
            obs_t = obs_t.unsqueeze(0)
            single = True
        obs_t = obs_t.to(self.device)
        obs_t.requires_grad_(True)

        features = self.model.policy.extract_features(obs_t)
        _, latent_vf = self.model.policy.mlp_extractor(features)
        values = self.model.policy.value_net(latent_vf)  # [B,1]

        obj = values.sum()
        obj.backward()

        grad_sign = torch.sign(obs_t.grad)
        adv = torch.clamp(obs_t + self.eps * grad_sign, -1.0, 1.0)
        adv_np = adv.detach().cpu().numpy()
        return adv_np[0] if single else adv_np

# %%
def print_attack_sanity(model, env, eps=0.01):
    atk = FGSMAttack(model, epsilon=eps, device="cpu")
    obs = env.reset()[0]
    adv = atk.perturb(obs)
    print("FGSM sanity:")
    print(" original obs:", obs)
    print(" adv obs     :", adv)
    print(" max |Δ|     :", float(np.max(np.abs(np.array(adv) - np.array(obs)))))

    atk2 = OIAttack(model, epsilon=eps, device="cpu")
    adv2 = atk2.perturb(obs)
    print("\nOIA sanity:")
    print(" original obs:", obs)
    print(" adv obs     :", adv2)
    print(" max |Δ|     :", float(np.max(np.abs(np.array(adv2) - np.array(obs)))))
