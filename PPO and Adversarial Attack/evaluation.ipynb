# %%
# ==== DEMO: Evaluate Baseline vs FGSM vs OIA (paper-aligned, CBF-aware) ====
import os, json, numpy as np
import matplotlib.pyplot as plt
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

# If attacks live in attacks.py (or converted notebook), import them:
try:
    from attacks import FGSMAttack, OIAttack
except Exception as e:
    raise ImportError("Import FGSMAttack/OIAttack failed. Make sure attacks.py exists or run attacks.ipynb first.") from e

# ============ Config ============
LOGDIR   = "runs/ppo_baseline"
VEC_PATH = os.path.join(LOGDIR, "vecnormalize.pkl")
MDL_PATH = os.path.join(LOGDIR, "ppo_acc.zip")

EPISODES = 100          # paper uses 100
EPSILON  = 0.02         # normalized epsilon; sweep around [0.005, 0.02]
SEED     = 2025

# ============ Env helpers ============
def make_env(seed=123, with_braking=True, normalize_obs=False):
    """
    ACCEnv factory. Keep normalize_obs=False and let VecNormalize handle scaling (SB3 best practice).
    We attach the paper's braking window via an attribute 'lead_profile' that ACCEnv.step() uses.
    """
    def _thunk():
        env = ACCEnv(normalize_obs=normalize_obs, seed=seed)
        if with_braking:
            # Paper-consistent "critical event": a_l = -2.0 m/s^2 for 3 s (Δt=0.1 -> 30 steps)
            def lead_profile(step):
                return -2.0 if 120 <= step < 150 else 0.0
            env.lead_profile = lead_profile
        return env
    return _thunk

def _get_inner_env(vec_env):
    """
    Robustly fetch the underlying Gym env (first subenv) from (possibly wrapped) VecEnv.
    Works for VecNormalize(DummyVecEnv(...)).
    """
    v = getattr(vec_env, "venv", None) or getattr(vec_env, "env", None) or vec_env
    while hasattr(v, "venv"):
        v = v.venv
    if hasattr(v, "envs") and len(v.envs) > 0:
        return v.envs[0]
    return None

def reset_unwrap(vec_env, **kwargs):
    out = vec_env.reset(**kwargs)
    if isinstance(out, np.ndarray):  # (n_envs, obs_dim)
        return out[0]
    if isinstance(out, tuple) and len(out) == 2:
        obs, _ = out
        return obs[0] if isinstance(obs, np.ndarray) and obs.ndim == 2 else obs
    return out

def step_unwrap(vec_env, action):
    out = vec_env.step(action)
    if len(out) == 4:
        obs, reward, done, info = out
        return obs[0], float(np.asarray(reward).ravel()[0]), bool(np.asarray(done).ravel()[0]), info[0]
    elif len(out) == 5:
        obs, reward, terminated, truncated, info = out
        done = bool(np.asarray(terminated).ravel()[0] or np.asarray(truncated).ravel()[0])
        return obs[0], float(np.asarray(reward).ravel()[0]), done, info[0]
    raise RuntimeError(f"Unexpected env.step() return length: {len(out)}")

def _is_collision(info, inner_env):
    # Prefer explicit flag; fall back to dx<=0; final fallback to env.collision
    if isinstance(info, dict) and "collision" in info:
        return bool(info["collision"])
    if isinstance(info, dict) and "dx" in info:
        try:
            return float(info["dx"]) <= 0.0
        except Exception:
            pass
    if inner_env is not None and hasattr(inner_env, "collision"):
        return bool(inner_env.collision)
    return False

# ============ Evaluation ============
def eval_suite(model, vec_norm_env, attack=None, eps=0.0, episodes=100, seed=0,
               collect_one_trace=False):
    """
    Evaluate a model on a VecNormalize-wrapped env.
      - attack: None, FGSMAttack(model), or OIAttack(model)
      - eps: epsilon in the *normalized* obs space
      - collect_one_trace: if True, return per-step traces for 1 rep episode for plotting RMSE/time series
    Returns dict with collision_rate, return_mean/std, and optional 'trace' for baseline/fgsm/oia.
    """
    rng = np.random.default_rng(seed)
    vec_norm_env.training = False
    vec_norm_env.norm_reward = False
    inner = _get_inner_env(vec_norm_env)

    total_coll = 0
    returns = []
    trace = None

    for ep in range(episodes):
        obs = reset_unwrap(vec_norm_env)
        ep_ret = 0.0
        collided = False
        done = False

        if collect_one_trace and trace is None:
            trace = {"t": [], "obs_used": [], "dx_true": [], "ego_v_true": [], "lead_v_true": [],
                     "action_raw": [], "action_applied": []}
            tstep = 0

        while not done:
            obs_for_policy = obs
            # ==== Attack in normalized space ====
            if attack is not None and eps > 0:
                adv = attack(obs, eps)  # consumes normalized obs, returns normalized obs
                # Let the CBF compute clamp using the attacked view of the state:
                if inner is not None and hasattr(inner, "set_safety_obs_for_filter"):
                    # If env expects raw units for CBF, de-normalize if helper exists
                    if hasattr(inner, "_denormalize") and np.max(np.abs(adv)) <= 1.1:
                        inner.set_safety_obs_for_filter(inner._denormalize(adv))
                    else:
                        inner.set_safety_obs_for_filter(adv)
                obs_for_policy = adv
            else:
                if inner is not None and hasattr(inner, "clear_safety_obs_for_filter"):
                    inner.clear_safety_obs_for_filter()

            action, _ = model.predict(obs_for_policy, deterministic=True)
            next_obs, r, done, info = step_unwrap(vec_norm_env, action)

            # Collision is judged on TRUE env state (info or inner state), not perturbed obs
            collided = collided or _is_collision(info, inner)

            # Optional trace (first episode only)
            if collect_one_trace and trace is not None:
                trace["t"].append(tstep * 0.1)  # Δt = 0.1 s
                trace["obs_used"].append(obs_for_policy.copy())
                trace["dx_true"].append(float(info.get("dx", np.nan)))
                trace["ego_v_true"].append(float(info.get("ego_v", np.nan)))
                trace["lead_v_true"].append(float(info.get("lead_v", np.nan)))
                trace["action_raw"].append(float(action[0] if hasattr(action, "__len__") else action))
                trace["action_applied"].append(float(info.get("applied_action", np.nan)))
                tstep += 1

            ep_ret += r
            obs = next_obs

        total_coll += int(collided)
        returns.append(ep_ret)

    out = {
        "episodes": episodes,
        "collision_rate": total_coll / max(1, episodes),
        "return_mean": float(np.mean(returns)),
        "return_std": float(np.std(returns)),
    }
    if collect_one_trace and trace is not None:
        # Stack to arrays for easier plotting
        for k in trace:
            trace[k] = np.asarray(trace[k])
        out["trace"] = trace
    return out

# ============ Load model + env ============
if not (os.path.exists(VEC_PATH) and os.path.exists(MDL_PATH)):
    raise FileNotFoundError(
        f"Missing saved artifacts:\n - {VEC_PATH}\n - {MDL_PATH}\nTrain first (longer run for paper-like numbers)."
    )

base_eval = DummyVecEnv([make_env(seed=SEED, with_braking=True, normalize_obs=False)])
env = VecNormalize.load(VEC_PATH, base_eval)
env.training = False
env.norm_reward = False
model = PPO.load(MDL_PATH, env=env)

# Attack callables (operate in normalized space)
fgsm = FGSMAttack(model)
oia  = OIAttack(model)

# ============ Run evaluations ============
results = {}
results["baseline"] = eval_suite(model, env, attack=None, eps=0.0,   episodes=EPISODES, seed=SEED,   collect_one_trace=True)
results["fgsm"]     = eval_suite(model, env, attack=fgsm, eps=EPSILON, episodes=EPISODES, seed=SEED+1)
results["oia"]      = eval_suite(model, env, attack=oia,  eps=EPSILON, episodes=EPISODES, seed=SEED+2)

print(json.dumps({k: {m: round(v[m], 3) for m in v if isinstance(v[m], (int, float))}
                  for k, v in results.items()}, indent=2))

# ============ Save metrics ============
os.makedirs("demo_outputs", exist_ok=True)
with open("demo_outputs/metrics.json", "w") as f:
    json.dump({k: {kk: (float(v[kk]) if isinstance(v[kk], (np.floating, float)) else v[kk])
                   for kk in v if kk != "trace"}
               for k, v in results.items()}, f, indent=2)

# ============ Plots ============
labels = ["Baseline","FGSM","OIA"]
x = np.arange(len(labels))

# Collision (NOTE: attacks should be non-zero; baseline may remain ~0 if agent is good)
coll = [results[k]["collision_rate"] for k in ["baseline","fgsm","oia"]]
plt.figure(figsize=(6,4))
plt.bar(x, coll)
plt.xticks(x, labels)
plt.ylim(0, 1)
for i, r in enumerate(coll):
    plt.text(i, min(0.98, r+0.03), f"{r:.2f}", ha="center")
plt.title(f"Collision Rate (ε={EPSILON})")
plt.ylabel("collided episodes / total")
plt.tight_layout()
plt.savefig("demo_outputs/collision_rate.png", dpi=200)
plt.show()

# Returns
rets = [results[k]["return_mean"] for k in ["baseline","fgsm","oia"]]
plt.figure(figsize=(6,4))
plt.bar(x, rets)
plt.xticks(x, labels)
for i, r in enumerate(rets):
    plt.text(i, r + 0.05*abs(r), f"{r:.2f}", ha="center")
plt.title(f"Episode Return (ε={EPSILON})")
plt.ylabel("mean return")
plt.tight_layout()
plt.savefig("demo_outputs/returns.png", dpi=200)
plt.show()

# ε-sweep (half episodes to keep it quick)
eps_grid = np.array([0.0, 0.005, 0.01, 0.015, 0.02], dtype=np.float32)
fgsm_curve, oia_curve = [], []
for eps in eps_grid:
    fgsm_curve.append(eval_suite(model, env, attack=fgsm, eps=float(eps), episodes=max(10, EPISODES//2), seed=SEED+3)["collision_rate"])
    oia_curve.append( eval_suite(model, env, attack=oia,  eps=float(eps), episodes=max(10, EPISODES//2), seed=SEED+4)["collision_rate"])

plt.figure(figsize=(6.5,4))
plt.plot(eps_grid, fgsm_curve, marker="o", label="FGSM")
plt.plot(eps_grid, oia_curve,  marker="o", label="OIA")
plt.xlabel("ε (normalized)")
plt.ylabel("collision rate")
plt.title("Collision Rate vs Attack Budget ε")
plt.legend()
plt.tight_layout()
plt.savefig("demo_outputs/epsilon_sweep.png", dpi=200)
plt.show()

# Time-series + Stealth (RMSE) from the single traced baseline episode vs attacks run for ONE episode each
def rmse(a, b): 
    a = np.asarray(a); b = np.asarray(b); 
    return float(np.sqrt(np.mean((a-b)**2)))

# Re-run ONE representative episode per condition to collect traces in normalized space
one_base = results["baseline"]["trace"]
one_fgsm = eval_suite(model, env, attack=fgsm, eps=EPSILON, episodes=1, seed=SEED+10, collect_one_trace=True)["trace"]
one_oia  = eval_suite(model, env, attack=oia,  eps=EPSILON, episodes=1, seed=SEED+11, collect_one_trace=True)["trace"]

# Plot distance & ego speed (true env signals from info)
plt.figure(figsize=(9,3))
plt.plot(one_base["t"], one_base["ego_v_true"], label="baseline")
plt.plot(one_fgsm["t"], one_fgsm["ego_v_true"], label="FGSM")
plt.plot(one_oia["t"],  one_oia["ego_v_true"],  label="OIA")
plt.xlabel("time (s)"); plt.ylabel("ego speed (m/s)")
plt.title("Time-series: Ego Speed")
plt.legend(); plt.tight_layout()
plt.savefig("demo_outputs/timeseries_ego_speed.png", dpi=200); plt.show()

plt.figure(figsize=(9,3))
plt.plot(one_base["t"], one_base["dx_true"], label="baseline")
plt.plot(one_fgsm["t"], one_fgsm["dx_true"], label="FGSM")
plt.plot(one_oia["t"],  one_oia["dx_true"],  label="OIA")
plt.axhline(0.0, linestyle="--")
plt.xlabel("time (s)"); plt.ylabel("headway distance (m)")
plt.title("Time-series: Inter-vehicle Distance")
plt.legend(); plt.tight_layout()
plt.savefig("demo_outputs/timeseries_distance.png", dpi=200); plt.show()

# Stealth RMSE between the normalized obs the policy actually consumed
# Align lengths defensively (episodes may terminate at different steps due to collision)
L = min(len(one_base["obs_used"]), len(one_fgsm["obs_used"]), len(one_oia["obs_used"]))
rmse_fgsm = rmse(one_base["obs_used"][:L], one_fgsm["obs_used"][:L])
rmse_oia  = rmse(one_base["obs_used"][:L], one_oia["obs_used"][:L])

plt.figure(figsize=(6,4))
plt.bar([0,1], [rmse_fgsm, rmse_oia], tick_label=["FGSM","OIA"])
plt.ylabel("RMSE vs baseline (normalized obs)")
plt.title("Stealth (lower RMSE is stealthier)")
for i, v in enumerate([rmse_fgsm, rmse_oia]):
    plt.text(i, v + 0.02*max(1e-6, v), f"{v:.3f}", ha="center")
plt.tight_layout()
plt.savefig("demo_outputs/rmse_stealth.png", dpi=200)
plt.show()

print("Saved figures to demo_outputs/:",
      "collision_rate.png, returns.png, epsilon_sweep.png, timeseries_ego_speed.png, timeseries_distance.png, rmse_stealth.png")
# Out:
# 2025-09-25 23:38:42.727473: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Imported ACCEnv from acc_env.py
# Train env created. obs_space: Box([  0. -30.   0.], [200.  30.  40.], (3,), float32) act_space: Box(-3.5, 2.0, (1,), float32)
# Using cpu device
# Logging to runs/ppo_baseline
# Starting training for 200000 timesteps ...
# -----------------------------
# | time/              |      |
# |    fps             | 1942 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 1024 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1441        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.009113206 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | -0.0173     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.124       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00692    |
# |    std                  | 1.01        |
# |    value_loss           | 1.05        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1406        |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.003913062 |
# |    clip_fraction        | 0.0106      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.497       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000263   |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00445    |
# |    std                  | 1           |
# |    value_loss           | 0.0238      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1392         |
# |    iterations           | 4            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0030840375 |
# |    clip_fraction        | 0.00615      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.0832       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.339        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00123     |
# |    std                  | 0.999        |
# |    value_loss           | 0.812        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1379         |
# |    iterations           | 5            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0042330017 |
# |    clip_fraction        | 0.0301       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.6          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0357       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00509     |
# |    std                  | 0.995        |
# |    value_loss           | 0.096        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1365        |
# |    iterations           | 6           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009058747 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.8         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000502    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 0.999       |
# |    value_loss           | 0.0499      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1364        |
# |    iterations           | 7           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.007461185 |
# |    clip_fraction        | 0.0226      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.866       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00749     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00701    |
# |    std                  | 0.984       |
# |    value_loss           | 0.0371      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1363        |
# |    iterations           | 8           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009910746 |
# |    clip_fraction        | 0.0904      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.821       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0123     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00825    |
# |    std                  | 0.997       |
# |    value_loss           | 0.0176      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1361         |
# |    iterations           | 9            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 0.0074170455 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.781        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00471      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00787     |
# |    std                  | 0.999        |
# |    value_loss           | 0.0189       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1355        |
# |    iterations           | 10          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.004428191 |
# |    clip_fraction        | 0.0146      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.0791      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00358     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00144    |
# |    std                  | 0.992       |
# |    value_loss           | 0.0577      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1356        |
# |    iterations           | 11          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.004160939 |
# |    clip_fraction        | 0.0238      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | -1.22       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00106    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00132    |
# |    std                  | 0.992       |
# |    value_loss           | 0.04        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1352        |
# |    iterations           | 12          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008616429 |
# |    clip_fraction        | 0.094       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.182       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0079     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00806    |
# |    std                  | 0.999       |
# |    value_loss           | 0.0211      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1350        |
# |    iterations           | 13          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.013144539 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.848       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0235     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0215     |
# |    std                  | 0.994       |
# |    value_loss           | 0.00566     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1349        |
# |    iterations           | 14          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.016838644 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0117     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.026      |
# |    std                  | 0.994       |
# |    value_loss           | 0.00344     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1341        |
# |    iterations           | 15          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.012169654 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.842       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0268     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0203     |
# |    std                  | 0.988       |
# |    value_loss           | 0.002       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1336        |
# |    iterations           | 16          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013534252 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.743       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0586     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0227     |
# |    std                  | 0.99        |
# |    value_loss           | 0.000728    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1335         |
# |    iterations           | 17           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 0.0029077576 |
# |    clip_fraction        | 0.00439      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0543       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0532       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000728    |
# |    std                  | 1            |
# |    value_loss           | 0.145        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1335         |
# |    iterations           | 18           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0044002896 |
# |    clip_fraction        | 0.0318       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.386        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0235       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00381     |
# |    std                  | 1            |
# |    value_loss           | 0.0896       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1335        |
# |    iterations           | 19          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.006383595 |
# |    clip_fraction        | 0.0725      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.574       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00379     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00895    |
# |    std                  | 0.99        |
# |    value_loss           | 0.0563      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1321        |
# |    iterations           | 20          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009418245 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00386    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0149     |
# |    std                  | 0.977       |
# |    value_loss           | 0.00503     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1321        |
# |    iterations           | 21          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.009366479 |
# |    clip_fraction        | 0.0972      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.807       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0185     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0132     |
# |    std                  | 0.971       |
# |    value_loss           | 0.00354     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1322         |
# |    iterations           | 22           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0035746056 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.763        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00497     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00208     |
# |    std                  | 0.965        |
# |    value_loss           | 0.00605      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1323        |
# |    iterations           | 23          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.009489691 |
# |    clip_fraction        | 0.0834      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00329     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00406    |
# |    std                  | 0.969       |
# |    value_loss           | 0.00605     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1319         |
# |    iterations           | 24           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0054925103 |
# |    clip_fraction        | 0.0584       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.883        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0148      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00537     |
# |    std                  | 0.967        |
# |    value_loss           | 0.00205      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1318        |
# |    iterations           | 25          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.007914549 |
# |    clip_fraction        | 0.0914      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.842       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0188      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.966       |
# |    value_loss           | 0.00186     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1319        |
# |    iterations           | 26          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008005966 |
# |    clip_fraction        | 0.0698      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0165     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.961       |
# |    value_loss           | 0.00075     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1319        |
# |    iterations           | 27          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.009147642 |
# |    clip_fraction        | 0.0883      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00084    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.949       |
# |    value_loss           | 0.000775    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1319        |
# |    iterations           | 28          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.013406157 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0154     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.934       |
# |    value_loss           | 0.000705    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1319        |
# |    iterations           | 29          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.012460796 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.02       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0162     |
# |    std                  | 0.927       |
# |    value_loss           | 0.000456    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1319        |
# |    iterations           | 30          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.006797091 |
# |    clip_fraction        | 0.0531      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.022      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00464    |
# |    std                  | 0.918       |
# |    value_loss           | 0.000291    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1320         |
# |    iterations           | 31           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 0.0032579973 |
# |    clip_fraction        | 0.00908      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.0621      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0323       |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00075     |
# |    std                  | 0.916        |
# |    value_loss           | 0.073        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1318         |
# |    iterations           | 32           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0051671956 |
# |    clip_fraction        | 0.0703       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.187        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0444       |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00623     |
# |    std                  | 0.917        |
# |    value_loss           | 0.137        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1317        |
# |    iterations           | 33          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.004063264 |
# |    clip_fraction        | 0.0397      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.545       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0433      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00464    |
# |    std                  | 0.924       |
# |    value_loss           | 0.107       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1318         |
# |    iterations           | 34           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0025403015 |
# |    clip_fraction        | 0.0042       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.897        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00449     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000677    |
# |    std                  | 0.926        |
# |    value_loss           | 0.0081       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1319        |
# |    iterations           | 35          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.004369855 |
# |    clip_fraction        | 0.00518     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.569       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0267      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.000596   |
# |    std                  | 0.93        |
# |    value_loss           | 0.0361      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1319         |
# |    iterations           | 36           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0071805706 |
# |    clip_fraction        | 0.0615       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.62         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0077       |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00543     |
# |    std                  | 0.936        |
# |    value_loss           | 0.0691       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1319        |
# |    iterations           | 37          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.006623161 |
# |    clip_fraction        | 0.0741      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0126     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 0.924       |
# |    value_loss           | 0.0403      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1315        |
# |    iterations           | 38          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008321956 |
# |    clip_fraction        | 0.0836      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.608       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000799   |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.914       |
# |    value_loss           | 0.026       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1316       |
# |    iterations           | 39         |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 39936      |
# | train/                  |            |
# |    approx_kl            | 0.00851915 |
# |    clip_fraction        | 0.0873     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.32      |
# |    explained_variance   | 0.558      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00946    |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0101    |
# |    std                  | 0.907      |
# |    value_loss           | 0.0279     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1317        |
# |    iterations           | 40          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.007951793 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.561       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00432    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00476    |
# |    std                  | 0.906       |
# |    value_loss           | 0.0231      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1317        |
# |    iterations           | 41          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.005493571 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.55        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00761    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00485    |
# |    std                  | 0.895       |
# |    value_loss           | 0.0178      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1316         |
# |    iterations           | 42           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0019349343 |
# |    clip_fraction        | 0.00352      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.488        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00962      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00125     |
# |    std                  | 0.886        |
# |    value_loss           | 0.0107       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1316         |
# |    iterations           | 43           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 44032        |
# | train/                  |              |
# |    approx_kl            | 0.0043397984 |
# |    clip_fraction        | 0.044        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.584        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00601     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00519     |
# |    std                  | 0.887        |
# |    value_loss           | 0.00666      |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1316       |
# |    iterations           | 44         |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.00341389 |
# |    clip_fraction        | 0.0289     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | 0.514      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00277    |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.00301   |
# |    std                  | 0.891      |
# |    value_loss           | 0.00445    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1316        |
# |    iterations           | 45          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.004512473 |
# |    clip_fraction        | 0.0363      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.852       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00367    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00489    |
# |    std                  | 0.877       |
# |    value_loss           | 0.0018      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1317         |
# |    iterations           | 46           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0058479495 |
# |    clip_fraction        | 0.0603       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.9          |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0138      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0046      |
# |    std                  | 0.874        |
# |    value_loss           | 0.00121      |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1318       |
# |    iterations           | 47         |
# |    time_elapsed         | 36         |
# |    total_timesteps      | 48128      |
# | train/                  |            |
# |    approx_kl            | 0.00910625 |
# |    clip_fraction        | 0.123      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.28      |
# |    explained_variance   | 0.91       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0125    |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0155    |
# |    std                  | 0.867      |
# |    value_loss           | 0.00042    |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1318         |
# |    iterations           | 48           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0070294403 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.885        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0167      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00506     |
# |    std                  | 0.858        |
# |    value_loss           | 0.000443     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1319        |
# |    iterations           | 49          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 50176       |
# | train/                  |             |
# |    approx_kl            | 0.011607236 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0107     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0193     |
# |    std                  | 0.846       |
# |    value_loss           | 0.000128    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1319         |
# |    iterations           | 50           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0009582436 |
# |    clip_fraction        | 0.00225      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.0999       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0528       |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -3.92e-05    |
# |    std                  | 0.849        |
# |    value_loss           | 0.149        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1319         |
# |    iterations           | 51           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 52224        |
# | train/                  |              |
# |    approx_kl            | 0.0025051364 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.427        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.041        |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00039     |
# |    std                  | 0.846        |
# |    value_loss           | 0.117        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1320        |
# |    iterations           | 52          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.005978998 |
# |    clip_fraction        | 0.0525      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.675       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0128     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00442    |
# |    std                  | 0.848       |
# |    value_loss           | 0.00347     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1319         |
# |    iterations           | 53           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 54272        |
# | train/                  |              |
# |    approx_kl            | 0.0061424784 |
# |    clip_fraction        | 0.0431       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.592        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0567       |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00339     |
# |    std                  | 0.848        |
# |    value_loss           | 0.0987       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1318        |
# |    iterations           | 54          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007984072 |
# |    clip_fraction        | 0.0746      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.74        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0113      |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00457    |
# |    std                  | 0.838       |
# |    value_loss           | 0.0151      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1318         |
# |    iterations           | 55           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 56320        |
# | train/                  |              |
# |    approx_kl            | 0.0069842758 |
# |    clip_fraction        | 0.0748       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.806        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00652      |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00479     |
# |    std                  | 0.833        |
# |    value_loss           | 0.0151       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1312        |
# |    iterations           | 56          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.003420039 |
# |    clip_fraction        | 0.0177      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.852       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.012      |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00375    |
# |    std                  | 0.827       |
# |    value_loss           | 0.018       |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1307          |
# |    iterations           | 57            |
# |    time_elapsed         | 44            |
# |    total_timesteps      | 58368         |
# | train/                  |               |
# |    approx_kl            | 0.00024105015 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.23         |
# |    explained_variance   | 0.829         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00713       |
# |    n_updates            | 560           |
# |    policy_gradient_loss | -0.000405     |
# |    std                  | 0.829         |
# |    value_loss           | 0.00824       |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1302        |
# |    iterations           | 58          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.005480409 |
# |    clip_fraction        | 0.0504      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00544    |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00467    |
# |    std                  | 0.828       |
# |    value_loss           | 0.00443     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1300        |
# |    iterations           | 59          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 60416       |
# | train/                  |             |
# |    approx_kl            | 0.004700631 |
# |    clip_fraction        | 0.0248      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.756       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00734    |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00224    |
# |    std                  | 0.815       |
# |    value_loss           | 0.00405     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1300        |
# |    iterations           | 60          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.006705679 |
# |    clip_fraction        | 0.0494      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.485       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0145     |
# ...
# |    fps                  | 1170         |
# |    iterations           | 180          |
# |    time_elapsed         | 157          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0043658405 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.824       |
# |    explained_variance   | 0.863        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00765     |
# |    n_updates            | 1790         |
# |    policy_gradient_loss | -0.00296     |
# |    std                  | 0.55         |
# |    value_loss           | 5.27e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1171         |
# |    iterations           | 181          |
# |    time_elapsed         | 158          |
# |    total_timesteps      | 185344       |
# | train/                  |              |
# |    approx_kl            | 0.0017134494 |
# |    clip_fraction        | 0.0529       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.819       |
# |    explained_variance   | 0.394        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0018       |
# |    n_updates            | 1800         |
# |    policy_gradient_loss | -0.000147    |
# |    std                  | 0.548        |
# |    value_loss           | 5.87e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1172         |
# |    iterations           | 182          |
# |    time_elapsed         | 158          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0032013985 |
# |    clip_fraction        | 0.0377       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.817       |
# |    explained_variance   | 0.783        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.013       |
# |    n_updates            | 1810         |
# |    policy_gradient_loss | -0.00294     |
# |    std                  | 0.549        |
# |    value_loss           | 7.34e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1173         |
# |    iterations           | 183          |
# |    time_elapsed         | 159          |
# |    total_timesteps      | 187392       |
# | train/                  |              |
# |    approx_kl            | 0.0006300588 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.818       |
# |    explained_variance   | -9.09        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000971    |
# |    n_updates            | 1820         |
# |    policy_gradient_loss | 0.000618     |
# |    std                  | 0.548        |
# |    value_loss           | 5.02e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1173        |
# |    iterations           | 184         |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.011051556 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.814      |
# |    explained_variance   | -0.0163     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00881    |
# |    n_updates            | 1830        |
# |    policy_gradient_loss | -0.00359    |
# |    std                  | 0.545       |
# |    value_loss           | 4.43e-06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1174        |
# |    iterations           | 185         |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 189440      |
# | train/                  |             |
# |    approx_kl            | 0.008584807 |
# |    clip_fraction        | 0.0691      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.81       |
# |    explained_variance   | -3.1        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00161     |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | -0.00638    |
# |    std                  | 0.542       |
# |    value_loss           | 4.39e-06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1175        |
# |    iterations           | 186         |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.008448213 |
# |    clip_fraction        | 0.0618      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.805      |
# |    explained_variance   | -0.699      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00728     |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | -0.00228    |
# |    std                  | 0.541       |
# |    value_loss           | 4.49e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1176         |
# |    iterations           | 187          |
# |    time_elapsed         | 162          |
# |    total_timesteps      | 191488       |
# | train/                  |              |
# |    approx_kl            | 0.0040612575 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.803       |
# |    explained_variance   | -1.4         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00988     |
# |    n_updates            | 1860         |
# |    policy_gradient_loss | -0.00181     |
# |    std                  | 0.54         |
# |    value_loss           | 4.14e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1177         |
# |    iterations           | 188          |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0036171214 |
# |    clip_fraction        | 0.0703       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.796       |
# |    explained_variance   | -0.0193      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00332     |
# |    n_updates            | 1870         |
# |    policy_gradient_loss | -0.0032      |
# |    std                  | 0.533        |
# |    value_loss           | 8.96e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1177        |
# |    iterations           | 189         |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 193536      |
# | train/                  |             |
# |    approx_kl            | 0.005575602 |
# |    clip_fraction        | 0.0536      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.785      |
# |    explained_variance   | -1.28       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00329     |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | -0.00301    |
# |    std                  | 0.529       |
# |    value_loss           | 8.5e-06     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1178        |
# |    iterations           | 190         |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.005069891 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.783      |
# |    explained_variance   | -0.784      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00725    |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.00643    |
# |    std                  | 0.53        |
# |    value_loss           | 3.86e-06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1179        |
# |    iterations           | 191         |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 195584      |
# | train/                  |             |
# |    approx_kl            | 0.005102026 |
# |    clip_fraction        | 0.0815      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.78       |
# |    explained_variance   | -0.164      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.013      |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | -0.00724    |
# |    std                  | 0.523       |
# |    value_loss           | 2.68e-05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1180         |
# |    iterations           | 192          |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0075633186 |
# |    clip_fraction        | 0.0493       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.766       |
# |    explained_variance   | 0.345        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00467      |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | -0.00231     |
# |    std                  | 0.517        |
# |    value_loss           | 2.34e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1180         |
# |    iterations           | 193          |
# |    time_elapsed         | 167          |
# |    total_timesteps      | 197632       |
# | train/                  |              |
# |    approx_kl            | 0.0074889837 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.757       |
# |    explained_variance   | -1.96        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00259     |
# |    n_updates            | 1920         |
# |    policy_gradient_loss | -0.000555    |
# |    std                  | 0.516        |
# |    value_loss           | 1.65e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1181        |
# |    iterations           | 194         |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.002015205 |
# |    clip_fraction        | 0.0251      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.753      |
# |    explained_variance   | -0.683      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00679    |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | -0.0013     |
# |    std                  | 0.511       |
# |    value_loss           | 1.47e-06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1182        |
# |    iterations           | 195         |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 199680      |
# | train/                  |             |
# |    approx_kl            | 0.007096169 |
# |    clip_fraction        | 0.066       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.742      |
# |    explained_variance   | 0.561       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00737    |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | -0.00524    |
# |    std                  | 0.506       |
# |    value_loss           | 1.91e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1183         |
# |    iterations           | 196          |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0025700508 |
# |    clip_fraction        | 0.0442       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.737       |
# |    explained_variance   | 0.678        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00796      |
# |    n_updates            | 1950         |
# |    policy_gradient_loss | -0.0013      |
# |    std                  | 0.507        |
# |    value_loss           | 2.12e-05     |
# ------------------------------------------
# Training finished.
# Saved model -> runs/ppo_baseline/ppo_acc.zip
# Saved VecNormalize -> runs/ppo_baseline/vecnormalize.pkl
# Loaded model and VecNormalize for evaluation.
# Running 3 smoke-check episodes ...
# Episode 0: return=-24.998, collision=False, steps=400
# Episode 1: return=-27.891, collision=False, steps=400
# Episode 2: return=-1.064, collision=False, steps=400
#
# Done. You now have:
#  - runs/ppo_baseline/ppo_acc.zip
#  - runs/ppo_baseline/vecnormalize.pkl
# These artifacts will be loaded by your attacks notebook.
# Imported ACCEnv from acc_env.py
# Loading saved model/env from runs/ppo_baseline ...
# Loaded saved PPO and VecNormalize.
#
# ✅ model and env are ready in this kernel.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 172
#     167 if not (os.path.exists(VEC_PATH) and os.path.exists(MDL_PATH)):
#     168     raise FileNotFoundError(
#     169         f"Missing saved artifacts:\n - {VEC_PATH}\n - {MDL_PATH}\nTrain first (longer run for paper-like numbers)."
#     170     )
# --> 172 base_eval = DummyVecEnv([make_env(seed=SEED, with_braking=True, normalize_obs=False)])
#     173 env = VecNormalize.load(VEC_PATH, base_eval)
#     174 env.training = False
#
# File /opt/miniconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:30, in DummyVecEnv.__init__(self, env_fns)
#      29 def __init__(self, env_fns: List[Callable[[], gym.Env]]):
# ---> 30     self.envs = [_patch_env(fn()) for fn in env_fns]
#      31     if len(set([id(env.unwrapped) for env in self.envs])) != len(self.envs):
#      32         raise ValueError(
#      33             "You tried to create multiple environments, but the function to create them returned the same instance "
#      34             "instead of creating different objects. "
#    (...)
#      39             "Please read https://github.com/DLR-RM/stable-baselines3/issues/1151 for more information."
#      40         )
#
# Cell In[1], line 29, in make_env.<locals>._thunk()
#      28 def _thunk():
# ---> 29     env = ACCEnv(normalize_obs=normalize_obs, seed=seed)
#      30     if with_braking:
#      31         # Paper-consistent "critical event": a_l = -2.0 m/s^2 for 3 s (Δt=0.1 -> 30 steps)
#      32         def lead_profile(step):
#
# NameError: name 'ACCEnv' is not defined
