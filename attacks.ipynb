# %%
# %run ./acc_env.ipynb   # executes the notebook and defines ACCEnv in this kernel

# now this works
env = ACCEnv()
# Out:
# Requirement already satisfied: stable-baselines3[extra] in /opt/miniconda3/lib/python3.12/site-packages (2.4.1)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /opt/miniconda3/lib/python3.12/site-packages (from stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: numpy<2.0,>=1.20 in /opt/miniconda3/lib/python3.12/site-packages (from stable-baselines3[extra]) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /opt/miniconda3/lib/python3.12/site-packages (from stable-baselines3[extra]) (2.2.2)
# Requirement already satisfied: cloudpickle in /opt/miniconda3/lib/python3.12/site-packages (from stable-baselines3[extra]) (3.1.1)
# Requirement already satisfied: pandas in /opt/miniconda3/lib/python3.12/site-packages (from stable-baselines3[extra]) (2.2.3)
# Requirement already satisfied: matplotlib in /opt/miniconda3/lib/python3.12/site-packages (from stable-baselines3[extra]) (3.9.2)
# Requirement already satisfied: opencv-python in /opt/miniconda3/lib/python3.12/site-packages (from stable-baselines3[extra]) (4.10.0.84)
# Requirement already satisfied: pygame in /opt/miniconda3/lib/python3.12/site-packages (from stable-baselines3[extra]) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /opt/miniconda3/lib/python3.12/site-packages (from stable-baselines3[extra]) (2.18.0)
# Requirement already satisfied: psutil in /opt/miniconda3/lib/python3.12/site-packages (from stable-baselines3[extra]) (6.1.0)
# Requirement already satisfied: tqdm in /opt/miniconda3/lib/python3.12/site-packages (from stable-baselines3[extra]) (4.66.4)
# Requirement already satisfied: rich in /opt/miniconda3/lib/python3.12/site-packages (from stable-baselines3[extra]) (13.9.4)
# Requirement already satisfied: ale-py>=0.9.0 in /opt/miniconda3/lib/python3.12/site-packages (from stable-baselines3[extra]) (0.11.2)
# Requirement already satisfied: pillow in /opt/miniconda3/lib/python3.12/site-packages (from stable-baselines3[extra]) (11.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/miniconda3/lib/python3.12/site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3[extra]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/miniconda3/lib/python3.12/site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: absl-py>=0.4 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.74.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.7)
# Requirement already satisfied: packaging in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (25.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (72.1.0)
# Requirement already satisfied: six>1.9 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.1.3)
# Requirement already satisfied: filelock in /opt/miniconda3/lib/python3.12/site-packages (from torch>=1.13->stable-baselines3[extra]) (3.16.1)
# Requirement already satisfied: sympy in /opt/miniconda3/lib/python3.12/site-packages (from torch>=1.13->stable-baselines3[extra]) (1.13.3)
# Requirement already satisfied: networkx in /opt/miniconda3/lib/python3.12/site-packages (from torch>=1.13->stable-baselines3[extra]) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/miniconda3/lib/python3.12/site-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.4)
# Requirement already satisfied: fsspec in /opt/miniconda3/lib/python3.12/site-packages (from torch>=1.13->stable-baselines3[extra]) (2024.10.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/miniconda3/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/miniconda3/lib/python3.12/site-packages (from matplotlib->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/miniconda3/lib/python3.12/site-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/miniconda3/lib/python3.12/site-packages (from matplotlib->stable-baselines3[extra]) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/miniconda3/lib/python3.12/site-packages (from matplotlib->stable-baselines3[extra]) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/miniconda3/lib/python3.12/site-packages (from matplotlib->stable-baselines3[extra]) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/miniconda3/lib/python3.12/site-packages (from matplotlib->stable-baselines3[extra]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/lib/python3.12/site-packages (from pandas->stable-baselines3[extra]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/lib/python3.12/site-packages (from pandas->stable-baselines3[extra]) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/miniconda3/lib/python3.12/site-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/miniconda3/lib/python3.12/site-packages (from rich->stable-baselines3[extra]) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/miniconda3/lib/python3.12/site-packages (from sympy->torch>=1.13->stable-baselines3[extra]) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pip in /opt/miniconda3/lib/python3.12/site-packages (25.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping tf2onnx as it is not installed.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gymnasium>=0.29 in /opt/miniconda3/lib/python3.12/site-packages (1.0.0)
# Requirement already satisfied: numpy<2.0 in /opt/miniconda3/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: torch<2.4,>=2.1 in /opt/miniconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: matplotlib in /opt/miniconda3/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: protobuf<=3.20.3 in /opt/miniconda3/lib/python3.12/site-packages (3.20.3)
# Requirement already satisfied: stable-baselines3[extra] in /opt/miniconda3/lib/python3.12/site-packages (2.4.1)
# Requirement already satisfied: filelock in /opt/miniconda3/lib/python3.12/site-packages (from torch<2.4,>=2.1) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/miniconda3/lib/python3.12/site-packages (from torch<2.4,>=2.1) (4.12.2)
# Requirement already satisfied: sympy in /opt/miniconda3/lib/python3.12/site-packages (from torch<2.4,>=2.1) (1.13.3)
# Requirement already satisfied: networkx in /opt/miniconda3/lib/python3.12/site-packages (from torch<2.4,>=2.1) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/miniconda3/lib/python3.12/site-packages (from torch<2.4,>=2.1) (3.1.4)
# Requirement already satisfied: fsspec in /opt/miniconda3/lib/python3.12/site-packages (from torch<2.4,>=2.1) (2024.10.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/miniconda3/lib/python3.12/site-packages (from gymnasium>=0.29) (3.1.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/miniconda3/lib/python3.12/site-packages (from gymnasium>=0.29) (0.0.4)
# Requirement already satisfied: pandas in /opt/miniconda3/lib/python3.12/site-packages (from stable-baselines3[extra]) (2.2.3)
# Requirement already satisfied: opencv-python in /opt/miniconda3/lib/python3.12/site-packages (from stable-baselines3[extra]) (4.10.0.84)
# Requirement already satisfied: pygame in /opt/miniconda3/lib/python3.12/site-packages (from stable-baselines3[extra]) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /opt/miniconda3/lib/python3.12/site-packages (from stable-baselines3[extra]) (2.18.0)
# Requirement already satisfied: psutil in /opt/miniconda3/lib/python3.12/site-packages (from stable-baselines3[extra]) (6.1.0)
# Requirement already satisfied: tqdm in /opt/miniconda3/lib/python3.12/site-packages (from stable-baselines3[extra]) (4.66.4)
# Requirement already satisfied: rich in /opt/miniconda3/lib/python3.12/site-packages (from stable-baselines3[extra]) (13.9.4)
# Requirement already satisfied: ale-py>=0.9.0 in /opt/miniconda3/lib/python3.12/site-packages (from stable-baselines3[extra]) (0.11.2)
# Requirement already satisfied: pillow in /opt/miniconda3/lib/python3.12/site-packages (from stable-baselines3[extra]) (11.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/miniconda3/lib/python3.12/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/miniconda3/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/miniconda3/lib/python3.12/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/miniconda3/lib/python3.12/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/miniconda3/lib/python3.12/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/miniconda3/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: absl-py>=0.4 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.74.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.7)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (72.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/miniconda3/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/lib/python3.12/site-packages (from pandas->stable-baselines3[extra]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/lib/python3.12/site-packages (from pandas->stable-baselines3[extra]) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/miniconda3/lib/python3.12/site-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/miniconda3/lib/python3.12/site-packages (from rich->stable-baselines3[extra]) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/miniconda3/lib/python3.12/site-packages (from sympy->torch<2.4,>=2.1) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# reset obs: [-0.6276754  -0.01029736  0.01372979] info: {}
# t=0: reward=-0.035, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.255947152615294, 'Δx': 37.21186178029772}
# t=1: reward=-0.049, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.305947152615294, 'Δx': 37.18626706503619}
# t=2: reward=-0.066, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.355947152615295, 'Δx': 37.15567234977466}
# t=3: reward=-0.085, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.405947152615296, 'Δx': 37.12007763451313}
# t=4: reward=-0.106, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.455947152615297, 'Δx': 37.0794829192516}
# t=5: reward=-0.130, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.505947152615297, 'Δx': 37.033888203990074}
# t=6: reward=-0.157, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.555947152615298, 'Δx': 36.98329348872854}
# t=7: reward=-0.186, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.605947152615299, 'Δx': 36.927698773467014}
# t=8: reward=-0.218, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.6559471526153, 'Δx': 36.867104058205484}
# t=9: reward=-0.252, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.7059471526153, 'Δx': 36.80150934294395}
# t=10: reward=-0.288, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.7559471526153, 'Δx': 36.730914627682424}
# t=11: reward=-0.327, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.805947152615301, 'Δx': 36.65531991242089}
# t=12: reward=-0.369, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.855947152615302, 'Δx': 36.57472519715936}
# t=13: reward=-0.413, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.905947152615303, 'Δx': 36.48913048189783}
# t=14: reward=-0.459, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.955947152615304, 'Δx': 36.3985357666363}
# t=15: reward=-0.508, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.005947152615303, 'Δx': 36.30294105137477}
# t=16: reward=-0.560, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.055947152615303, 'Δx': 36.20234633611324}
# t=17: reward=-0.614, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.105947152615304, 'Δx': 36.096751620851705}
# t=18: reward=-0.671, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.155947152615305, 'Δx': 35.98615690559018}
# t=19: reward=-0.730, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.205947152615305, 'Δx': 35.87056219032865}
# t=20: reward=-0.791, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.255947152615306, 'Δx': 35.749967475067116}
# t=21: reward=-0.855, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.305947152615307, 'Δx': 35.62437275980559}
# t=22: reward=-0.922, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.355947152615308, 'Δx': 35.49377804454406}
# t=23: reward=-0.991, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.40594715261531, 'Δx': 35.358183329282525}
# t=24: reward=-1.062, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.45594715261531, 'Δx': 35.217588614021}
# t=25: reward=-1.136, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.50594715261531, 'Δx': 35.071993898759466}
# t=26: reward=-1.213, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.55594715261531, 'Δx': 34.92139918349793}
# t=27: reward=-1.292, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.60594715261531, 'Δx': 34.765804468236404}
# t=28: reward=-1.374, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.655947152615312, 'Δx': 34.60520975297487}
# t=29: reward=-1.458, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.705947152615312, 'Δx': 34.43961503771334}
# t=30: reward=-1.544, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.755947152615313, 'Δx': 34.26902032245181}
# t=31: reward=-1.633, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.805947152615314, 'Δx': 34.09342560719028}
# t=32: reward=-1.725, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.855947152615315, 'Δx': 33.91283089192874}
# t=33: reward=-1.819, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.905947152615315, 'Δx': 33.72723617666721}
# t=34: reward=-1.915, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.955947152615316, 'Δx': 33.53664146140568}
# t=35: reward=-2.014, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.005947152615317, 'Δx': 33.341046746144144}
# t=36: reward=-2.116, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.055947152615317, 'Δx': 33.140452030882614}
# t=37: reward=-2.220, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.105947152615318, 'Δx': 32.93485731562108}
# t=38: reward=-2.327, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.15594715261532, 'Δx': 32.72426260035955}
# t=39: reward=-2.436, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.20594715261532, 'Δx': 32.50866788509802}
# t=40: reward=-2.547, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.25594715261532, 'Δx': 32.288073169836494}
# t=41: reward=-2.661, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.30594715261532, 'Δx': 32.06247845457496}
# t=42: reward=-2.778, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.35594715261532, 'Δx': 31.831883739313426}
# t=43: reward=-2.897, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.405947152615322, 'Δx': 31.5962890240519}
# t=44: reward=-3.018, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.455947152615323, 'Δx': 31.355694308790362}
# t=45: reward=-3.187, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.505947152615324, 'Δx': 31.11009959352883}
# t=46: reward=-3.719, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.555947152615325, 'Δx': 30.859504878267302}
# t=47: reward=-4.694, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.605947152615325, 'Δx': 30.603910163005764}
# t=48: reward=-6.131, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.655947152615326, 'Δx': 30.34331544774423}
# t=49: reward=-8.051, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.705947152615327, 'Δx': 30.077720732482703}
# t=50: reward=-10.474, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.755947152615327, 'Δx': 29.807126017221165}
# t=51: reward=-13.421, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.805947152615328, 'Δx': 29.53153130195963}
# t=52: reward=-16.913, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.85594715261533, 'Δx': 29.250936586698103}
# t=53: reward=-20.970, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.90594715261533, 'Δx': 28.965341871436564}
# t=54: reward=-25.616, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.95594715261533, 'Δx': 28.67474715617503}
# t=55: reward=-30.871, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 18.00594715261533, 'Δx': 28.3791524409135}
# t=56: reward=-36.758, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 18.05594715261533, 'Δx': 28.07855772565196}
# t=57: reward=-43.299, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 18.105947152615332, 'Δx': 27.772963010390427}
# t=58: reward=-50.518, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 18.155947152615333, 'Δx': 27.462368295128897}
# t=59: reward=-54.802, term=False, trunc=False, info={'collision': False, 'a': -0.5809659570575106, 'v': 18.09785055690958, 'Δx': 27.146773579867357}
# t=60: reward=-54.223, term=False, trunc=False, info={'collision': False, 'a': -2.0652464443481535, 'v': 17.891325912474766, 'Δx': 26.83698852417639}
# t=61: reward=-53.678, term=False, trunc=False, info={'collision': False, 'a': -1.9275314317599486, 'v': 17.69857276929877, 'Δx': 26.54785593292891}
# t=62: reward=-53.204, term=False, trunc=False, info={'collision': False, 'a': -1.7990675362613013, 'v': 17.51866601567264, 'Δx': 26.277998655999028}
# t=63: reward=-52.791, term=False, trunc=False, info={'collision': False, 'a': -1.679123289700293, 'v': 17.35075368670261, 'Δx': 26.02613205443177}
# t=64: reward=-52.431, term=False, trunc=False, info={'collision': False, 'a': -1.567169084975186, 'v': 17.194036778205092, 'Δx': 25.791056685761504}
# t=65: reward=-52.118, term=False, trunc=False, info={'collision': False, 'a': -1.4626846927810628, 'v': 17.047768308926987, 'Δx': 25.571653007940995}
# t=66: reward=-51.845, term=False, trunc=False, info={'collision': False, 'a': -1.3651533806185994, 'v': 16.911252970865128, 'Δx': 25.366876177048297}
# t=67: reward=-51.607, term=False, trunc=False, info={'collision': False, 'a': -1.274174923193026, 'v': 16.783835478545825, 'Δx': 25.175750879961782}
# t=68: reward=-51.400, term=False, trunc=False, info={'collision': False, 'a': -1.1892491183587337, 'v': 16.664910566709953, 'Δx': 24.997367332107203}
# t=69: reward=-51.220, term=False, trunc=False, info={'collision': False, 'a': -1.109946653756242, 'v': 16.553915901334328, 'Δx': 24.83087627543621}
# t=70: reward=-51.062, term=False, trunc=False, info={'collision': False, 'a': -1.0359120473078085, 'v': 16.45032469660355, 'Δx': 24.675484685302777}
# t=71: reward=-50.926, term=False, trunc=False, info={'collision': False, 'a': -0.9668830385939057, 'v': 16.353636392744157, 'Δx': 24.530452215642427}
# t=72: reward=-50.806, term=False, trunc=False, info={'collision': False, 'a': -0.9024305536736157, 'v': 16.263393337376794, 'Δx': 24.39508857636801}
# t=73: reward=-50.702, term=False, trunc=False, info={'collision': False, 'a': -0.8422621324427377, 'v': 16.17916712413252, 'Δx': 24.268749242630335}
# t=74: reward=-50.612, term=False, trunc=False, info={'collision': False, 'a': -0.786143171035076, 'v': 16.10055280702901, 'Δx': 24.150832530217087}
# t=75: reward=-50.533, term=False, trunc=False, info={'collision': False, 'a': -0.73369545813653, 'v': 16.02718326121536, 'Δx': 24.040777249514193}
# t=76: reward=-50.464, term=False, trunc=False, info={'collision': False, 'a': -0.6847761015548842, 'v': 15.958705651059871, 'Δx': 23.938058923392646}
# t=77: reward=-50.404, term=False, trunc=False, info={'collision': False, 'a': -0.6391243508548448, 'v': 15.894793215974387, 'Δx': 23.84218835828665}
# t=78: reward=-50.352, term=False, trunc=False, info={'collision': False, 'a': -0.5965573787348588, 'v': 15.8351374781009, 'Δx': 23.752709036689197}
# t=79: reward=-50.307, term=False, trunc=False, info={'collision': False, 'a': -0.5567551082738212, 'v': 15.779461967273518, 'Δx': 23.66919528887911}
# t=80: reward=-50.267, term=False, trunc=False, info={'collision': False, 'a': -0.5196253906970524, 'v': 15.727499428203812, 'Δx': 23.59124909215177}
# t=81: reward=-50.233, term=False, trunc=False, info={'collision': False, 'a': -0.48499322677915835, 'v': 15.679000105525896, 'Δx': 23.518499149331376}
# t=82: reward=-50.203, term=False, trunc=False, info={'collision': False, 'a': -0.45268258414763807, 'v': 15.633731847111132, 'Δx': 23.450599138778784}
# t=83: reward=-50.177, term=False, trunc=False, info={'collision': False, 'a': -0.4224624352147439, 'v': 15.591485603589659, 'Δx': 23.387225954067674}
# t=84: reward=-50.154, term=False, trunc=False, info={'collision': False, 'a': -0.3943555092168349, 'v': 15.552050052667976, 'Δx': 23.328077393708696}
# t=85: reward=-50.134, term=False, trunc=False, info={'collision': False, 'a': -0.3680142713616096, 'v': 15.515248625531814, 'Δx': 23.272872388441897}
# t=86: reward=-50.117, term=False, trunc=False, info={'collision': False, 'a': -0.3434958626313834, 'v': 15.480899039268676, 'Δx': 23.221347525888717}
# t=87: reward=-50.102, term=False, trunc=False, info={'collision': False, 'a': -0.32058979917127167, 'v': 15.448840059351548, 'Δx': 23.173257621961852}
# t=88: reward=-50.089, term=False, trunc=False, info={'collision': False, 'a': -0.2992298800935573, 'v': 15.418917071342193, 'Δx': 23.128373616026693}
# t=89: reward=-50.077, term=False, trunc=False, info={'collision': False, 'a': -0.2792970947987728, 'v': 15.390987361862315, 'Δx': 23.086481908892466}
# t=90: reward=-50.067, term=False, trunc=False, info={'collision': False, 'a': -0.2606455112580218, 'v': 15.364922810736513, 'Δx': 23.047383172706247}
# t=91: reward=-50.059, term=False, trunc=False, info={'collision': False, 'a': -0.2432914214064569, 'v': 15.340593668595867, 'Δx': 23.010890891632584}
# t=92: reward=-50.051, term=False, trunc=False, info={'collision': False, 'a': -0.2270560907945272, 'v': 15.317888059516415, 'Δx': 22.97683152477299}
# t=93: reward=-50.044, term=False, trunc=False, info={'collision': False, 'a': -0.2119190154257969, 'v': 15.296696157973836, 'Δx': 22.945042718821355}
# t=94: reward=-50.039, term=False, trunc=False, info={'collision': False, 'a': -0.19778470866570164, 'v': 15.276917687107266, 'Δx': 22.915373103023967}
# t=95: reward=-50.034, term=False, trunc=False, info={'collision': False, 'a': -0.1846213217678396, 'v': 15.258455554930482, 'Δx': 22.887681334313243}
# t=96: reward=-50.029, term=False, trunc=False, info={'collision': False, 'a': -0.172297327158175, 'v': 15.241225822214664, 'Δx': 22.861835778820193}
# t=97: reward=-50.026, term=False, trunc=False, info={'collision': False, 'a': -0.16081720511887476, 'v': 15.225144101702776, 'Δx': 22.837713196598713}
# t=98: reward=-50.022, term=False, trunc=False, info={'collision': False, 'a': -0.15013102682916057, 'v': 15.21013099901986, 'Δx': 22.815198786428425}
# t=99: reward=-50.019, term=False, trunc=False, info={'collision': False, 'a': -0.14008097906840308, 'v': 15.19612290111302, 'Δx': 22.794185686526447}
# t=100: reward=-50.017, term=False, trunc=False, info={'collision': False, 'a': -0.13072951756605564, 'v': 15.183049949356414, 'Δx': 22.77457339641515}
# t=101: reward=-50.015, term=False, trunc=False, info={'collision': False, 'a': -0.12201421639498526, 'v': 15.170848527716917, 'Δx': 22.756268401479502}
# t=102: reward=-50.013, term=False, trunc=False, info={'collision': False, 'a': -0.11393716171762, 'v': 15.159454811545155, 'Δx': 22.739183548707814}
# t=103: reward=-50.011, term=False, trunc=False, info={'collision': False, 'a': -0.10629048234916376, 'v': 15.148825763310239, 'Δx': 22.723238067553297}
# t=104: reward=-50.010, term=False, trunc=False, info={'collision': False, 'a': -0.09920763308037166, 'v': 15.138905000002202, 'Δx': 22.708355491222278}
# t=105: reward=-50.009, term=False, trunc=False, info={'collision': False, 'a': -0.09260333953846998, 'v': 15.129644666048355, 'Δx': 22.69446499122205}
# t=106: reward=-50.007, term=False, trunc=False, info={'collision': False, 'a': -0.0864106955141588, 'v': 15.121003596496939, 'Δx': 22.681500524617206}
# t=107: reward=-50.006, term=False, trunc=False, info={'collision': False, 'a': -0.08070403296157125, 'v': 15.112933193200782, 'Δx': 22.6694001649675}
# t=108: reward=-50.006, term=False, trunc=False, info={'collision': False, 'a': -0.07529197628025312, 'v': 15.105403995572756, 'Δx': 22.65810684564741}
# t=109: reward=-50.005, term=False, trunc=False, info={'collision': False, 'a': -0.0702439003050443, 'v': 15.09837960554225, 'Δx': 22.64756644609014}
# t=110: reward=-50.004, term=False, trunc=False, info={'collision': False, 'a': -0.06560547709195907, 'v': 15.091819057833055, 'Δx': 22.637728485535916}
# t=111: reward=-50.004, term=False, trunc=False, info={'collision': False, 'a': -0.061228599042711926, 'v': 15.085696197928783, 'Δx': 22.628546579752623}
# t=112: reward=-50.003, term=False, trunc=False, info={'collision': False, 'a': -0.057121263113277074, 'v': 15.079984071617455, 'Δx': 22.619976959959757}
# t=113: reward=-50.003, term=False, trunc=False, info={'collision': False, 'a': -0.05333225073509736, 'v': 15.074650846543944, 'Δx': 22.611978552798007}
# t=114: reward=-50.002, term=False, trunc=False, info={'collision': False, 'a': -0.04976405368287452, 'v': 15.069674441175657, 'Δx': 22.604513468143608}
# t=115: reward=-50.002, term=False, trunc=False, info={'collision': False, 'a': -0.04644009161339025, 'v': 15.065030432014318, 'Δx': 22.59754602402603}
# t=116: reward=-50.002, term=False, trunc=False, info={'collision': False, 'a': -0.04335044532100445, 'v': 15.060695387482218, 'Δx': 22.591042980824596}
# t=117: reward=-50.002, term=False, trunc=False, info={'collision': False, 'a': -0.04047630705801746, 'v': 15.056647756776416, 'Δx': 22.584973442076375}
# t=118: reward=-50.001, term=False, trunc=False, info={'collision': False, 'a': -0.037742920187230404, 'v': 15.052873464757692, 'Δx': 22.57930866639873}
# t=119: reward=-50.001, term=False, trunc=False, info={'collision': False, 'a': -0.03524261974782529, 'v': 15.04934920278291, 'Δx': 22.574021319922963}
# t=120: reward=-50.001, term=False, trunc=False, info={'collision': False, 'a': -0.03291854539600393, 'v': 15.046057348243309, 'Δx': 22.569086399644675}
# t=121: reward=-50.001, term=False, trunc=False, info={'collision': False, 'a': -0.030720793146255084, 'v': 15.042985268928684, 'Δx': 22.564480664820337}
# t=122: reward=-50.001, term=False, trunc=False, info={'collision': False, 'a': -0.02861551998023685, 'v': 15.04012371693066, 'Δx': 22.560182137927455}
# t=123: reward=-50.001, term=False, trunc=False, info={'collision': False, 'a': -0.026758681440606998, 'v': 15.037447848786599, 'Δx': 22.556169766234376}
# t=124: reward=-50.001, term=False, trunc=False, info={'collision': False, 'a': -0.024993842664054643, 'v': 15.034948464520193, 'Δx': 22.552424981355728}
# t=125: reward=-50.001, term=False, trunc=False, info={'collision': False, 'a': -0.02327990376722028, 'v': 15.03262047414347, 'Δx': 22.548930134903713}
# t=126: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.021743805250324735, 'v': 15.030446093618439, 'Δx': 22.54566808748936}
# t=127: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.02031965045767162, 'v': 15.028414128572672, 'Δx': 22.542623478127524}
# t=128: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.018910964311069912, 'v': 15.026523032141565, 'Δx': 22.53978206527026}
# t=129: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.017685201081798718, 'v': 15.024754512033384, 'Δx': 22.53712976205611}
# t=130: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.016512546829245228, 'v': 15.02310325735046, 'Δx': 22.534654310852773}
# t=131: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.015395816630923981, 'v': 15.021563675687368, 'Δx': 22.532343985117734}
# t=132: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.01437896394237286, 'v': 15.02012577929313, 'Δx': 22.53018761754899}
# t=133: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.013433082996329724, 'v': 15.018782470993497, 'Δx': 22.52817503961967}
# t=134: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.012499396166383944, 'v': 15.017532531376858, 'Δx': 22.526296792520327}
# t=135: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.011713788374166655, 'v': 15.016361152539442, 'Δx': 22.52454353938265}
# t=136: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.01090743692518701, 'v': 15.015270408846924, 'Δx': 22.522907424128704}
# t=137: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.010154843895157141, 'v': 15.014254924457408, 'Δx': 22.521380383244008}
# t=138: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.009531895925924473, 'v': 15.013301734864815, 'Δx': 22.51995489079826}
# t=139: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.008867825721591999, 'v': 15.012414952292655, 'Δx': 22.51862471731178}
# t=140: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.008270279884329351, 'v': 15.011587924304223, 'Δx': 22.517383222082515}
# t=141: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.007715748729511964, 'v': 15.010816349431272, 'Δx': 22.516224429652084}
# t=142: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.007191828903917999, 'v': 15.01009716654088, 'Δx': 22.515142794708964}
# t=143: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0067568783179457696, 'v': 15.009421478709086, 'Δx': 22.51413307805487}
# t=144: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0062587362577352125, 'v': 15.008795605083312, 'Δx': 22.513190930183953}
# t=145: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.005866918321726497, 'v': 15.00820891325114, 'Δx': 22.512311369675615}
# t=146: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00549804258449138, 'v': 15.00765910899269, 'Δx': 22.51149047835051}
# t=147: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.005109254240615916, 'v': 15.00714818356863, 'Δx': 22.510724567451234}
# t=148: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.004743206308969669, 'v': 15.006673862937733, 'Δx': 22.510009749094365}
# t=149: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0044556027412310855, 'v': 15.00622830266361, 'Δx': 22.509342362800595}
# t=150: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.004155383789178644, 'v': 15.005812764284691, 'Δx': 22.50871953253423}
# t=151: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.003852926558687762, 'v': 15.005427471628822, 'Δx': 22.508138256105752}
# t=152: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.003634212296319148, 'v': 15.00506405039919, 'Δx': 22.50759550894287}
# t=153: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0033823944856835888, 'v': 15.004725810950621, 'Δx': 22.507089103902956}
# t=154: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0031410068663066597, 'v': 15.004411710263991, 'Δx': 22.50661652280789}
# t=155: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.002934785674561925, 'v': 15.004118231696534, 'Δx': 22.50617535178148}
# t=156: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00273913313068935, 'v': 15.003844318383464, 'Δx': 22.505763528611823}
# t=157: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0025660611220146745, 'v': 15.003587712271264, 'Δx': 22.50537909677348}
# t=158: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0024108849410794677, 'v': 15.003346623777157, 'Δx': 22.505020325546354}
# t=159: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0022279067652798768, 'v': 15.003123833100629, 'Δx': 22.50468566316863}
# t=160: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0020698428636741605, 'v': 15.002916848814262, 'Δx': 22.504373279858555}
# t=161: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0019731791926743446, 'v': 15.002719530894995, 'Δx': 22.50408159497715}
# t=162: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0018130238511463292, 'v': 15.00253822850988, 'Δx': 22.503809641887642}
# t=163: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0016730820886506255, 'v': 15.002370920301015, 'Δx': 22.50355581903665}
# t=164: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0015869744926690504, 'v': 15.002212222851748, 'Δx': 22.503318727006558}
# t=165: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0014875340835981345, 'v': 15.002063469443389, 'Δx': 22.50309750472138}
# t=166: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0013756496535556658, 'v': 15.001925904478034, 'Δx': 22.502891157777015}
# t=167: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0012489714758425385, 'v': 15.00180100733045, 'Δx': 22.50269856732922}
# t=168: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0012261061111762243, 'v': 15.001678396719331, 'Δx': 22.5025184665962}
# t=169: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.001118934405877772, 'v': 15.001566503278744, 'Δx': 22.502350626924283}
# t=170: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0010475177240394308, 'v': 15.001461751506339, 'Δx': 22.502193976596402}
# t=171: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0009586096412626861, 'v': 15.001365890542212, 'Δx': 22.50204780144577}
# t=172: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.000923312518037901, 'v': 15.001273559290409, 'Δx': 22.501911212391576}
# t=173: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0008522217214687351, 'v': 15.001188337118261, 'Δx': 22.50178385646251}
# t=174: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0007731545356308196, 'v': 15.001111021664698, 'Δx': 22.50166502275067}
# t=175: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0007502211068108815, 'v': 15.001035999554018, 'Δx': 22.50155392058423}
# t=176: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0006970274573547434, 'v': 15.000966296808283, 'Δx': 22.501450320628805}
# t=177: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0006283066049442266, 'v': 15.000903466147788, 'Δx': 22.50135369094795}
# t=178: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0005927773107780894, 'v': 15.00084418841671, 'Δx': 22.501263344333154}
# t=179: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0005977636115101606, 'v': 15.000784412055559, 'Δx': 22.5011789254915}
# t=180: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0005261235674892317, 'v': 15.00073179969881, 'Δx': 22.501100484285928}
# t=181: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00047833302439462554, 'v': 15.000683966396371, 'Δx': 22.50102730431604}
# t=182: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0004400863251624571, 'v': 15.000639957763855, 'Δx': 22.50095890767642}
# t=183: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0004171051272586472, 'v': 15.00059824725113, 'Δx': 22.500894911900048}
# t=184: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00040201374443502654, 'v': 15.000558045876687, 'Δx': 22.50083508717495}
# t=185: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00036885497650410886, 'v': 15.000521160379037, 'Δx': 22.500779282587303}
# t=186: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00036651704655682774, 'v': 15.000484508674381, 'Δx': 22.50072716654938}
# t=187: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00031029341691639155, 'v': 15.00045347933269, 'Δx': 22.500678715681943}
# t=188: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0002896071917089724, 'v': 15.000424518613519, 'Δx': 22.500633367748662}
# t=189: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0003052681170541082, 'v': 15.000393991801813, 'Δx': 22.5005909158873}
# t=190: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00024676992620234744, 'v': 15.000369314809193, 'Δx': 22.500551516707105}
# t=191: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0002621077408432933, 'v': 15.000343104035109, 'Δx': 22.5005145852262}
# t=192: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00022873932833429526, 'v': 15.000320230102275, 'Δx': 22.500480274822678}
# t=193: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00022620572364662173, 'v': 15.00029760952991, 'Δx': 22.50044825181243}
# t=194: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00017297837195706165, 'v': 15.000280311692714, 'Δx': 22.50041849085943}
# t=195: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00019323560673214786, 'v': 15.000260988132041, 'Δx': 22.500390459690152}
# t=196: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.0001930689000024055, 'v': 15.000241681242041, 'Δx': 22.500364360876972}
# t=197: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00013251391248555666, 'v': 15.000228429850793, 'Δx': 22.500340192752788}
# t=198: reward=-50.000, term=False, trunc=False, info={'collision': False, 'a': -0.00016500555275794347, 'v': 15.000211929295517, 'Δx': 22.500317349767727}
# t=199: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -0.00013493169363701078, 'v': 15.000198436126153, 'Δx': 22.500296156838147}
# t=200: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -0.00015772538527496511, 'v': 15.000182663587626, 'Δx': 22.500276313225527}
# t=201: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -0.00010906339594436624, 'v': 15.000171757248031, 'Δx': 22.500258046866747}
# t=202: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -0.00010179249318013233, 'v': 15.000161577998714, 'Δx': 22.500240871141955}
# t=203: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -0.00011725874301632141, 'v': 15.000149852124412, 'Δx': 22.500224713342106}
# t=204: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -0.00010944149348189997, 'v': 15.000138907975064, 'Δx': 22.500209728129676}
# t=205: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.35351592173318e-05, 'v': 15.000131554459141, 'Δx': 22.50019583733217}
# t=206: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -8.13484797349035e-05, 'v': 15.000123419611167, 'Δx': 22.50018268188626}
# t=207: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -0.0001045354611088772, 'v': 15.000112966065057, 'Δx': 22.50017033992515}
# t=208: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -6.895621022109147e-05, 'v': 15.000106070444035, 'Δx': 22.50015904331866}
# t=209: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -8.661153362297601e-05, 'v': 15.000097409290673, 'Δx': 22.50014843627423}
# t=210: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.3153718416670086e-05, 'v': 15.00009409391883, 'Δx': 22.500138695345186}
# t=211: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.862718445712722e-05, 'v': 15.000086231200385, 'Δx': 22.500129285953278}
# t=212: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -6.3848628984954e-05, 'v': 15.000079846337487, 'Δx': 22.50012066283324}
# t=213: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.051856348871711e-05, 'v': 15.000075794481138, 'Δx': 22.500112678199514}
# t=214: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -6.642755318426576e-05, 'v': 15.00006915172582, 'Δx': 22.50010509875142}
# t=215: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -5.564122322671683e-05, 'v': 15.000063587603497, 'Δx': 22.500098183578814}
# t=216: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.2858324258504e-05, 'v': 15.000060301771072, 'Δx': 22.50009182481847}
# t=217: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.0667771248192294e-05, 'v': 15.000057234993946, 'Δx': 22.500085794641336}
# t=218: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.815999407637978e-05, 'v': 15.000053418994538, 'Δx': 22.50008007114195}
# t=219: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.561599204596875e-05, 'v': 15.000049857395334, 'Δx': 22.5000747292425}
# t=220: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.32415925762375e-05, 'v': 15.000046533236077, 'Δx': 22.50006974350299}
# t=221: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.056223378340609e-05, 'v': 15.000042477012698, 'Δx': 22.500065090179362}
# t=222: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -5.057373736499889e-05, 'v': 15.000037419638963, 'Δx': 22.500060842478092}
# t=223: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 1.00182993255514e-05, 'v': 15.000038421468895, 'Δx': 22.500057100514198}
# t=224: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.8333302524557326e-05, 'v': 15.000034588138643, 'Δx': 22.500053258367302}
# t=225: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3692238388934025e-06, 'v': 15.000034825061027, 'Δx': 22.500049799553437}
# t=226: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.5472437705182884e-05, 'v': 15.000030277817256, 'Δx': 22.50004631704735}
# t=227: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.2904200380862614e-05, 'v': 15.000026987397218, 'Δx': 22.500043289265648}
# t=228: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 7.436382282540531e-06, 'v': 15.000027731035447, 'Δx': 22.50004059052594}
# t=229: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -4.074308739912652e-05, 'v': 15.000023656726707, 'Δx': 22.500037817422424}
# t=230: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 1.2008845975659662e-07, 'v': 15.000023668735553, 'Δx': 22.50003545174974}
# t=231: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 1.1208126893599992e-07, 'v': 15.00002367994368, 'Δx': 22.50003308487618}
# t=232: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.804236125215426e-05, 'v': 15.000019875707556, 'Δx': 22.500030716881838}
# t=233: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.6407661969307117e-06, 'v': 15.000020139784176, 'Δx': 22.500028729311055}
# t=234: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.5682252974884125e-05, 'v': 15.000016571558879, 'Δx': 22.500026715332638}
# t=235: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.843531901283637e-06, 'v': 15.00001705591207, 'Δx': 22.500025058176732}
# t=236: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -5.01611275374827e-06, 'v': 15.000016554300794, 'Δx': 22.500023352585515}
# t=237: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.329193249829484e-05, 'v': 15.000013225107544, 'Δx': 22.500021697155432}
# t=238: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -2.462243312810633e-06, 'v': 15.000012978883213, 'Δx': 22.50002037464469}
# t=239: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -2.298092869339608e-06, 'v': 15.000012749073926, 'Δx': 22.50001907675636}
# ...
# t=895: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.862724663530733e-06, 'v': 14.999997955556346, 'Δx': 22.499999121827386}
# t=896: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 3.314877076582228e-05, 'v': 15.000001270433422, 'Δx': 22.49999932627179}
# t=897: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.328625286563657e-06, 'v': 15.000001503295952, 'Δx': 22.49999919922834}
# t=898: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.363358882012185e-06, 'v': 15.000000766960063, 'Δx': 22.499999048898644}
# t=899: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.6642741701895263e-06, 'v': 15.00000103338748, 'Δx': 22.499998972202548}
# t=900: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.566031414515055e-05, 'v': 14.999997467356065, 'Δx': 22.499998868863713}
# t=901: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.8640100826235444e-06, 'v': 14.999997953757074, 'Δx': 22.4999991221282}
# t=902: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 3.314997038925394e-05, 'v': 15.000001268754113, 'Δx': 22.49999932675246}
# t=903: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3297447986756803e-06, 'v': 15.000001501728594, 'Δx': 22.49999919987704}
# t=904: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.362314024251956e-06, 'v': 15.000000765497191, 'Δx': 22.49999904970423}
# t=905: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.6652494137140987e-06, 'v': 15.000001032022132, 'Δx': 22.49999897315456}
# t=906: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.565940404417964e-05, 'v': 14.999997466081727, 'Δx': 22.49999886995238}
# t=907: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.8648595506183694e-06, 'v': 14.999997952567682, 'Δx': 22.499999123344196}
# t=908: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 3.3150763165416136e-05, 'v': 15.000001267643999, 'Δx': 22.49999932808737}
# t=909: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.330484899939908e-06, 'v': 15.00000150069249, 'Δx': 22.499999201322908}
# t=910: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.361623263072009e-06, 'v': 15.000000764530164, 'Δx': 22.499999051253553}
# t=911: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.6658940938322266e-06, 'v': 15.000001031119574, 'Δx': 22.49999897480052}
# t=912: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.565880226189209e-05, 'v': 14.999997465239348, 'Δx': 22.499998871688604}
# t=913: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.865421163559274e-06, 'v': 14.999997951781465, 'Δx': 22.499999125164777}
# t=914: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 3.3151287337494315e-05, 'v': 15.000001266910198, 'Δx': 22.499999329986622}
# t=915: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.330974132265621e-06, 'v': 15.000001500007611, 'Δx': 22.4999992032956}
# t=916: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.361166620970937e-06, 'v': 15.000000763890949, 'Δx': 22.499999053294914}
# t=917: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.666320267862821e-06, 'v': 15.000001030522975, 'Δx': 22.499998976905772}
# t=918: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.565840450956903e-05, 'v': 14.999997464682524, 'Δx': 22.49999887385343}
# t=919: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.865792388955299e-06, 'v': 14.999997951261763, 'Δx': 22.49999912738508}
# t=920: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 3.315163385495259e-05, 'v': 15.000001266425148, 'Δx': 22.499999332258994}
# t=921: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.331297457610546e-06, 'v': 15.000001499554894, 'Δx': 22.499999205616405}
# t=922: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.3608648961237395e-06, 'v': 15.000000763468405, 'Δx': 22.499999055660965}
# t=923: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.666601945932304e-06, 'v': 15.0000010301286, 'Δx': 22.499998979314114}
# t=924: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.565814166561774e-05, 'v': 14.999997464314433, 'Δx': 22.499998876301333}
# t=925: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.866037649343526e-06, 'v': 14.999997950918198, 'Δx': 22.49999912986982}
# t=926: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 3.3151862896019715e-05, 'v': 15.000001266104487, 'Δx': 22.499999334778067}
# t=927: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.331511188851214e-06, 'v': 15.000001499255607, 'Δx': 22.499999208167537}
# t=928: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.360665337841229e-06, 'v': 15.000000763189073, 'Δx': 22.499999058241883}
# t=929: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.6667881649600774e-06, 'v': 15.000001029867889, 'Δx': 22.499998981923}
# t=930: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.5657967800558844e-05, 'v': 14.99999746407111, 'Δx': 22.49999887893614}
# t=931: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.86619984255453e-06, 'v': 14.999997950691093, 'Δx': 22.499999132528956}
# t=932: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 3.3152014326877464e-05, 'v': 15.000001265892525, 'Δx': 22.49999933745994}
# t=933: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.331652539476691e-06, 'v': 15.00000149905778, 'Δx': 22.499999210870783}
# t=934: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.360533461118263e-06, 'v': 15.000000763004433, 'Δx': 22.49999906096491}
# t=935: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.6669112120059015e-06, 'v': 15.000001029695554, 'Δx': 22.499998984664444}
# t=936: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.5657852976860396e-05, 'v': 14.999997463910256, 'Δx': 22.499998881694864}
# t=937: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.8663073145046245e-06, 'v': 14.999997950540989, 'Δx': 22.499999135303824}
# t=938: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 3.315211437128799e-05, 'v': 15.000001265752426, 'Δx': 22.499999340249815}
# t=939: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3317459900510687e-06, 'v': 15.000001498927025, 'Δx': 22.499999213674528}
# t=940: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.360446301215154e-06, 'v': 15.000000762882395, 'Δx': 22.499999063781843}
# t=941: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.6669926117762837e-06, 'v': 15.000001029581657, 'Δx': 22.499998987493655}
# t=942: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.5657776958266646e-05, 'v': 14.999997463803961, 'Δx': 22.499998884535444}
# t=943: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.8663781035041925e-06, 'v': 14.999997950441772, 'Δx': 22.49999913815509}
# t=944: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 3.315218046123191e-05, 'v': 15.000001265659819, 'Δx': 22.499999343110858}
# t=945: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.331807684104226e-06, 'v': 15.000001498840588, 'Δx': 22.499999216544893}
# t=946: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.360388624096662e-06, 'v': 15.000000762801726, 'Δx': 22.49999906666085}
# t=947: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.667046385646941e-06, 'v': 15.000001029506365, 'Δx': 22.499998990380618}
# t=948: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.565772678447894e-05, 'v': 14.999997463733687, 'Δx': 22.49999888742991}
# t=949: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.866424790895771e-06, 'v': 14.999997950376166, 'Δx': 22.499999141056605}
# t=950: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 3.315222426855713e-05, 'v': 15.000001265598593, 'Δx': 22.499999346018967}
# t=951: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3318484597806366e-06, 'v': 15.000001498783439, 'Δx': 22.49999921945914}
# t=952: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.3603506526953946e-06, 'v': 15.000000762748373, 'Δx': 22.49999906958078}
# t=953: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.6670819696247753e-06, 'v': 15.00000102945657, 'Δx': 22.499998993306008}
# t=954: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.565769358792454e-05, 'v': 14.999997463687212, 'Δx': 22.499998890360303}
# t=955: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.86645586529601e-06, 'v': 14.999997950332798, 'Δx': 22.499999143991545}
# t=956: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 3.31522532208032e-05, 'v': 15.00000126555812, 'Δx': 22.499999348958227}
# t=957: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3318754414549908e-06, 'v': 15.000001498745664, 'Δx': 22.499999222402494}
# t=958: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.360325338427883e-06, 'v': 15.00000076271313, 'Δx': 22.499999072528}
# t=959: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.667105464903005e-06, 'v': 15.000001029423677, 'Δx': 22.499998996256636}
# t=960: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.5657671608470715e-05, 'v': 14.999997463656516, 'Δx': 22.49999889331434}
# t=961: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.866476328925436e-06, 'v': 14.999997950304149, 'Δx': 22.499999146948767}
# t=962: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 3.3152272320190666e-05, 'v': 15.000001265531381, 'Δx': 22.499999351918404}
# t=963: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3318933281829333e-06, 'v': 15.000001498720714, 'Δx': 22.499999225365173}
# t=964: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.360308815941902e-06, 'v': 15.000000762689831, 'Δx': 22.49999907549318}
# t=965: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.6671210021031246e-06, 'v': 15.00000102940193, 'Δx': 22.49999899922409}
# t=966: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.56576572081389e-05, 'v': 14.99999746363621, 'Δx': 22.49999889628384}
# t=967: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.866489971345053e-06, 'v': 14.999997950285207, 'Δx': 22.499999149920313}
# t=968: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 3.31522849015332e-05, 'v': 15.000001265513697, 'Δx': 22.49999935489177}
# t=969: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.331905151613268e-06, 'v': 15.000001498704213, 'Δx': 22.499999228340357}
# t=970: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.360297750423767e-06, 'v': 15.000000762674437, 'Δx': 22.499999078469955}
# t=971: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.6671312339178372e-06, 'v': 15.00000102938756, 'Δx': 22.499999002202458}
# t=972: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.565764758265394e-05, 'v': 14.999997463622801, 'Δx': 22.4999988992638}
# t=973: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.866498914709024e-06, 'v': 14.999997950272693, 'Δx': 22.49999915290141}
# t=974: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 3.315229323856742e-05, 'v': 15.000001265502016, 'Δx': 22.49999935787423}
# t=975: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3319128823177174e-06, 'v': 15.000001498693305, 'Δx': 22.499999231323955}
# t=976: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.3602904744666385e-06, 'v': 15.000000762664257, 'Δx': 22.49999908145469}
# t=977: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.6671380551276457e-06, 'v': 15.000001029378062, 'Δx': 22.49999900518833}
# t=978: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.565764129198267e-05, 'v': 14.999997463613933, 'Δx': 22.49999890225058}
# t=979: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.866504826424192e-06, 'v': 14.999997950264417, 'Δx': 22.4999991558891}
# t=980: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 3.315229869553526e-05, 'v': 15.000001265494287, 'Δx': 22.499999360862603}
# t=981: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3319181119119045e-06, 'v': 15.000001498686098, 'Δx': 22.499999234313236}
# t=982: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.360285623828552e-06, 'v': 15.000000762657535, 'Δx': 22.499999084444653}
# t=983: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.6671425268096315e-06, 'v': 15.000001029371788, 'Δx': 22.499999008178975}
# t=984: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.565763712346557e-05, 'v': 14.999997463608075, 'Δx': 22.499998905241682}
# t=985: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.866508767567637e-06, 'v': 14.999997950258951, 'Δx': 22.499999158880883}
# t=986: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 3.3152302333513826e-05, 'v': 15.000001265489184, 'Δx': 22.499999363855068}
# t=987: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3319214467255885e-06, 'v': 15.000001498681328, 'Δx': 22.499999237306156}
# t=988: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.360282440597309e-06, 'v': 15.000000762653084, 'Δx': 22.499999087438027}
# t=989: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.6671454826672153e-06, 'v': 15.000001029367633, 'Δx': 22.499999011172804}
# t=990: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.565763431919042e-05, 'v': 14.9999974636042, 'Δx': 22.499998908235966}
# t=991: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.86651119288668e-06, 'v': 14.99999795025532, 'Δx': 22.49999916187562}
# t=992: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 3.3152304758832865e-05, 'v': 15.000001265485796, 'Δx': 22.499999366850034}
# t=993: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3319237204621913e-06, 'v': 15.000001498678168, 'Δx': 22.49999924030135}
# t=994: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -7.3602804700255865e-06, 'v': 15.00000076265012, 'Δx': 22.499999090433448}
# t=995: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.6671474532389373e-06, 'v': 15.000001029364865, 'Δx': 22.499999014168452}
# t=996: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': -3.565763242440992e-05, 'v': 14.999997463601623, 'Δx': 22.49999891123207}
# t=997: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 4.8665130118759614e-06, 'v': 14.999997950252924, 'Δx': 22.49999916487195}
# t=998: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 3.315230627465727e-05, 'v': 15.00000126548355, 'Δx': 22.49999936984659}
# t=999: reward=-50.000, term=False, trunc=True, info={'collision': False, 'a': 2.3319252362865933e-06, 'v': 15.000001498676074, 'Δx': 22.499999243298134}

# %%
from __future__ import annotations
import torch
import numpy as np

def _to_tensor(x: np.ndarray) -> torch.Tensor:
    return torch.as_tensor(x, dtype=torch.float32)

class AttackWrapper:
    """Base class: wraps (policy, value_fn) to perturb observation before acting.
    Assumes observations are already normalized to [-1,1].
    """
    def __init__(self, model, epsilon: float = 0.01, device: str = "cpu") -> None:
        self.model = model
        self.eps = epsilon
        self.device = device

    def perturb(self, obs: np.ndarray) -> np.ndarray:
        return obs

    @torch.no_grad()
    def act(self, obs: np.ndarray):
        obs_adv = self.perturb(obs)
        action, _ = self.model.predict(obs_adv, deterministic=True)
        return action, obs_adv

class FGSMAttack(AttackWrapper):
    """FGSM wrt policy mean action output.
    For SB3 PPO, we pass obs through model.policy to get latent and mean action.
    """
    def perturb(self, obs: np.ndarray) -> np.ndarray:
        self.model.policy.set_training_mode(True)  # enable grad path
        obs_t = _to_tensor(obs).to(self.device)
        if obs_t.ndim == 1:
            obs_t = obs_t.unsqueeze(0)
        obs_t.requires_grad_(True)

        # Forward to get mean action (pre squashing)
        features = self.model.policy.extract_features(obs_t)
        latent_pi, _ = self.model.policy.mlp_extractor(features)
        mean_actions = self.model.policy.action_net(latent_pi)  # shape [B, act_dim]
        # Sum to get scalar objective (maximize change magnitude)
        obj = (mean_actions**2).sum()
        obj.backward()
        grad = obs_t.grad
        sign = torch.sign(grad)
        adv = torch.clamp(obs_t + self.eps * sign, -1.0, 1.0)
        return adv.detach().cpu().numpy()

class OIAttack(AttackWrapper):
    """Optimism Induction Attack: pushes obs to increase the critic's V(s).
    """
    def perturb(self, obs: np.ndarray) -> np.ndarray:
        self.model.policy.set_training_mode(True)
        obs_t = _to_tensor(obs).to(self.device)
        if obs_t.ndim == 1:
            obs_t = obs_t.unsqueeze(0)
        obs_t.requires_grad_(True)

        features = self.model.policy.extract_features(obs_t)
        _, latent_vf = self.model.policy.mlp_extractor(features)
        values = self.model.policy.value_net(latent_vf)  # shape [B,1]
        obj = values.sum()   # maximize value
        obj.backward()
        grad = obs_t.grad
        sign = torch.sign(grad)
        adv = torch.clamp(obs_t + self.eps * sign, -1.0, 1.0)
        return adv.detach().cpu().numpy()

# %%
from __future__ import annotations
import torch
import numpy as np

def _to_tensor(x: np.ndarray) -> torch.Tensor:
    # Accept 1D or 2D np arrays; always float32
    return torch.as_tensor(x, dtype=torch.float32)

class AttackWrapper:
    """
    Base class: wraps an SB3 policy to perturb the observation (normalized to [-1,1])
    before acting. Subclasses implement `perturb`.
    """
    def __init__(self, model, epsilon: float = 0.01, device: str = "cpu") -> None:
        self.model = model
        self.eps = float(epsilon)
        self.device = device

    def perturb(self, obs: np.ndarray) -> np.ndarray:
        # Identity (no attack) by default
        return obs

    def act(self, obs: np.ndarray):
        """
        Compute adversarial observation (grad-enabled) then get action (no grad).
        DO NOT decorate with @torch.no_grad().
        """
        obs_adv = self.perturb(obs)

        # Action selection should not track gradients
        with torch.no_grad():
            action, _ = self.model.predict(obs_adv, deterministic=True)
        return action, obs_adv

class FGSMAttack(AttackWrapper):
    """
    FGSM with respect to the policy mean action output.
    """
    def perturb(self, obs: np.ndarray) -> np.ndarray:
        # Ensure model in training mode for grad path through policy
        self.model.policy.set_training_mode(True)

        # Clear any stale grads
        self.model.policy.zero_grad(set_to_none=True)

        # Prepare input tensor
        obs_t = _to_tensor(obs)
        single = False
        if obs_t.ndim == 1:
            obs_t = obs_t.unsqueeze(0)    # [1, obs_dim]
            single = True
        obs_t = obs_t.to(self.device)
        obs_t.requires_grad_(True)

        # Forward: features -> latent_pi -> action mean
        features = self.model.policy.extract_features(obs_t)
        latent_pi, _ = self.model.policy.mlp_extractor(features)
        mean_actions = self.model.policy.action_net(latent_pi)  # [B, act_dim]

        # Objective: increase action magnitude (any non-zero scalar works)
        obj = (mean_actions ** 2).sum()
        obj.backward()

        # FGSM step in observation space
        grad_sign = torch.sign(obs_t.grad)
        adv = torch.clamp(obs_t + self.eps * grad_sign, -1.0, 1.0)

        adv_np = adv.detach().cpu().numpy()
        return adv_np[0] if single else adv_np

class OIAttack(AttackWrapper):
    """
    Optimism Induction Attack: push obs to increase critic V(s).
    """
    def perturb(self, obs: np.ndarray) -> np.ndarray:
        self.model.policy.set_training_mode(True)
        self.model.policy.zero_grad(set_to_none=True)

        obs_t = _to_tensor(obs)
        single = False
        if obs_t.ndim == 1:
            obs_t = obs_t.unsqueeze(0)
            single = True
        obs_t = obs_t.to(self.device)
        obs_t.requires_grad_(True)

        features = self.model.policy.extract_features(obs_t)
        _, latent_vf = self.model.policy.mlp_extractor(features)
        values = self.model.policy.value_net(latent_vf)  # [B, 1]

        obj = values.sum()  # maximize value estimate
        obj.backward()

        grad_sign = torch.sign(obs_t.grad)
        adv = torch.clamp(obs_t + self.eps * grad_sign, -1.0, 1.0)

        adv_np = adv.detach().cpu().numpy()
        return adv_np[0] if single else adv_np

# %%
# After: model, env loaded; observations normalized
atk = FGSMAttack(model, epsilon=0.01, device="cpu")

obs = env.reset()[0]
adv = atk.perturb(obs)
print("obs shape:", np.array(obs).shape)
print("adv shape:", np.array(adv).shape)
print("max |adv-obs|:", float(np.max(np.abs(np.array(adv) - np.array(obs)))))

action, adv_obs = atk.act(obs)
print("action:", action)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 # After: model, env loaded; observations normalized
# ----> 2 atk = FGSMAttack(model, epsilon=0.01, device="cpu")
#       4 obs = env.reset()[0]
#       5 adv = atk.perturb(obs)
#
# NameError: name 'model' is not defined
