# %%
# %run ./acc_env.ipynb   # executes the notebook and defines ACCEnv in this kernel

# now this works
env = ACCEnv()
# Out:
# reset obs: [-0.60096765  0.03967232 -0.05289644] info: {}
# t=0: reward=-0.279, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 14.25655369961164, 'Δx': 39.98258188636605}
# t=1: reward=-0.243, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 14.30655369961164, 'Δx': 40.056926516404886}
# t=2: reward=-0.210, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 14.356553699611641, 'Δx': 40.12627114644373}
# t=3: reward=-0.179, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 14.406553699611642, 'Δx': 40.19061577648256}
# t=4: reward=-0.150, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 14.456553699611643, 'Δx': 40.249960406521396}
# t=5: reward=-0.124, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 14.506553699611644, 'Δx': 40.30430503656023}
# t=6: reward=-0.101, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 14.556553699611644, 'Δx': 40.35364966659907}
# t=7: reward=-0.080, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 14.606553699611645, 'Δx': 40.397994296637904}
# t=8: reward=-0.061, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 14.656553699611646, 'Δx': 40.43733892667674}
# t=9: reward=-0.046, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 14.706553699611646, 'Δx': 40.471683556715575}
# t=10: reward=-0.032, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 14.756553699611647, 'Δx': 40.50102818675441}
# t=11: reward=-0.021, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 14.806553699611648, 'Δx': 40.525372816793244}
# t=12: reward=-0.013, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 14.856553699611649, 'Δx': 40.54471744683208}
# t=13: reward=-0.007, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 14.90655369961165, 'Δx': 40.559062076870916}
# t=14: reward=-0.003, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 14.95655369961165, 'Δx': 40.56840670690975}
# t=15: reward=-0.003, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.00655369961165, 'Δx': 40.572751336948585}
# t=16: reward=-0.004, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.056553699611651, 'Δx': 40.57209596698742}
# t=17: reward=-0.008, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.106553699611652, 'Δx': 40.56644059702626}
# t=18: reward=-0.015, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.156553699611653, 'Δx': 40.55578522706509}
# t=19: reward=-0.024, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.206553699611653, 'Δx': 40.54012985710392}
# t=20: reward=-0.035, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.256553699611654, 'Δx': 40.51947448714276}
# t=21: reward=-0.049, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.306553699611655, 'Δx': 40.493819117181594}
# t=22: reward=-0.066, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.356553699611656, 'Δx': 40.46316374722043}
# t=23: reward=-0.085, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.406553699611656, 'Δx': 40.427508377259265}
# t=24: reward=-0.107, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.456553699611657, 'Δx': 40.3868530072981}
# t=25: reward=-0.131, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.506553699611658, 'Δx': 40.34119763733693}
# t=26: reward=-0.157, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.556553699611658, 'Δx': 40.29054226737577}
# t=27: reward=-0.186, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.60655369961166, 'Δx': 40.234886897414604}
# t=28: reward=-0.218, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.65655369961166, 'Δx': 40.174231527453436}
# t=29: reward=-0.252, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.70655369961166, 'Δx': 40.10857615749227}
# t=30: reward=-0.289, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.756553699611661, 'Δx': 40.03792078753111}
# t=31: reward=-0.328, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.806553699611662, 'Δx': 39.96226541756994}
# t=32: reward=-0.369, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.856553699611663, 'Δx': 39.881610047608774}
# t=33: reward=-0.413, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.906553699611663, 'Δx': 39.79595467764761}
# t=34: reward=-0.460, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 15.956553699611664, 'Δx': 39.70529930768644}
# t=35: reward=-0.509, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.006553699611665, 'Δx': 39.609643937725274}
# t=36: reward=-0.561, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.056553699611666, 'Δx': 39.508988567764106}
# t=37: reward=-0.615, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.106553699611666, 'Δx': 39.40333319780294}
# t=38: reward=-0.671, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.156553699611667, 'Δx': 39.29267782784177}
# t=39: reward=-0.730, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.206553699611668, 'Δx': 39.177022457880604}
# t=40: reward=-0.792, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.25655369961167, 'Δx': 39.05636708791944}
# t=41: reward=-0.856, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.30655369961167, 'Δx': 38.930711717958275}
# t=42: reward=-0.923, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.35655369961167, 'Δx': 38.80005634799711}
# t=43: reward=-0.992, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.40655369961167, 'Δx': 38.66440097803594}
# t=44: reward=-1.063, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.45655369961167, 'Δx': 38.523745608074776}
# t=45: reward=-1.137, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.506553699611672, 'Δx': 38.378090238113614}
# t=46: reward=-1.214, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.556553699611673, 'Δx': 38.22743486815244}
# t=47: reward=-1.293, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.606553699611673, 'Δx': 38.071779498191276}
# t=48: reward=-1.375, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.656553699611674, 'Δx': 37.911124128230114}
# t=49: reward=-1.459, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.706553699611675, 'Δx': 37.74546875826894}
# t=50: reward=-1.545, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.756553699611676, 'Δx': 37.55481338830778}
# t=51: reward=-1.634, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.806553699611676, 'Δx': 37.33915801834661}
# t=52: reward=-1.726, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.856553699611677, 'Δx': 37.098502648385434}
# t=53: reward=-1.820, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.906553699611678, 'Δx': 36.83284727842427}
# t=54: reward=-1.917, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 16.95655369961168, 'Δx': 36.54219190846311}
# t=55: reward=-2.016, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.00655369961168, 'Δx': 36.22653653850193}
# t=56: reward=-2.117, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.05655369961168, 'Δx': 35.88588116854076}
# t=57: reward=-2.221, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.10655369961168, 'Δx': 35.5202257985796}
# t=58: reward=-2.328, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.15655369961168, 'Δx': 35.129570428618436}
# t=59: reward=-2.437, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.206553699611682, 'Δx': 34.71391505865728}
# t=60: reward=-2.549, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.256553699611683, 'Δx': 34.273259688696115}
# t=61: reward=-2.663, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.306553699611683, 'Δx': 33.80760431873493}
# t=62: reward=-2.779, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.356553699611684, 'Δx': 33.31694894877377}
# t=63: reward=-2.898, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.406553699611685, 'Δx': 32.801293578812604}
# t=64: reward=-3.020, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.456553699611685, 'Δx': 32.26063820885142}
# t=65: reward=-3.144, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.506553699611686, 'Δx': 31.694982838890255}
# t=66: reward=-3.377, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.556553699611687, 'Δx': 31.104327468929085}
# t=67: reward=-5.097, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.606553699611688, 'Δx': 30.488672098967925}
# t=68: reward=-8.889, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.65655369961169, 'Δx': 29.84801672900676}
# t=69: reward=-14.970, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.70655369961169, 'Δx': 29.182361359045586}
# t=70: reward=-23.560, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.75655369961169, 'Δx': 28.491705989084437}
# t=71: reward=-34.890, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.80655369961169, 'Δx': 27.776050619123268}
# t=72: reward=-49.197, term=False, trunc=False, info={'collision': False, 'a': 0.5, 'v': 17.85655369961169, 'Δx': 27.035395249162093}
# t=73: reward=-53.701, term=False, trunc=False, info={'collision': False, 'a': -3.3005991960570586, 'v': 17.526493780005985, 'Δx': 26.26973987920094}
# t=74: reward=-57.567, term=False, trunc=False, info={'collision': False, 'a': -3.5, 'v': 17.176493780005984, 'Δx': 25.517090501200343}
# t=75: reward=-61.420, term=False, trunc=False, info={'collision': False, 'a': -3.5, 'v': 16.826493780005983, 'Δx': 24.77944112319973}
# t=76: reward=-65.237, term=False, trunc=False, info={'collision': False, 'a': -3.5, 'v': 16.47649378000598, 'Δx': 24.056791745199135}
# t=77: reward=-68.982, term=False, trunc=False, info={'collision': False, 'a': -3.5, 'v': 16.12649378000598, 'Δx': 23.34914236719854}
# t=78: reward=-72.622, term=False, trunc=False, info={'collision': False, 'a': -3.5, 'v': 15.77649378000598, 'Δx': 22.656492989197957}
# t=79: reward=-76.127, term=False, trunc=False, info={'collision': False, 'a': -3.5, 'v': 15.42649378000598, 'Δx': 21.978843611197362}
# t=80: reward=-78.966, term=False, trunc=False, info={'collision': False, 'a': -3.5, 'v': 15.07649378000598, 'Δx': 21.336194233196778}
# t=81: reward=-81.090, term=False, trunc=False, info={'collision': False, 'a': -3.5, 'v': 14.726493780005981, 'Δx': 20.72854485519619}
# t=82: reward=-82.463, term=False, trunc=False, info={'collision': False, 'a': -3.5, 'v': 14.376493780005982, 'Δx': 20.1558954771956}
# t=83: reward=-83.068, term=False, trunc=False, info={'collision': False, 'a': -3.5, 'v': 14.026493780005982, 'Δx': 19.618246099195005}
# t=84: reward=-82.896, term=False, trunc=False, info={'collision': False, 'a': -3.5, 'v': 13.676493780005982, 'Δx': 19.115596721194407}
# t=85: reward=-81.959, term=False, trunc=False, info={'collision': False, 'a': -3.5, 'v': 13.326493780005983, 'Δx': 18.647947343193806}
# t=86: reward=-80.281, term=False, trunc=False, info={'collision': False, 'a': -3.5, 'v': 12.976493780005983, 'Δx': 18.2152979651932}
# t=87: reward=-77.899, term=False, trunc=False, info={'collision': False, 'a': -3.5, 'v': 12.626493780005983, 'Δx': 17.817648587192622}
# t=88: reward=-74.868, term=False, trunc=False, info={'collision': False, 'a': -3.5, 'v': 12.276493780005984, 'Δx': 17.45499920919204}
# t=89: reward=-71.256, term=False, trunc=False, info={'collision': False, 'a': -3.5, 'v': 11.926493780005984, 'Δx': 17.127349831191452}
# t=90: reward=-67.145, term=False, trunc=False, info={'collision': False, 'a': -3.5, 'v': 11.576493780005984, 'Δx': 16.834700453190862}
# t=91: reward=-62.634, term=False, trunc=False, info={'collision': False, 'a': -3.5, 'v': 11.226493780005985, 'Δx': 16.57705107519027}
# t=92: reward=-58.498, term=False, trunc=False, info={'collision': False, 'a': -3.235580228630589, 'v': 10.902935757142926, 'Δx': 16.354401697189672}
# t=93: reward=-58.937, term=False, trunc=False, info={'collision': False, 'a': -1.2686459967122559, 'v': 10.7760711574717, 'Δx': 16.16410812147538}
# t=94: reward=-59.442, term=False, trunc=False, info={'collision': False, 'a': -1.1840537394478903, 'v': 10.65766578352691, 'Δx': 15.986501005728229}
# t=95: reward=-59.926, term=False, trunc=False, info={'collision': False, 'a': -1.105094518103562, 'v': 10.547156331716554, 'Δx': 15.820734427375555}
# t=96: reward=-60.389, term=False, trunc=False, info={'collision': False, 'a': -1.0314279504438657, 'v': 10.444013536672168, 'Δx': 15.666018794203893}
# t=97: reward=-60.831, term=False, trunc=False, info={'collision': False, 'a': -0.9626820240373443, 'v': 10.347745334268433, 'Δx': 15.521617440536687}
# t=98: reward=-61.252, term=False, trunc=False, info={'collision': False, 'a': -0.8985064225417918, 'v': 10.257894692014254, 'Δx': 15.386842907109838}
# t=99: reward=-61.652, term=False, trunc=False, info={'collision': False, 'a': -0.8385836519038714, 'v': 10.174036326823867, 'Δx': 15.26105343790843}
# t=100: reward=-62.032, term=False, trunc=False, info={'collision': False, 'a': -0.7826908702398387, 'v': 10.095767239799883, 'Δx': 15.143649805226062}
# t=101: reward=-62.392, term=False, trunc=False, info={'collision': False, 'a': -0.7305082787835789, 'v': 10.022716411921525, 'Δx': 15.034073081246078}
# t=102: reward=-62.733, term=False, trunc=False, info={'collision': False, 'a': -0.6818172477126311, 'v': 9.954534687150263, 'Δx': 14.931801440053931}
# t=103: reward=-63.056, term=False, trunc=False, info={'collision': False, 'a': -0.6363437148885887, 'v': 9.890900315661403, 'Δx': 14.83634797133891}
# t=104: reward=-63.360, term=False, trunc=False, info={'collision': False, 'a': -0.5939557951095713, 'v': 9.831504736150446, 'Δx': 14.747257939772766}
# t=105: reward=-63.648, term=False, trunc=False, info={'collision': False, 'a': -0.55434282898772, 'v': 9.776070453251673, 'Δx': 14.66410746615773}
# t=106: reward=-63.919, term=False, trunc=False, info={'collision': False, 'a': -0.5173707458176583, 'v': 9.724333378669908, 'Δx': 14.586500420832579}
# t=107: reward=-64.175, term=False, trunc=False, info={'collision': False, 'a': -0.48287936806133797, 'v': 9.676045441863774, 'Δx': 14.514067082965596}
# t=108: reward=-64.415, term=False, trunc=False, info={'collision': False, 'a': -0.4507191675432013, 'v': 9.630973525109454, 'Δx': 14.44646253877923}
# t=109: reward=-64.642, term=False, trunc=False, info={'collision': False, 'a': -0.42064898388656435, 'v': 9.588908626720798, 'Δx': 14.383365186268293}
# t=110: reward=-64.855, term=False, trunc=False, info={'collision': False, 'a': -0.39259617890250326, 'v': 9.549649008830547, 'Δx': 14.324474323596206}
# t=111: reward=-65.055, term=False, trunc=False, info={'collision': False, 'a': -0.3664294634355455, 'v': 9.513006062486992, 'Δx': 14.269509422713156}
# t=112: reward=-65.243, term=False, trunc=False, info={'collision': False, 'a': -0.3420231114300266, 'v': 9.478803751343989, 'Δx': 14.218208816464454}
# t=113: reward=-65.420, term=False, trunc=False, info={'collision': False, 'a': -0.31916435418649786, 'v': 9.44688731592534, 'Δx': 14.17032844133007}
# t=114: reward=-65.585, term=False, trunc=False, info={'collision': False, 'a': -0.2979216774372405, 'v': 9.417095148181616, 'Δx': 14.125639709737555}
# t=115: reward=-65.741, term=False, trunc=False, info={'collision': False, 'a': -0.27808884912508053, 'v': 9.389286263269108, 'Δx': 14.08393019491939}
# t=116: reward=-65.887, term=False, trunc=False, info={'collision': False, 'a': -0.25953050711075715, 'v': 9.363333212558032, 'Δx': 14.045001568592482}
# t=117: reward=-66.023, term=False, trunc=False, info={'collision': False, 'a': -0.24221577619033494, 'v': 9.339111634938998, 'Δx': 14.008668247336686}
# t=118: reward=-66.152, term=False, trunc=False, info={'collision': False, 'a': -0.2260871378854404, 'v': 9.316502921150454, 'Δx': 13.974757083842803}
# t=119: reward=-66.272, term=False, trunc=False, info={'collision': False, 'a': -0.21098604385154077, 'v': 9.2954043167653, 'Δx': 13.943106791727757}
# t=120: reward=-66.384, term=False, trunc=False, info={'collision': False, 'a': -0.19694255469581373, 'v': 9.275710061295719, 'Δx': 13.91356636005122}
# t=121: reward=-66.489, term=False, trunc=False, info={'collision': False, 'a': -0.183803526227826, 'v': 9.257329708672936, 'Δx': 13.885995353921658}
# t=122: reward=-66.588, term=False, trunc=False, info={'collision': False, 'a': -0.17156583913804235, 'v': 9.240173124759131, 'Δx': 13.860262383054362}
# t=123: reward=-66.680, term=False, trunc=False, info={'collision': False, 'a': -0.1601026944872638, 'v': 9.224162855310405, 'Δx': 13.836245070578457}
# t=124: reward=-66.767, term=False, trunc=False, info={'collision': False, 'a': -0.14942918218371998, 'v': 9.209219937092033, 'Δx': 13.813828785047434}
# t=125: reward=-66.848, term=False, trunc=False, info={'collision': False, 'a': -0.13948312465294793, 'v': 9.195271624626738, 'Δx': 13.792906791338226}
# t=126: reward=-66.923, term=False, trunc=False, info={'collision': False, 'a': -0.13017790641775587, 'v': 9.182253833984962, 'Δx': 13.773379628875546}
# t=127: reward=-66.994, term=False, trunc=False, info={'collision': False, 'a': -0.12149302348170798, 'v': 9.170104531636792, 'Δx': 13.755154245477058}
# t=128: reward=-67.060, term=False, trunc=False, info={'collision': False, 'a': -0.11342208821413169, 'v': 9.15876232281538, 'Δx': 13.738143792313394}
# t=129: reward=-67.122, term=False, trunc=False, info={'collision': False, 'a': -0.10583518236629282, 'v': 9.14817880457875, 'Δx': 13.722267560031867}
# t=130: reward=-67.180, term=False, trunc=False, info={'collision': False, 'a': -0.09880811310718435, 'v': 9.138297993268031, 'Δx': 13.707449679573983}
# t=131: reward=-67.234, term=False, trunc=False, info={'collision': False, 'a': -0.09219865382974653, 'v': 9.129078127885057, 'Δx': 13.693619880247184}
# t=132: reward=-67.284, term=False, trunc=False, info={'collision': False, 'a': -0.0860393784701775, 'v': 9.120474190038038, 'Δx': 13.680712067458671}
# t=133: reward=-67.332, term=False, trunc=False, info={'collision': False, 'a': -0.08029068967877133, 'v': 9.112445121070161, 'Δx': 13.668664648454865}
# t=134: reward=-67.376, term=False, trunc=False, info={'collision': False, 'a': -0.07499838368787731, 'v': 9.104945282701374, 'Δx': 13.657420136347866}
# t=135: reward=-67.417, term=False, trunc=False, info={'collision': False, 'a': -0.06994126767548021, 'v': 9.097951155933826, 'Δx': 13.646925608077737}
# t=136: reward=-67.456, term=False, trunc=False, info={'collision': False, 'a': -0.06531030497660202, 'v': 9.091420125436166, 'Δx': 13.637130492484374}
# t=137: reward=-67.492, term=False, trunc=False, info={'collision': False, 'a': -0.06093721182204578, 'v': 9.08532640425396, 'Δx': 13.627988479940768}
# t=138: reward=-67.525, term=False, trunc=False, info={'collision': False, 'a': -0.05689380186987081, 'v': 9.079637024066972, 'Δx': 13.619455839515382}
# t=139: reward=-67.557, term=False, trunc=False, info={'collision': False, 'a': -0.05306273841760546, 'v': 9.074330750225212, 'Δx': 13.611492137108684}
# t=140: reward=-67.586, term=False, trunc=False, info={'collision': False, 'a': -0.04959515399905597, 'v': 9.069371234825306, 'Δx': 13.60405906208618}
# t=141: reward=-67.614, term=False, trunc=False, info={'collision': False, 'a': -0.046244315203623515, 'v': 9.064746803304944, 'Δx': 13.597121938603664}
# t=142: reward=-67.639, term=False, trunc=False, info={'collision': False, 'a': -0.04313274433752946, 'v': 9.06043352887119, 'Δx': 13.59064725827318}
# t=143: reward=-67.663, term=False, trunc=False, info={'collision': False, 'a': -0.04031763205362311, 'v': 9.056401765665829, 'Δx': 13.584603905386075}
# t=144: reward=-67.686, term=False, trunc=False, info={'collision': False, 'a': -0.037607535696229336, 'v': 9.052641012096206, 'Δx': 13.578963728819502}
# t=145: reward=-67.706, term=False, trunc=False, info={'collision': False, 'a': -0.03508129233691525, 'v': 9.049132882862514, 'Δx': 13.573699627609898}
# t=146: reward=-67.726, term=False, trunc=False, info={'collision': False, 'a': -0.032755255999000844, 'v': 9.045857357262614, 'Δx': 13.568786339323651}
# t=147: reward=-67.744, term=False, trunc=False, info={'collision': False, 'a': -0.03055567835712744, 'v': 9.042801789426901, 'Δx': 13.564200603597385}
# t=148: reward=-67.761, term=False, trunc=False, info={'collision': False, 'a': -0.02855677960672673, 'v': 9.039946111466229, 'Δx': 13.559920424654706}
# t=149: reward=-67.777, term=False, trunc=False, info={'collision': False, 'a': -0.026633921476828838, 'v': 9.037282719318545, 'Δx': 13.555925813508082}
# t=150: reward=-67.792, term=False, trunc=False, info={'collision': False, 'a': -0.024842434458784705, 'v': 9.034798475872668, 'Δx': 13.55219754157622}
# t=151: reward=-67.806, term=False, trunc=False, info={'collision': False, 'a': -0.023221237899511162, 'v': 9.032476352082716, 'Δx': 13.548717693988948}
# t=152: reward=-67.819, term=False, trunc=False, info={'collision': False, 'a': -0.02161911482529418, 'v': 9.030314440600186, 'Δx': 13.545470058780694}
# t=153: reward=-67.831, term=False, trunc=False, info={'collision': False, 'a': -0.02021280789727114, 'v': 9.02829315981046, 'Δx': 13.54243861472068}
# t=154: reward=-67.842, term=False, trunc=False, info={'collision': False, 'a': -0.018881183100645987, 'v': 9.026405041500395, 'Δx': 13.539609298739634}
# t=155: reward=-67.852, term=False, trunc=False, info={'collision': False, 'a': -0.01761607832491894, 'v': 9.024643433667903, 'Δx': 13.536968794589598}
# t=156: reward=-67.862, term=False, trunc=False, info={'collision': False, 'a': -0.016387632886811665, 'v': 9.02300467037922, 'Δx': 13.534504451222801}
# t=157: reward=-67.871, term=False, trunc=False, info={'collision': False, 'a': -0.01535552265197865, 'v': 9.021469118114023, 'Δx': 13.53220398418489}
# t=158: reward=-67.880, term=False, trunc=False, info={'collision': False, 'a': -0.01431274815349552, 'v': 9.020037843298674, 'Δx': 13.530057072373495}
# t=159: reward=-67.888, term=False, trunc=False, info={'collision': False, 'a': -0.01334902803516576, 'v': 9.018702940495157, 'Δx': 13.528053288043623}
# t=160: reward=-67.895, term=False, trunc=False, info={'collision': False, 'a': -0.012459093495095162, 'v': 9.017457031145646, 'Δx': 13.526182993994126}
# t=161: reward=-67.902, term=False, trunc=False, info={'collision': False, 'a': -0.01165391675424465, 'v': 9.016291639470221, 'Δx': 13.524437290879575}
# t=162: reward=-67.909, term=False, trunc=False, info={'collision': False, 'a': -0.010864273231139743, 'v': 9.015205212147107, 'Δx': 13.522808126932546}
# t=163: reward=-67.915, term=False, trunc=False, info={'collision': False, 'a': -0.010124095351083539, 'v': 9.014192802611998, 'Δx': 13.521287605717845}
# t=164: reward=-67.921, term=False, trunc=False, info={'collision': False, 'a': -0.009455513199618707, 'v': 9.013247251292036, 'Δx': 13.519868325456656}
# t=165: reward=-67.926, term=False, trunc=False, info={'collision': False, 'a': -0.008872830027892645, 'v': 9.012359968289246, 'Δx': 13.518543600327462}
# t=166: reward=-67.931, term=False, trunc=False, info={'collision': False, 'a': -0.008220907994413577, 'v': 9.011537877489804, 'Δx': 13.517307603498551}
# t=167: reward=-67.935, term=False, trunc=False, info={'collision': False, 'a': -0.007679206117647092, 'v': 9.01076995687804, 'Δx': 13.51615381574959}
# t=168: reward=-67.940, term=False, trunc=False, info={'collision': False, 'a': -0.00720222680932953, 'v': 9.010049734197107, 'Δx': 13.515076820061779}
# t=169: reward=-67.944, term=False, trunc=False, info={'collision': False, 'a': -0.006668036359067414, 'v': 9.0093829305612, 'Δx': 13.514071846642082}
# t=170: reward=-67.947, term=False, trunc=False, info={'collision': False, 'a': -0.006277542763671514, 'v': 9.008755176284833, 'Δx': 13.51313355358596}
# t=171: reward=-67.951, term=False, trunc=False, info={'collision': False, 'a': -0.005811355620629117, 'v': 9.00817404072277, 'Δx': 13.512258035957473}
# t=172: reward=-67.954, term=False, trunc=False, info={'collision': False, 'a': -0.0054588997201715315, 'v': 9.007628150750753, 'Δx': 13.511440631885193}
# t=173: reward=-67.957, term=False, trunc=False, info={'collision': False, 'a': -0.0050822579949452865, 'v': 9.007119924951258, 'Δx': 13.51067781681013}
# t=174: reward=-67.960, term=False, trunc=False, info={'collision': False, 'a': -0.0047466192955372445, 'v': 9.006645263021705, 'Δx': 13.509965824315003}
# t=175: reward=-67.963, term=False, trunc=False, info={'collision': False, 'a': -0.004449252053018161, 'v': 9.006200337816402, 'Δx': 13.509301298012844}
# t=176: reward=-67.965, term=False, trunc=False, info={'collision': False, 'a': -0.004120846004242406, 'v': 9.005788253215979, 'Δx': 13.5086812642312}
# t=177: reward=-67.968, term=False, trunc=False, info={'collision': False, 'a': -0.0038493018514690054, 'v': 9.005403323030832, 'Δx': 13.508102438909617}
# t=178: reward=-67.970, term=False, trunc=False, info={'collision': False, 'a': -0.0036022185740462974, 'v': 9.005043101173428, 'Δx': 13.507562106606542}
# t=179: reward=-67.972, term=False, trunc=False, info={'collision': False, 'a': -0.0033747862016379154, 'v': 9.004705622553264, 'Δx': 13.507057796489192}
# t=180: reward=-67.974, term=False, trunc=False, info={'collision': False, 'a': -0.0031498004134699427, 'v': 9.004390642511916, 'Δx': 13.506587234233876}
# t=181: reward=-67.975, term=False, trunc=False, info={'collision': False, 'a': -0.0029334560564548734, 'v': 9.004097296906272, 'Δx': 13.50614816998268}
# t=182: reward=-67.977, term=False, trunc=False, info={'collision': False, 'a': -0.0026997453285487073, 'v': 9.003827322373416, 'Δx': 13.505738440292049}
# t=183: reward=-67.979, term=False, trunc=False, info={'collision': False, 'a': -0.002561088015018197, 'v': 9.003571213571915, 'Δx': 13.505355708054708}
# t=184: reward=-67.980, term=False, trunc=False, info={'collision': False, 'a': -0.0023776331573126114, 'v': 9.003333450256184, 'Δx': 13.504998586697525}
# t=185: reward=-67.981, term=False, trunc=False, info={'collision': False, 'a': -0.0022191243939867445, 'v': 9.003111537816785, 'Δx': 13.504665241671916}
# t=186: reward=-67.983, term=False, trunc=False, info={'collision': False, 'a': -0.002083898538253641, 'v': 9.00290314796296, 'Δx': 13.504354087890249}
# t=187: reward=-67.984, term=False, trunc=False, info={'collision': False, 'a': -0.0019227196732843586, 'v': 9.002710875995632, 'Δx': 13.504063773093947}
# t=188: reward=-67.985, term=False, trunc=False, info={'collision': False, 'a': -0.0018231484134004323, 'v': 9.002528561154293, 'Δx': 13.503792685494375}
# t=189: reward=-67.986, term=False, trunc=False, info={'collision': False, 'a': -0.0017016052375805433, 'v': 9.002358400630534, 'Δx': 13.503539829378951}
# t=190: reward=-67.987, term=False, trunc=False, info={'collision': False, 'a': -0.0015563758915199657, 'v': 9.002202763041382, 'Δx': 13.503303989315896}
# t=191: reward=-67.988, term=False, trunc=False, info={'collision': False, 'a': -0.0014875853063363233, 'v': 9.002054004510748, 'Δx': 13.503083713011762}
# t=192: reward=-67.989, term=False, trunc=False, info={'collision': False, 'a': -0.0013375504913315235, 'v': 9.001920249461616, 'Δx': 13.502878312560682}
# t=193: reward=-67.989, term=False, trunc=False, info={'collision': False, 'a': -0.0012992430233054126, 'v': 9.001790325159286, 'Δx': 13.502686287614523}
# t=194: reward=-67.990, term=False, trunc=False, info={'collision': False, 'a': -0.001177658791684763, 'v': 9.001672559280117, 'Δx': 13.502507255098607}
# t=195: reward=-67.991, term=False, trunc=False, info={'collision': False, 'a': -0.0011214006255011537, 'v': 9.001560419217567, 'Δx': 13.502339999170601}
# t=196: reward=-67.991, term=False, trunc=False, info={'collision': False, 'a': -0.0010339249167486762, 'v': 9.001457026725893, 'Δx': 13.50218395724886}
# t=197: reward=-67.992, term=False, trunc=False, info={'collision': False, 'a': -0.0009649966510535985, 'v': 9.001360527060788, 'Δx': 13.502038254576235}
# t=198: reward=-67.992, term=False, trunc=False, info={'collision': False, 'a': -0.0009356315089621468, 'v': 9.001266963909892, 'Δx': 13.501902201870138}
# t=199: reward=-67.993, term=False, trunc=True, info={'collision': False, 'a': -0.0008478247926666749, 'v': 9.001182181430625, 'Δx': 13.501775505479117}
# t=200: reward=-67.993, term=False, trunc=True, info={'collision': False, 'a': -0.0007754085689417638, 'v': 9.00110464057373, 'Δx': 13.50165728733603}
# t=201: reward=-67.994, term=False, trunc=True, info={'collision': False, 'a': -0.0007427881442281915, 'v': 9.001030361759307, 'Δx': 13.50154682327863}
# t=202: reward=-67.994, term=False, trunc=True, info={'collision': False, 'a': -0.0006614798083740885, 'v': 9.00096421377847, 'Δx': 13.501443787102687}
# t=203: reward=-67.995, term=False, trunc=True, info={'collision': False, 'a': -0.0006714226851280394, 'v': 9.000897071509957, 'Δx': 13.501347365724826}
# t=204: reward=-67.995, term=False, trunc=True, info={'collision': False, 'a': -0.0005948720879393914, 'v': 9.000837584301163, 'Δx': 13.50125765857382}
# t=205: reward=-67.995, term=False, trunc=True, info={'collision': False, 'a': -0.0005520350164582899, 'v': 9.000782380799517, 'Δx': 13.50117390014367}
# t=206: reward=-67.996, term=False, trunc=True, info={'collision': False, 'a': -0.0005215905103799237, 'v': 9.00073022174848, 'Δx': 13.501095662063705}
# t=207: reward=-67.996, term=False, trunc=True, info={'collision': False, 'a': -0.00048681779933990087, 'v': 9.000681539968546, 'Δx': 13.501022639888845}
# t=208: reward=-67.996, term=False, trunc=True, info={'collision': False, 'a': -0.00044482656272569764, 'v': 9.000637057312273, 'Δx': 13.500954485891981}
# t=209: reward=-67.996, term=False, trunc=True, info={'collision': False, 'a': -0.00044378169647685137, 'v': 9.000592679142626, 'Δx': 13.500890780160745}
# t=210: reward=-67.997, term=False, trunc=True, info={'collision': False, 'a': -0.0003665125063595792, 'v': 9.00055602789199, 'Δx': 13.500831512246464}
# t=211: reward=-67.997, term=False, trunc=True, info={'collision': False, 'a': -0.0003738674706818449, 'v': 9.000518641144922, 'Δx': 13.500775909457246}
# t=212: reward=-67.997, term=False, trunc=True, info={'collision': False, 'a': -0.00037119538997808997, 'v': 9.000481521605924, 'Δx': 13.500724045342736}
# t=213: reward=-67.997, term=False, trunc=True, info={'collision': False, 'a': -0.0002924074844786186, 'v': 9.000452280857475, 'Δx': 13.50067589318212}
# t=214: reward=-67.998, term=False, trunc=True, info={'collision': False, 'a': -0.0002951660617607245, 'v': 9.000422764251299, 'Δx': 13.500630665096367}
# t=215: reward=-67.998, term=False, trunc=True, info={'collision': False, 'a': -0.00029774072224915854, 'v': 9.000392990179074, 'Δx': 13.50058838867119}
# t=216: reward=-67.998, term=False, trunc=True, info={'collision': False, 'a': -0.0002619967582438838, 'v': 9.00036679050325, 'Δx': 13.500549089653248}
# t=217: reward=-67.998, term=False, trunc=True, info={'collision': False, 'a': -0.00026678272762299996, 'v': 9.000340112230488, 'Δx': 13.50051241060288}
# t=218: reward=-67.998, term=False, trunc=True, info={'collision': False, 'a': -0.0002235658899848631, 'v': 9.00031775564149, 'Δx': 13.500478399379801}
# t=219: reward=-67.998, term=False, trunc=True, info={'collision': False, 'a': -0.00021501931791037104, 'v': 9.000296253709699, 'Δx': 13.500446623815606}
# t=220: reward=-67.998, term=False, trunc=True, info={'collision': False, 'a': -0.0001879690555340153, 'v': 9.000277456804145, 'Δx': 13.50041699844462}
# t=221: reward=-67.998, term=False, trunc=True, info={'collision': False, 'a': -0.00018815343798894336, 'v': 9.000258641460347, 'Δx': 13.500389252764194}
# t=222: reward=-67.999, term=False, trunc=True, info={'collision': False, 'a': -0.00018196771027605103, 'v': 9.00024044468932, 'Δx': 13.500363388618155}
# t=223: reward=-67.999, term=False, trunc=True, info={'collision': False, 'a': -0.00014758411742329353, 'v': 9.000225686277577, 'Δx': 13.50033934414921}
# t=224: reward=-67.999, term=False, trunc=True, info={'collision': False, 'a': -0.0001536397510227172, 'v': 9.000210322302475, 'Δx': 13.500316775521412}
# t=225: reward=-67.999, term=False, trunc=True, info={'collision': False, 'a': -0.00014975493318723296, 'v': 9.000195346809157, 'Δx': 13.500295743291133}
# t=226: reward=-67.999, term=False, trunc=True, info={'collision': False, 'a': -0.00010162431185641176, 'v': 9.00018518437797, 'Δx': 13.500276208610217}
# t=227: reward=-67.999, term=False, trunc=True, info={'collision': False, 'a': -0.00011074392861311709, 'v': 9.00017410998511, 'Δx': 13.500257690172418}
# t=228: reward=-67.999, term=False, trunc=True, info={'collision': False, 'a': -0.00015740252680395566, 'v': 9.00015836973243, 'Δx': 13.500240279173909}
# t=229: reward=-67.999, term=False, trunc=True, info={'collision': False, 'a': -0.00010558315042908959, 'v': 9.000147811417387, 'Δx': 13.500224442200647}
# t=230: reward=-67.999, term=False, trunc=True, info={'collision': False, 'a': -7.629187385441265e-05, 'v': 9.000140182230002, 'Δx': 13.500209661058875}
# t=231: reward=-67.999, term=False, trunc=True, info={'collision': False, 'a': -0.00010935270740237239, 'v': 9.000129246959261, 'Δx': 13.500195642835877}
# t=232: reward=-67.999, term=False, trunc=True, info={'collision': False, 'a': -7.981013867100801e-05, 'v': 9.000121265945394, 'Δx': 13.50018271813991}
# t=233: reward=-67.999, term=False, trunc=True, info={'collision': False, 'a': -6.495272152483131e-05, 'v': 9.00011477067324, 'Δx': 13.500170591545327}
# t=234: reward=-67.999, term=False, trunc=True, info={'collision': False, 'a': -7.651711323393976e-05, 'v': 9.000107118961918, 'Δx': 13.500159114477981}
# t=235: reward=-67.999, term=False, trunc=True, info={'collision': False, 'a': -7.14159687945425e-05, 'v': 9.000099977365037, 'Δx': 13.500148402581772}
# t=236: reward=-67.999, term=False, trunc=True, info={'collision': False, 'a': -8.254947347182641e-05, 'v': 9.00009172241769, 'Δx': 13.500138404845245}
# t=237: reward=-67.999, term=False, trunc=True, info={'collision': False, 'a': -6.750943465234689e-05, 'v': 9.000084971474225, 'Δx': 13.500129232603456}
# t=238: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -4.075640967662994e-05, 'v': 9.000080895833257, 'Δx': 13.500120735455994}
# t=239: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -7.618628516455486e-05, 'v': 9.000073277204741, 'Δx': 13.500112645872662}
# t=240: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -3.296022646341636e-05, 'v': 9.000069981182095, 'Δx': 13.50010531815218}
# t=241: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -3.076288255978415e-05, 'v': 9.00006690489384, 'Δx': 13.500098320033942}
# t=242: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -4.460659395617957e-05, 'v': 9.000062444234445, 'Δx': 13.500091629544556}
# t=243: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -3.209608043774317e-05, 'v': 9.0000592346264, 'Δx': 13.50008538512111}
# t=244: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -3.949308281498186e-05, 'v': 9.000055285318119, 'Δx': 13.500079461658459}
# t=245: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -8.136501070950086e-05, 'v': 9.000047148817048, 'Δx': 13.5000739331266}
# t=246: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 9.89000964945076e-06, 'v': 9.000048137818013, 'Δx': 13.500069218244846}
# t=247: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -3.84530405257122e-05, 'v': 9.00004429251396, 'Δx': 13.500064404463046}
# t=248: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -3.588950497572853e-05, 'v': 9.000040703563464, 'Δx': 13.500059975211627}
# t=249: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -4.3033612060392325e-05, 'v': 9.000036400202259, 'Δx': 13.50005590485523}
# t=250: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 7.519008051698812e-06, 'v': 9.000037152103063, 'Δx': 13.500052264835006}
# t=251: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -4.702379788170143e-05, 'v': 9.000032449723275, 'Δx': 13.500048549624694}
# t=252: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -3.4352136464769287e-05, 'v': 9.000029014509629, 'Δx': 13.50004530465236}
# t=253: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 6.084975109206369e-06, 'v': 9.000029623007139, 'Δx': 13.500042403201348}
# t=254: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -4.200440245862841e-05, 'v': 9.000025422566893, 'Δx': 13.500039440900593}
# t=255: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -1.0571383632040495e-06, 'v': 9.000025316853057, 'Δx': 13.500036898643884}
# t=256: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -4.549146190775649e-05, 'v': 9.000020767706866, 'Δx': 13.500034366958573}
# t=257: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 5.225015184201464e-06, 'v': 9.000021290208384, 'Δx': 13.500032290187846}
# t=258: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 4.876679949304385e-06, 'v': 9.000021777876379, 'Δx': 13.50003016116699}
# t=259: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -4.313214307183486e-05, 'v': 9.000017464662072, 'Δx': 13.500027983379312}
# t=260: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 7.427043591565307e-06, 'v': 9.00001820736643, 'Δx': 13.500026236913072}
# t=261: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -2.604835095308076e-06, 'v': 9.00001794688292, 'Δx': 13.500024416176416}
# t=262: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -4.0578148726966517e-05, 'v': 9.000013889068047, 'Δx': 13.500022621488085}
# t=263: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 2.7403073537546757e-07, 'v': 9.00001391647112, 'Δx': 13.500021232581275}
# t=264: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 2.557620196837697e-07, 'v': 9.000013942047323, 'Δx': 13.500019840934158}
# t=265: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 2.387120268111994e-07, 'v': 9.000013965918525, 'Δx': 13.500018446729428}
# t=266: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -3.7924173029867884e-05, 'v': 9.000010173501222, 'Δx': 13.500017050137558}
# t=267: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 2.7510757703057727e-06, 'v': 9.0000104486088, 'Δx': 13.500016032787414}
# t=268: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 2.5676701126222935e-06, 'v': 9.00001070537581, 'Δx': 13.500014987926534}
# t=269: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 2.396492913553822e-06, 'v': 9.000010945025101, 'Δx': 13.500013917388912}
# t=270: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 2.2367262342530915e-06, 'v': 9.000011168697725, 'Δx': 13.50001282288639}
# t=271: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -4.5596101085208924e-05, 'v': 9.000006609087617, 'Δx': 13.500011706016608}
# t=272: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 5.1273512243168135e-06, 'v': 9.000007121822739, 'Δx': 13.50001104510784}
# t=273: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 4.785527667885415e-06, 'v': 9.000007600375506, 'Δx': 13.50001033292557}
# t=274: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -5.070250119097244e-06, 'v': 9.000007093350494, 'Δx': 13.500009572888018}
# t=275: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 4.804509124210887e-06, 'v': 9.000007573801406, 'Δx': 13.500008863552921}
# t=276: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -5.052533769817599e-06, 'v': 9.00000706854803, 'Δx': 13.500008106172743}
# t=277: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -3.968375412218852e-05, 'v': 9.000003100172618, 'Δx': 13.500007399317894}
# t=278: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 1.1087991746451984e-06, 'v': 9.000003211052535, 'Δx': 13.500007089300595}
# t=279: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 1.0348792397743478e-06, 'v': 9.000003314540459, 'Δx': 13.500006768195306}
# t=280: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 9.658872500340739e-07, 'v': 9.000003411129184, 'Δx': 13.500006436741216}
# t=281: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -8.635247650420739e-06, 'v': 9.000002547604419, 'Δx': 13.500006095628294}
# t=282: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 1.4771778524437207e-06, 'v': 9.000002695322204, 'Δx': 13.500005840867857}
# t=283: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 1.3786995916903693e-06, 'v': 9.000002833192163, 'Δx': 13.500005571335635}
# t=284: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 1.2867862148392056e-06, 'v': 9.000002961870784, 'Δx': 13.500005288016382}
# t=285: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 1.2010005581327228e-06, 'v': 9.00000308197084, 'Δx': 13.500004991829258}
# t=286: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 1.1209338037297278e-06, 'v': 9.00000319406422, 'Δx': 13.500004683632142}
# t=287: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 1.046204721793143e-06, 'v': 9.000003298684693, 'Δx': 13.500004364225674}
# t=288: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 9.764578515007229e-07, 'v': 9.000003396330477, 'Δx': 13.500004034357175}
# t=289: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -8.625381755718533e-06, 'v': 9.000002533792301, 'Δx': 13.500003694724114}
# t=290: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 1.4863861825203825e-06, 'v': 9.00000268243092, 'Δx': 13.500003441344859}
# t=291: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 1.3872937097193808e-06, 'v': 9.00000282116029, 'Δx': 13.500003173101732}
# t=292: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 1.2948075028267393e-06, 'v': 9.00000295064104, 'Δx': 13.500002890985684}
# t=293: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 1.2084870632712662e-06, 'v': 9.000003071489747, 'Δx': 13.500002595921558}
# t=294: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 1.1279211478927257e-06, 'v': 9.000003184281862, 'Δx': 13.500002288772578}
# t=295: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -3.7094243708418776e-05, 'v': 8.999999474857491, 'Δx': 13.500001970344385}
# t=296: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.5256758336786893e-06, 'v': 8.999999827425075, 'Δx': 13.50000202285861}
# t=297: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.246111733758124e-06, 'v': 8.999999202813902, 'Δx': 13.500002040116101}
# t=298: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.7070382358596268e-06, 'v': 8.999999573517725, 'Δx': 13.500002119834676}
# t=299: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.0768401722843045e-06, 'v': 8.999998965833708, 'Δx': 13.500002162482872}
# t=300: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.865024958356426e-06, 'v': 8.999999352336204, 'Δx': 13.500002265899468}
# t=301: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.607356675800437e-06, 'v': 8.99999971307187, 'Δx': 13.500002330665836}
# t=302: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.16987626342654e-06, 'v': 8.999999096084244, 'Δx': 13.500002359358632}
# t=303: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.77819133644969e-06, 'v': 8.999999473903378, 'Δx': 13.500002449750184}
# t=304: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 4.1673282024611996e-05, 'v': 9.00000364123158, 'Δx': 13.500002502359848}
# t=305: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -8.78864923147545e-06, 'v': 9.000002762366655, 'Δx': 13.500002138236653}
# t=306: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -3.6812967029237346e-05, 'v': 8.999999081069953, 'Δx': 13.500001861999976}
# t=307: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.7882008555139756e-06, 'v': 8.99999945989004, 'Δx': 13.500001953892934}
# t=308: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.535654126760296e-06, 'v': 8.999999813455453, 'Δx': 13.500002007903902}
# t=309: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.2367986602152895e-06, 'v': 8.999999189775586, 'Δx': 13.50000202655832}
# t=310: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.715730427727442e-06, 'v': 8.999999561348629, 'Δx': 13.500002107580713}
# t=311: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.068727442189726e-06, 'v': 8.999998954475885, 'Δx': 13.500002151445813}
# t=312: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.872596955991237e-06, 'v': 8.999999341735581, 'Δx': 13.500002255998197}
# t=313: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.614423752326975e-06, 'v': 8.999999703177956, 'Δx': 13.500002321824638}
# t=314: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.1632803240719175e-06, 'v': 8.999999086849924, 'Δx': 13.500002351506794}
# t=315: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.7843475161975157e-06, 'v': 8.999999465284676, 'Δx': 13.500002442821767}
# t=316: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 4.167902783279861e-05, 'v': 9.00000363318746, 'Δx': 13.500002496293291}
# t=317: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -8.783286547906409e-06, 'v': 9.000002754858805, 'Δx': 13.500002132974544}
# t=318: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -3.680796177706228e-05, 'v': 8.999999074062627, 'Δx': 13.500001857488655}
# t=319: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.7928723989469703e-06, 'v': 8.999999453349867, 'Δx': 13.500001950082378}
# t=320: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.540014244069921e-06, 'v': 8.99999980735129, 'Δx': 13.500002004747387}
# t=321: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.232729211708632e-06, 'v': 8.99999918407837, 'Δx': 13.500002024012247}
# t=322: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.719528591035672e-06, 'v': 8.999999556031229, 'Δx': 13.50000210560438}
# t=323: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.065182516295638e-06, 'v': 8.999998949512976, 'Δx': 13.50000215000125}
# t=324: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.875905470122043e-06, 'v': 8.999999337103523, 'Δx': 13.500002255049935}
# t=325: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.6175118276941358e-06, 'v': 8.999999698854705, 'Δx': 13.500002321339537}
# t=326: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.160398135554145e-06, 'v': 8.999999082814892, 'Δx': 13.500002351454043}
# t=327: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.7870375360767375e-06, 'v': 8.999999461518644, 'Δx': 13.500002443172548}
# ...
# t=895: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.7760019933704154e-06, 'v': 8.999999476968412, 'Δx': 13.500002273495511}
# t=896: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.5242685423039653e-06, 'v': 8.999999829395266, 'Δx': 13.500002325798619}
# t=897: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.24742519560237e-06, 'v': 8.999999204652747, 'Δx': 13.500002342859034}
# t=898: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.7058123128745902e-06, 'v': 8.999999575233979, 'Δx': 13.500002422393777}
# t=899: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.206898575868019e-05, 'v': 9.000002782132555, 'Δx': 13.500002464870363}
# t=900: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 1.3208258707731507e-06, 'v': 9.000002914215141, 'Δx': 13.50000218665707}
# t=901: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -3.691419923976407e-05, 'v': 8.999999222795218, 'Δx': 13.500001895235528}
# t=902: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.6937173604937806e-06, 'v': 8.999999592166954, 'Δx': 13.500001972955943}
# t=903: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.089273001924298e-06, 'v': 8.999998983239655, 'Δx': 13.500002013739277}
# t=904: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.853421095186222e-06, 'v': 8.999999368581765, 'Δx': 13.500002115415327}
# t=905: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.5965262999269124e-06, 'v': 8.999999728234394, 'Δx': 13.50000217855711}
# t=906: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.179984614241829e-06, 'v': 8.999999110235933, 'Δx': 13.500002205733608}
# t=907: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.7687568453722645e-06, 'v': 8.999999487111618, 'Δx': 13.500002294710043}
# t=908: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.5175064117514794e-06, 'v': 8.999999838862259, 'Δx': 13.500002345998837}
# t=909: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.25373651997773e-06, 'v': 8.999999213488607, 'Δx': 13.500002362112582}
# t=910: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.6999217434575872e-06, 'v': 8.99999958348078, 'Δx': 13.500002440763751}
# t=911: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.20634879014701e-05, 'v': 9.000002789829571, 'Δx': 13.500002482415653}
# t=912: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 1.3156946535902794e-06, 'v': 9.000002921399036, 'Δx': 13.5000022034327}
# t=913: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -3.6918988486961875e-05, 'v': 8.999999229500187, 'Δx': 13.50000191129277}
# t=914: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.6892473459150182e-06, 'v': 8.999999598424921, 'Δx': 13.500001988342774}
# t=915: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.093444967530037e-06, 'v': 8.999998989080424, 'Δx': 13.500002028500262}
# t=916: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.8495271696714014e-06, 'v': 8.999999374033141, 'Δx': 13.50000212959219}
# t=917: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.5928920730277474e-06, 'v': 8.99999973332235, 'Δx': 13.500002192188845}
# t=918: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.183376593453767e-06, 'v': 8.99999911498469, 'Δx': 13.500002218856594}
# t=919: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.765590970317676e-06, 'v': 8.999999491543786, 'Δx': 13.500002307358045}
# t=920: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.514551653140466e-06, 'v': 8.999999842998951, 'Δx': 13.500002358203687}
# t=921: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.256494306681619e-06, 'v': 8.99999921734952, 'Δx': 13.500002373903726}
# t=922: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.6973477978319407e-06, 'v': 8.9999995870843, 'Δx': 13.500002452168701}
# t=923: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.206108554716676e-05, 'v': 9.000002793192856, 'Δx': 13.500002493460215}
# t=924: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 1.313452446134989e-06, 'v': 9.0000029245381, 'Δx': 13.500002214140864}
# t=925: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -3.6921081082548696e-05, 'v': 8.99999923242999, 'Δx': 13.500001921687044}
# t=926: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.6872941682775603e-06, 'v': 8.999999601159407, 'Δx': 13.500001998444077}
# t=927: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.095267954799177e-06, 'v': 8.999998991632612, 'Δx': 13.500002038328148}
# t=928: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.847825808362709e-06, 'v': 8.999999376415193, 'Δx': 13.500002139164849}
# t=929: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.591304019593097e-06, 'v': 8.999999735545595, 'Δx': 13.50000220152333}
# t=930: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.184858747606139e-06, 'v': 8.99999911705972, 'Δx': 13.500002227968707}
# t=931: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.764207666864113e-06, 'v': 8.999999493480487, 'Δx': 13.50000231626268}
# t=932: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.513260511810538e-06, 'v': 8.999999844806538, 'Δx': 13.5000023669146}
# t=933: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.257699377607227e-06, 'v': 8.999999219036601, 'Δx': 13.500002382433877}
# t=934: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.696223056125731e-06, 'v': 8.999999588658907, 'Δx': 13.50000246053014}
# t=935: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.2060035838768444e-05, 'v': 9.00000279466249, 'Δx': 13.500002501664198}
# t=936: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 1.3124726172416007e-06, 'v': 9.000002925909753, 'Δx': 13.500002222197963}
# t=937: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -3.6921995730992804e-05, 'v': 8.999999233710179, 'Δx': 13.500001929606924}
# t=938: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.68644068334807e-06, 'v': 8.999999602354247, 'Δx': 13.500002006235832}
# t=939: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.096064520522375e-06, 'v': 8.999998992747795, 'Δx': 13.500002046000418}
# t=940: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.847082296493577e-06, 'v': 8.999999377456025, 'Δx': 13.500002146725592}
# t=941: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.590610150973127e-06, 'v': 8.99999973651704, 'Δx': 13.500002208979936}
# t=942: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.18550638358185e-06, 'v': 8.999999117966402, 'Δx': 13.500002235328225}
# t=943: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.763603231883855e-06, 'v': 8.999999494326724, 'Δx': 13.50000232353159}
# t=944: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.512696359863761e-06, 'v': 8.99999984559636, 'Δx': 13.500002374098926}
# t=945: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.258225918161032e-06, 'v': 8.999999219773768, 'Δx': 13.500002389539304}
# t=946: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 4.184270173897329e-05, 'v': 9.000003404043941, 'Δx': 13.500002467561899}
# t=947: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -8.63052419000198e-06, 'v': 9.000002540991522, 'Δx': 13.500002127157472}
# t=948: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -3.6665383485402005e-05, 'v': 8.999998874453173, 'Δx': 13.500001873058295}
# t=949: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.925945334739023e-06, 'v': 8.999999267047706, 'Δx': 13.500001985612926}
# t=950: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.6642156659674132e-06, 'v': 8.999999633469272, 'Δx': 13.50000205890808}
# t=951: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.11680787639359e-06, 'v': 8.999999021788485, 'Δx': 13.500002095561172}
# t=952: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.827721808276411e-06, 'v': 8.999999404560665, 'Δx': 13.500002193382329}
# t=953: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.572540387234179e-06, 'v': 8.999999761814703, 'Δx': 13.500002252926265}
# t=954: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.202371483773e-06, 'v': 8.999999141577554, 'Δx': 13.500002276744794}
# t=955: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.747862494442816e-06, 'v': 8.999999516363804, 'Δx': 13.500002362586997}
# t=956: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.4980049518649363e-06, 'v': 8.999999866164298, 'Δx': 13.500002410950628}
# t=957: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.187503223689609e-05, 'v': 9.000003053667522, 'Δx': 13.500002424334184}
# t=958: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 1.1398026343021376e-06, 'v': 9.000003167647785, 'Δx': 13.500002118967359}
# t=959: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -3.7083154240259356e-05, 'v': 8.999999459332361, 'Δx': 13.500001802202519}
# t=960: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.536025920590472e-06, 'v': 8.999999812934954, 'Δx': 13.50000185626925}
# t=961: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.236451650114085e-06, 'v': 8.999999189289788, 'Δx': 13.500001874975737}
# t=962: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.716054283610908e-06, 'v': 8.999999560895217, 'Δx': 13.50000195604673}
# t=963: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.068425167856182e-06, 'v': 8.9999989540527, 'Δx': 13.500001999957135}
# t=964: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.872878975121211e-06, 'v': 8.999999341340597, 'Δx': 13.500002104551868}
# t=965: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.6146870889211954e-06, 'v': 8.999999702809307, 'Δx': 13.500002170417815}
# t=966: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.163034533145149e-06, 'v': 8.999999086505854, 'Δx': 13.500002200136805}
# t=967: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.7845768983251336e-06, 'v': 8.999999464963544, 'Δx': 13.500002291486226}
# t=968: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.5322717919811165e-06, 'v': 8.999999818190723, 'Δx': 13.500002344989866}
# t=969: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.239955497166882e-06, 'v': 8.999999194195173, 'Δx': 13.500002363170779}
# t=970: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.712784044046249e-06, 'v': 8.999999565473576, 'Δx': 13.500002443751214}
# t=971: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.2075492700194615e-05, 'v': 9.000002773022846, 'Δx': 13.500002487203801}
# t=972: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 1.3268990212393625e-06, 'v': 9.000002905712748, 'Δx': 13.500002209901481}
# t=973: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -3.6908530965995604e-05, 'v': 8.99999921485965, 'Δx': 13.500001919330202}
# t=974: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.699007701343242e-06, 'v': 8.99999958476042, 'Δx': 13.500001997844265}
# t=975: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.084335317621939e-06, 'v': 8.99999897632689, 'Δx': 13.500002039368155}
# t=976: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.858029580324098e-06, 'v': 8.999999362129847, 'Δx': 13.500002141735422}
# t=977: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.6008276032497436e-06, 'v': 8.999999722212607, 'Δx': 13.500002205522378}
# t=978: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.175970085948034e-06, 'v': 8.999999104615599, 'Δx': 13.500002233301075}
# t=979: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.772503735920101e-06, 'v': 8.999999481865972, 'Δx': 13.500002322839464}
# t=980: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.521003532333493e-06, 'v': 8.999999833966324, 'Δx': 13.500002374652809}
# t=981: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.250472552136533e-06, 'v': 8.99999920891907, 'Δx': 13.500002391256203}
# t=982: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 4.1849938208876744e-05, 'v': 9.000003393912891, 'Δx': 13.50000247036428}
# t=983: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -8.623770282796872e-06, 'v': 9.000002531535863, 'Δx': 13.500002130972916}
# t=984: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -3.6659079626461826e-05, 'v': 8.9999988656279, 'Δx': 13.500001877819273}
# t=985: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.931828855572557e-06, 'v': 8.999999258810785, 'Δx': 13.500001991256454}
# t=986: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.669706967236957e-06, 'v': 8.999999625781482, 'Δx': 13.500002065375384}
# t=987: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.111682684612716e-06, 'v': 8.999999014613214, 'Δx': 13.500002102797225}
# t=988: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.832505371132707e-06, 'v': 8.999999397863752, 'Δx': 13.50000220133586}
# t=989: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.5770049827407044e-06, 'v': 8.99999975556425, 'Δx': 13.500002261549412}
# t=990: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.1982045014399814e-06, 'v': 8.9999991357438, 'Δx': 13.500002285992991}
# t=991: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.7517516072151605e-06, 'v': 8.99999951091896, 'Δx': 13.500002372418635}
# t=992: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.5016348586645563e-06, 'v': 8.999999861082445, 'Δx': 13.500002421326712}
# t=993: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.1878420132856045e-05, 'v': 9.000003048924459, 'Δx': 13.500002435218448}
# t=994: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 1.1429647955869413e-06, 'v': 9.000003163220939, 'Δx': 13.500002130325925}
# t=995: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -3.7080203233313734e-05, 'v': 8.999999455200616, 'Δx': 13.500001814003781}
# t=996: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.538780400902384e-06, 'v': 8.999999809078655, 'Δx': 13.50000186848365}
# t=997: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.233880792980658e-06, 'v': 8.999999185690577, 'Δx': 13.500001887575763}
# t=998: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': 3.7184537578478947e-06, 'v': 8.999999557535952, 'Δx': 13.50000196900669}
# t=999: reward=-68.000, term=False, trunc=True, info={'collision': False, 'a': -6.06618566993701e-06, 'v': 8.999998950917385, 'Δx': 13.500002013253038}

# %%
from __future__ import annotations
import torch, numpy as np
import gymnasium as gym

def _to_tensor(x: np.ndarray) -> torch.Tensor:
    return torch.as_tensor(x, dtype=torch.float32)

class AttackWrapper:
    def __init__(self, model, epsilon: float = 0.01, device: str = "cpu"):
        self.model = model
        self.eps = float(epsilon)
        self.device = device

    def perturb(self, obs: np.ndarray) -> np.ndarray:
        return obs

    def act(self, obs: np.ndarray):
        obs_adv = self.perturb(obs)
        with torch.no_grad():
            action, _ = self.model.predict(obs_adv, deterministic=True)
        return action, obs_adv

class FGSMAttack(AttackWrapper):
    def perturb(self, obs: np.ndarray) -> np.ndarray:
        self.model.policy.set_training_mode(True)
        self.model.policy.zero_grad(set_to_none=True)
        obs_t = _to_tensor(obs)
        single = False
        if obs_t.ndim == 1:
            obs_t = obs_t.unsqueeze(0)
            single = True
        obs_t = obs_t.to(self.device)
        obs_t.requires_grad_(True)
        features = self.model.policy.extract_features(obs_t)
        latent_pi, _ = self.model.policy.mlp_extractor(features)
        mean_actions = self.model.policy.action_net(latent_pi)
        (mean_actions**2).sum().backward()
        adv = torch.clamp(obs_t + self.eps * torch.sign(obs_t.grad), -1.0, 1.0)
        out = adv.detach().cpu().numpy()
        return out[0] if single else out

class OIAttack(AttackWrapper):
    def perturb(self, obs: np.ndarray) -> np.ndarray:
        self.model.policy.set_training_mode(True)
        self.model.policy.zero_grad(set_to_none=True)
        obs_t = _to_tensor(obs)
        single = False
        if obs_t.ndim == 1:
            obs_t = obs_t.unsqueeze(0)
            single = True
        obs_t = obs_t.to(self.device)
        obs_t.requires_grad_(True)
        features = self.model.policy.extract_features(obs_t)
        _, latent_vf = self.model.policy.mlp_extractor(features)
        values = self.model.policy.value_net(latent_vf)
        values.sum().backward()
        adv = torch.clamp(obs_t + self.eps * torch.sign(obs_t.grad), -1.0, 1.0)
        out = adv.detach().cpu().numpy()
        return out[0] if single else out

# Perturb observations from reset() and step()
class ObsAttackEnv(gym.Wrapper):
    def __init__(self, env: gym.Env, attacker: AttackWrapper):
        super().__init__(env)
        self.attacker = attacker

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        return self.attacker.perturb(obs), info

    def step(self, action):
        obs, r, term, trunc, info = self.env.step(action)
        return self.attacker.perturb(obs), r, term, trunc, info

# %%
# ----------------------
# Quick sanity check
# ----------------------
try:
    atk = FGSMAttack(model, epsilon=0.01, device="cpu")
    obs = env.reset()[0]
    adv = atk.perturb(obs)
    print("FGSM sanity check:")
    print("  original obs:", obs)
    print("  adv obs     :", adv)
    print("  max |Δ|     :", float(np.max(np.abs(np.array(adv) - np.array(obs)))))

    atk2 = OIAttack(model, epsilon=0.01, device="cpu")
    adv2 = atk2.perturb(obs)
    print("\\nOIA sanity check:")
    print("  original obs:", obs)
    print("  adv obs     :", adv2)
    print("  max |Δ|     :", float(np.max(np.abs(np.array(adv2) - np.array(obs)))))
except NameError:
    print("⚠️ Define `model` and `env` first (from training/eval notebook) to run the sanity check.")
# Out:
# ⚠️ Define `model` and `env` first (from training/eval notebook) to run the sanity check.
